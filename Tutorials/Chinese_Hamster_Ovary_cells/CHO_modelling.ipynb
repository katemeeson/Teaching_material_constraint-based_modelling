# %%
import numpy as np
import pandas as pd
import cobra
from cobra.io import read_sbml_model
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from cobra import Model, Reaction, Metabolite

# %% [markdown]
# ### Chinese hamster ovary cells

# %% [markdown]
# Chinese hamster ovary (CHO) cells are the powerhouses for the production of many drugs, for example, those used to treat Parkinson's Disease, cancers and Alzheimer's (Xu et al, 2023, PMID: 36648523). Genome-scale models are a popular platform for predicting metabolic signatures of cells under particular environmental conditions, but how well do these models replicate the actual biological priorities and adaptive evolution of cells? One approach to evaluate this is through exploring the objective function. But, before we do this, we need to understand the different reactions which the genome-scale models contain, and how these are structured and organised within the model.

# %% [markdown]
# ![image.png](attachment:7094feff-36b1-42d9-874b-ca48bef62686.png)

# %% [markdown]
# Image from PMID: 27883890

# %% [markdown]
# #### 1. Load comprehensive genome-scale models (iCHO2291 and updated iCHO2441)

# %% [markdown]
# Depending on what's easier for your report, you can work directly on the CHO GEM from 2020 (iCHO2291: https://www.ebi.ac.uk/biomodels/MODEL1912180001), which has been assigned to 'model_original' below. Alternatively, you can work on the iCHO2441 model from 2023 (the most recent CHO GEM), which the post-doc before me updated with the metabolic subsystems (e.g. 'transport reactions' or 'lipid metabolism' etc) from the iCHO2291 model (assigned to 'model_updated below).

# %%
# model_updated = read_sbml_model('iCHO2441_221-107_producing.xml') - switch between this line and the next to change model :)
model_original = read_sbml_model('iCHO2291.xml')
model_original
# Out:
# <Model iCHO2291 at 0x2dbb9517950>

# %% [markdown]
# ### 2. Study the metabolic subsystem organisation of models

# %% [markdown]
# I couldn't find a good image describing the central metabolic subsystems of CHO cells, but here is a figure (PMID: 35741058) which shows you the changes in CHO metabolism over its time in culture. The cells shift from a phase of exponential growth (where metabolism favours maximal growth), to production of their recombinant protein (what we isolate to make drugs) to the stationary/death phase where there are too many cells in too small of a space and not enough feed to keep them alive, so they die:

# %% [markdown]
# ![image.png](attachment:f61cd1a4-7cb4-4679-87ac-900b536246c7.png)

# %% [markdown]
# Print the 'groups' (a.k.a subsystems) of the model and see how many reactions are assigned to each subsystem

# %%
for g in model_original.groups:
    print(g.name,'; number of reactions in subsystem:',len(g.members))
# Out:
# Amino acid metabolism ; number of reactions in subsystem: 381
# Bile, eicosanoid and steroid metabolism ; number of reactions in subsystem: 212
# Biomass synthesis ; number of reactions in subsystem: 47
# Central carbon and energy metabolism ; number of reactions in subsystem: 93
# Exchange/demand/sink reaction ; number of reactions in subsystem: 649
# Fatty acid metabolism ; number of reactions in subsystem: 728
# Glycan and glycosaminoglycan metabolism ; number of reactions in subsystem: 497
# Glycerophospholipid, sphingolipid and inositol metabolism ; number of reactions in subsystem: 289
# Miscellaneous ; number of reactions in subsystem: 324
# Nucelotide metabolism ; number of reactions in subsystem: 288
# Other carbon metabolism ; number of reactions in subsystem: 158
# Transport ; number of reactions in subsystem: 2245
# Unassigned ; number of reactions in subsystem: 63
# Vitamin and cofactor metabolism ; number of reactions in subsystem: 217
# Xenobiotics metabolism ; number of reactions in subsystem: 45

# %% [markdown]
# Another way to do this is to print the individual reaction and find its subsystem, but this gives a very long list to look through!

# %%
for r in model_original.reactions:
    print(r.id,':',r.subsystem) #here we use the term 'subsystem' instead of group
# Out:
# 10FTHF5GLUtl : Transport
# 10FTHF5GLUtm : Transport
# 10FTHF6GLUtl : Transport
# 10FTHF6GLUtm : Transport
# 10FTHF7GLUtl : Transport
# 10FTHF7GLUtm : Transport
# 10FTHFtl : Transport
# 10FTHFtm : Transport
# 11DOCRTSLtm : Transport
# 11DOCRTSLtr : Transport
# 11DOCRTSTRNtm : Transport
# 11DOCRTSTRNtr : Transport
# 13DAMPPOX : Miscellaneous
# 1a_24_25VITD2Hm : Vitamin and cofactor metabolism
# 1a_24_25VITD3Hm : Vitamin and cofactor metabolism
# 1a_25VITD2Hm : Vitamin and cofactor metabolism
# 1a_25VITD3Hm : Vitamin and cofactor metabolism
# 1a25DHVITD3TRn : Transport
# 1MNCAMti : Transport
# 1PPDCRp : Amino acid metabolism
# 24_25DHVITD2t : Transport
# 24_25DHVITD2tm : Transport
# 24_25DHVITD3t : Transport
# 24_25DHVITD3tm : Transport
# 24_25VITD2Hm : Vitamin and cofactor metabolism
# 24_25VITD3Hm : Vitamin and cofactor metabolism
# 24NPHte : Transport
# 25HVITD2t : Transport
# 25HVITD2tm : Transport
# 25HVITD3c : Vitamin and cofactor metabolism
# 25HVITD3t : Transport
# 25HVITD3tm : Transport
# 25VITD2Hm : Vitamin and cofactor metabolism
# 25VITD3Hm : Vitamin and cofactor metabolism
# 2AMACHYD : Amino acid metabolism
# 2AMACSULT : Amino acid metabolism
# 2AMADPTm : Amino acid metabolism
# 2AOBUTtm : Transport
# 2DR1PP : Nucelotide metabolism
# 2HBO : Miscellaneous
# 2HBt2 : Transport
# 2MB2COAc : Transport
# 2MCITt : Transport
# 2OXOADPTm : Amino acid metabolism
# 34DHOXPEGOX : Amino acid metabolism
# 34DHOXPEGt : Transport
# 34DHPHAMT : Amino acid metabolism
# 34DHPHELAT1tc : Transport
# 34DHPHEt : Transport
# 34DHPLACOX : Amino acid metabolism
# 34DHPLACOXy : Amino acid metabolism
# 34DHXMANDACOX : Amino acid metabolism
# 34DHXMANDACOXy : Amino acid metabolism
# 34HPLFM : Vitamin and cofactor metabolism
# 34HPPOR : Amino acid metabolism
# 34HPPte : Transport
# 35CGMPtn : Transport
# 3AIB_Dtm : Transport
# 3AIBt : Transport
# 3AIBt1m : Transport
# 3AIBTm : Amino acid metabolism
# 3DPHBH1 : Vitamin and cofactor metabolism
# 3DPHBH2 : Vitamin and cofactor metabolism
# 3DSPHR : Glycerophospholipid, sphingolipid and inositol metabolism
# 3HAO : Amino acid metabolism
# 3HBCOAHLm : Amino acid metabolism
# 3HCO3_NAt : Transport
# 3HKYNAKGAT : Amino acid metabolism
# 3HLYTCL : Amino acid metabolism
# 3HXKYNDCL : Amino acid metabolism
# 3HXKYNOXDA : Amino acid metabolism
# 3M4HDXPAC : Amino acid metabolism
# 3MLDAt : Transport
# 3MOBt2im : Transport
# 3MOBte : Transport
# 3MOPt2im : Transport
# 3MOPte : Transport
# 3MOX4HOXPGALDOX : Amino acid metabolism
# 3MOX4HOXPGALDOXy : Amino acid metabolism
# 3MOXTYROX : Amino acid metabolism
# 3NTD7l : Nucelotide metabolism
# 3SALAASPm : Transport
# 3SALACBOXL : Amino acid metabolism
# 3SALAOX : Amino acid metabolism
# 3SALATAi : Amino acid metabolism
# 3SALATAim : Amino acid metabolism
# 3SPYRSP : Amino acid metabolism
# 3SPYRSPm : Amino acid metabolism
# 41R1H2MAE12BOOX : Amino acid metabolism
# 41R2A1H12BOOX : Amino acid metabolism
# 42A12BOOX : Amino acid metabolism
# 4ABUTtm : Transport
# 4HBZCOAFm : Vitamin and cofactor metabolism
# 4HBZFm : Vitamin and cofactor metabolism
# 4HDEBRISOQUINEte : Transport
# 4HGLSDm : Amino acid metabolism
# 4HOXPACDOX : Amino acid metabolism
# 4HOXPACDOXy : Amino acid metabolism
# 4HPRO_LTte : Transport
# 4HPROLTASCT1 : Transport
# 4MOPt2im : Transport
# 4MOPte : Transport
# 4MPTNLte : Transport
# 4MPTNLtm : Transport
# 4MTOLBUTAMIDEte : Transport
# 4NPHSFte : Transport
# 4NPHSULT : Xenobiotics metabolism
# 4NPHte : Transport
# 4OHPROIMINOtc : Transport
# 4PYRDX : Transport
# 5ADTSTSTERONEGLCte : Transport
# 5ADTSTSTERONEGLCtr : Transport
# 5ADTSTSTERONESte : Transport
# 5ADTSTSTERONESULT : Bile, eicosanoid and steroid metabolism
# 5ADTSTSTERONEte : Transport
# 5ADTSTSTERONEtr : Transport
# 5AOPtm : Transport
# 5FTHFt2 : Transport
# 5HLTDL : Amino acid metabolism
# 5HOMEPRAZOLEte : Transport
# 5HOXINDACTO2OX : Amino acid metabolism
# 5HOXINDACTOX : Amino acid metabolism
# 5HOXINOXDA : Amino acid metabolism
# 5HTRPDOX : Amino acid metabolism
# 5HTRPVESSEC : Transport
# 5HXKYNDCL : Amino acid metabolism
# 5HXKYNOXDA : Amino acid metabolism
# 5MTAte : Transport
# 5MTHFt : Transport
# 5MTHFt2 : Transport
# 5OXPROt : Transport
# 5THFtl : Transport
# 5THFtm : Transport
# 6DHFtl : Transport
# 6DHFtm : Transport
# 6HTSTSTERONEte : Transport
# 6HTSTSTERONEtr : Transport
# 6THFtl : Transport
# 6THFtm : Transport
# 7DHCHSTEROLtr : Transport
# 7DHFtl : Transport
# 7DHFtm : Transport
# 7THFtl : Transport
# 7THFtm : Transport
# A_MANASE : Glycan and glycosaminoglycan metabolism
# A_MANASEly : Glycan and glycosaminoglycan metabolism
# A4GALTg : Glycerophospholipid, sphingolipid and inositol metabolism
# A4GNT1g : Glycan and glycosaminoglycan metabolism
# A4GNT2g : Glycan and glycosaminoglycan metabolism
# AACOAT : Miscellaneous
# AACTOOR : Amino acid metabolism
# AACTtm : Transport
# THP2CDH : Amino acid metabolism
# AASAD3 : Amino acid metabolism
# AASAD3m : Amino acid metabolism
# AATAi : Amino acid metabolism
# ABO1g : Glycan and glycosaminoglycan metabolism
# ABO2g : Glycan and glycosaminoglycan metabolism
# ABO3g : Glycan and glycosaminoglycan metabolism
# ABO4g : Glycan and glycosaminoglycan metabolism
# ABO5g : Glycan and glycosaminoglycan metabolism
# ABO6g : Glycan and glycosaminoglycan metabolism
# ABO7g : Glycan and glycosaminoglycan metabolism
# ABO8g : Glycan and glycosaminoglycan metabolism
# ABO9g : Glycan and glycosaminoglycan metabolism
# ABTArm : Amino acid metabolism
# ABTD : Other carbon metabolism
# ABTti : Transport
# ABUTD : Miscellaneous
# ABUTt2r : Transport
# ABUTt4_2_r : Transport
# ACACT10m : Amino acid metabolism
# ACACT1r : Amino acid metabolism
# ACACT1rm : Amino acid metabolism
# ACACT1x : Bile, eicosanoid and steroid metabolism
# ACACt2 : Transport
# ACACt2m : Transport
# ACACtx : Transport
# ACALDt : Transport
# ACALDtm : Transport
# ACALDtx : Transport
# ACCOAC : Fatty acid metabolism
# ACCOACm : Fatty acid metabolism
# ACCOAgt : Transport
# ACCOALm : Miscellaneous
# ACCOAtn : Transport
# ACCOAtr : Transport
# ACETONEt2 : Transport
# ACETONEt2m : Transport
# ACGAGBSIDEtg : Transport
# ACGAGBSIDEtl : Transport
# ACGALFUCGALACGALFUC12GAL14ACGLCGALGLUSIDEte : Transport
# ACGALFUCGALACGALFUC12GAL14ACGLCGALGLUSIDEtg : Transport
# ACGALFUCGALACGALFUCGALACGLCGAL14ACGLCGALGLUSIDEte : Transport
# ACGALFUCGALACGALFUCGALACGLCGAL14ACGLCGALGLUSIDEtg : Transport
# ACGALK : Other carbon metabolism
# ACGALK2 : Other carbon metabolism
# ACGALtly : Transport
# ACGAM2E : Other carbon metabolism
# ACGAM6PSi : Other carbon metabolism
# ACGAMK : Other carbon metabolism
# ACGAMPM : Other carbon metabolism
# ACGAMtly : Transport
# ACGBGBSIDEtg : Transport
# ACGBGBSIDEtl : Transport
# ACGPID : Glycerophospholipid, sphingolipid and inositol metabolism
# ACGSm : Miscellaneous
# ACHEe : Glycerophospholipid, sphingolipid and inositol metabolism
# ACHtn : Transport
# ACHVESSEC : Transport
# ACITL : Central carbon and energy metabolism
# ACN13ACNGALGBSIDEte : Transport
# ACN13ACNGALGBSIDEtg : Transport
# ACN23ACNGALGBSIDEte : Transport
# ACN23ACNGALGBSIDEtg : Transport
# ACNACNGAL14ACGLCGALGLUSIDEte : Transport
# ACNACNGAL14ACGLCGALGLUSIDEtg : Transport
# ACNACNGALGBSIDEte : Transport
# ACNACNGALGBSIDEtg : Transport
# ACNAM9PL : Other carbon metabolism
# ACNAM9PL2 : Other carbon metabolism
# ACNAMlt : Transport
# ACNAMPH : Other carbon metabolism
# ACNAMtn : Transport
# ACNGALACGLCGAL14ACGLCGALGLUSIDEte : Transport
# ACNGALACGLCGAL14ACGLCGALGLUSIDEtg : Transport
# ACNMLr : Other carbon metabolism
# ACOAD10m : Amino acid metabolism
# ACOAD1fm : Miscellaneous
# ACOAD8m : Amino acid metabolism
# ACOAD9m : Amino acid metabolism
# ACOAHi : Other carbon metabolism
# ACODA : Miscellaneous
# ACOX22x : Bile, eicosanoid and steroid metabolism
# ACOX2x : Bile, eicosanoid and steroid metabolism
# ACP1_FMN : Vitamin and cofactor metabolism
# ACRNtm : Transport
# ACSm : Fatty acid metabolism
# ACt2m : Transport
# ACt2r : Transport
# ACtg : Transport
# ACTLMO : Other carbon metabolism
# ACTNMO : Other carbon metabolism
# ACYP : Central carbon and energy metabolism
# ADA : Nucelotide metabolism
# ADAe : Nucelotide metabolism
# ADCim : Miscellaneous
# ADEt : Transport
# ADEtl : Transport
# ADHAPtx : Transport
# ADK1 : Nucelotide metabolism
# ADK1m : Nucelotide metabolism
# ADK3 : Nucelotide metabolism
# ADK3m : Nucelotide metabolism
# ADKd : Nucelotide metabolism
# ADMDC : Amino acid metabolism
# ADNCYC : Nucelotide metabolism
# ADNK1 : Nucelotide metabolism
# ADNK1m : Nucelotide metabolism
# ADNK3 : Nucelotide metabolism
# ADNK4 : Nucelotide metabolism
# ADNt : Transport
# ADNt4 : Transport
# ADNt5 : Transport
# ADNtl : Transport
# ADNtm : Transport
# ADPACDAc : Fatty acid metabolism
# ADPACTD : Transport
# ADPCOACROT : Miscellaneous
# ADPCOAPTE : Fatty acid metabolism
# ADPGK : Central carbon and energy metabolism
# ADPGLC : Other carbon metabolism
# ADPMAN : Other carbon metabolism
# ADPRDP : Other carbon metabolism
# ADPRDPm : Other carbon metabolism
# ADPRIBt : Transport
# ADPT : Nucelotide metabolism
# ADPtx : Transport
# ADRNCOAtx : Transport
# ADRNCPT1 : Miscellaneous
# ADRNCPT2 : Miscellaneous
# ADRNCRNt : Transport
# ADRNLPVESSEC : Transport
# ADRNt : Transport
# ADSK : Nucelotide metabolism
# ADSKn : Nucelotide metabolism
# ADSL1 : Nucelotide metabolism
# ADSL2 : Nucelotide metabolism
# ADSS : Nucelotide metabolism
# AFLATOXINte : Transport
# AG13T10g : Glycan and glycosaminoglycan metabolism
# AG13T11g : Glycan and glycosaminoglycan metabolism
# AG13T12g : Glycan and glycosaminoglycan metabolism
# AG13T13g : Glycan and glycosaminoglycan metabolism
# AG13T14g : Glycan and glycosaminoglycan metabolism
# AG13T15g : Glycan and glycosaminoglycan metabolism
# AG13T16g : Glycan and glycosaminoglycan metabolism
# AG13T17g : Glycan and glycosaminoglycan metabolism
# AG13T18g : Glycan and glycosaminoglycan metabolism
# AG13T1g : Glycan and glycosaminoglycan metabolism
# AG13T2g : Glycan and glycosaminoglycan metabolism
# AG13T3g : Glycan and glycosaminoglycan metabolism
# AG13T4g : Glycan and glycosaminoglycan metabolism
# AG13T5g : Glycan and glycosaminoglycan metabolism
# AG13T6g : Glycan and glycosaminoglycan metabolism
# AG13T7g : Glycan and glycosaminoglycan metabolism
# AG13T8g : Glycan and glycosaminoglycan metabolism
# AG13T9g : Glycan and glycosaminoglycan metabolism
# AGDC : Other carbon metabolism
# AGLPC : Glycerophospholipid, sphingolipid and inositol metabolism
# AGLPED : Glycerophospholipid, sphingolipid and inositol metabolism
# AGLPET : Glycerophospholipid, sphingolipid and inositol metabolism
# AGLPH : Glycerophospholipid, sphingolipid and inositol metabolism
# AGLPR : Glycerophospholipid, sphingolipid and inositol metabolism
# AGLPT : Glycerophospholipid, sphingolipid and inositol metabolism
# AGMTm : Amino acid metabolism
# AGPAT1 : Glycerophospholipid, sphingolipid and inositol metabolism
# AGPAT1m : Glycerophospholipid, sphingolipid and inositol metabolism
# AGPex : Transport
# AGPRim : Miscellaneous
# AGPSx : Glycerophospholipid, sphingolipid and inositol metabolism
# AGTim : Amino acid metabolism
# AGTix : Amino acid metabolism
# AGXT2L2 : Amino acid metabolism
# AHANDROSTANGLCte : Transport
# AHANDROSTANGLCtr : Transport
# AHC : Amino acid metabolism
# AHCYStd : Transport
# AHCYSte : Transport
# AHCYStn : Transport
# AHCYStr : Transport
# AHEXASE2ly : Glycan and glycosaminoglycan metabolism
# AHEXASEly : Glycan and glycosaminoglycan metabolism
# AICART : Nucelotide metabolism
# AICARte : Transport
# AIRCr : Nucelotide metabolism
# AK2LGCHOLt : Transport
# AKGMALtm : Transport
# AKGt4_3 : Transport
# AKGtp : Transport
# AKR1C1 : Bile, eicosanoid and steroid metabolism
# AKR1C41 : Bile, eicosanoid and steroid metabolism
# AKR1C42 : Bile, eicosanoid and steroid metabolism
# AKR1D : Bile, eicosanoid and steroid metabolism
# AKR1D2 : Bile, eicosanoid and steroid metabolism
# ALA_DTDe : Transport
# ALAALACNc : Amino acid metabolism
# ALAALAPEPT1tc : Transport
# ALAASNNaEx : Transport
# ALAATB0tc : Transport
# ALACYSNaEx : Transport
# ALADGLNexR : Transport
# ALADGLYexR : Transport
# ALAGLNexR : Transport
# ALAGLNNaEx : Transport
# ALAGLYexR : Transport
# ALASERNaEx : Transport
# ALASm : Amino acid metabolism
# ALAt2r : Transport
# ALAt2rL : Transport
# ALAt4 : Transport
# ALATA_L : Amino acid metabolism
# ALATHRNaEx : Transport
# ALAtN1 : Transport
# ALAyLATthc : Transport
# ALCD1 : Miscellaneous
# ALCD21_D : Other carbon metabolism
# ALCD21_L : Other carbon metabolism
# ALCD22_D : Other carbon metabolism
# ALCD22_L : Other carbon metabolism
# ALCD2if : Other carbon metabolism
# ALCD2yf : Other carbon metabolism
# ALDD19x : Amino acid metabolism
# ALDD19y : Amino acid metabolism
# ALDD20x : Amino acid metabolism
# ALDD20xm : Amino acid metabolism
# ALDD21 : Fatty acid metabolism
# ALDD2x : Other carbon metabolism
# ALDD2xm : Other carbon metabolism
# ALDD2y : Other carbon metabolism
# ALDSTRNte : Transport
# ALDSTRNtm : Transport
# ALKP : Glycerophospholipid, sphingolipid and inositol metabolism
# ALOX12 : Bile, eicosanoid and steroid metabolism
# ALOX12R : Bile, eicosanoid and steroid metabolism
# ALOX15 : Bile, eicosanoid and steroid metabolism
# ALOX5 : Bile, eicosanoid and steroid metabolism
# ALOX52 : Bile, eicosanoid and steroid metabolism
# ALR : Amino acid metabolism
# ALR2 : Other carbon metabolism
# ALR3 : Other carbon metabolism
# AM6SAD : Amino acid metabolism
# AMACR2p : Bile, eicosanoid and steroid metabolism
# AMACRp : Bile, eicosanoid and steroid metabolism
# AMANK : Other carbon metabolism
# AMCOXO : Amino acid metabolism
# AMETr : Transport
# AMETt2m : Transport
# AMETtd : Transport
# AMETtn : Transport
# AMPDA : Nucelotide metabolism
# AMPTASECG : Amino acid metabolism
# AMPTASECGe : Amino acid metabolism
# AMPtp : Transport
# AMPtr : Transport
# AMY1e : Other carbon metabolism
# AMY2e : Other carbon metabolism
# ANDRSTRNGLCte : Transport
# ANDRSTRNGLCtr : Transport
# ANDRSTRNte : Transport
# ANDRSTRNtr : Transport
# ANTHte : Transport
# ANTIPYRENEte : Transport
# AOBUTDsm : Amino acid metabolism
# AP4AH1 : Nucelotide metabolism
# APAT2rm : Miscellaneous
# APNNOXte : Transport
# APOC_LYS_BTNP : Miscellaneous
# APOC_LYS_BTNPm : Miscellaneous
# APOCF : Miscellaneous
# APOCFm : Miscellaneous
# APPNNte : Transport
# APRGSTRNte : Transport
# APRTO2 : Amino acid metabolism
# AQCOBALt : Transport
# ARAB_Lt : Transport
# ARABR : Other carbon metabolism
# ARACHCOAtcx : Transport
# ARACHCPT1 : Miscellaneous
# ARACHCPT2 : Miscellaneous
# ARACHCRNt : Transport
# ARACHDCOAtcx : Transport
# ARACHDt2 : Transport
# ARACHDtr : Transport
# ARACHFATPc : Transport
# ARACHt : Transport
# ARD1_cho : Amino acid metabolism
# ARGATB0tc : Transport
# ARGDCm : Amino acid metabolism
# ARGLYSex : Transport
# ARGN : Miscellaneous
# ARGNm : Miscellaneous
# ARGSL : Amino acid metabolism
# ARGSS : Amino acid metabolism
# ARGt4 : Transport
# ARGt5r : Transport
# ARGtm : Transport
# ARS_cho : Amino acid metabolism
# ARSA : Glycerophospholipid, sphingolipid and inositol metabolism
# ASAH1 : Glycerophospholipid, sphingolipid and inositol metabolism
# ASCBOX : Vitamin and cofactor metabolism
# ASCBt : Transport
# ASCBt4 : Transport
# ASCBt5 : Transport
# Asn_X_Ser/Thrtr : Transport
# ASNALANaEx : Transport
# ASNATB0tc : Transport
# ASNCYSNaEx : Transport
# ASNGLNNaEx : Transport
# ASNN : Amino acid metabolism
# ASNNm : Amino acid metabolism
# ASNPHELAT2tc : Transport
# ASNS1 : Amino acid metabolism
# ASNSERNaEx : Transport
# ASNt4 : Transport
# ASNTHRNaEx : Transport
# ASNtm : Transport
# ASNtN1 : Transport
# ASP1DC : Miscellaneous
# ASPCTr : Nucelotide metabolism
# ASPDt6 : Transport
# ASPDTDe : Transport
# ASPDxt : Transport
# ASPGLUm : Transport
# ASPNATm : Amino acid metabolism
# ASPOX : Amino acid metabolism
# ASPPROASCT1 : Transport
# ASPt6 : Transport
# ASPTA : Amino acid metabolism
# ASPTAm : Amino acid metabolism
# ASPte : Transport
# ATP1ter : Transport
# ATP2ter : Transport
# ATPasel : Transport
# ATPH1e : Nucelotide metabolism
# ATPH2e : Nucelotide metabolism
# ATPS4m : Central carbon and energy metabolism
# ATPtm : Transport
# ATPtn : Transport
# ATPtx : Transport
# AVITE1t : Transport
# B_MANNASEly : Glycan and glycosaminoglycan metabolism
# B3GALT3g : Glycerophospholipid, sphingolipid and inositol metabolism
# B3GALT41g : Glycerophospholipid, sphingolipid and inositol metabolism
# B3GALT42g : Glycerophospholipid, sphingolipid and inositol metabolism
# B3GALT43g : Glycerophospholipid, sphingolipid and inositol metabolism
# B3GALT44g : Glycerophospholipid, sphingolipid and inositol metabolism
# B3GALT5g : Glycerophospholipid, sphingolipid and inositol metabolism
# B3GALTg : Glycan and glycosaminoglycan metabolism
# B3GNT11g : Glycan and glycosaminoglycan metabolism
# B3GNT12g : Glycan and glycosaminoglycan metabolism
# B3GNT310g : Glycan and glycosaminoglycan metabolism
# B3GNT311g : Glycan and glycosaminoglycan metabolism
# B3GNT312g : Glycan and glycosaminoglycan metabolism
# B3GNT313g : Glycan and glycosaminoglycan metabolism
# B3GNT314g : Glycan and glycosaminoglycan metabolism
# B3GNT315g : Glycan and glycosaminoglycan metabolism
# B3GNT34g : Glycerophospholipid, sphingolipid and inositol metabolism
# B3GNT35g : Glycerophospholipid, sphingolipid and inositol metabolism
# B3GNT37g : Glycerophospholipid, sphingolipid and inositol metabolism
# B3GNT38g : Glycan and glycosaminoglycan metabolism
# B3GNT39g : Glycerophospholipid, sphingolipid and inositol metabolism
# B3GNT51g : Glycan and glycosaminoglycan metabolism
# CCGTx : Bile, eicosanoid and steroid metabolism
# CCTTx : Bile, eicosanoid and steroid metabolism
# DCCGTx : Bile, eicosanoid and steroid metabolism
# DCCTTx : Bile, eicosanoid and steroid metabolism
# BACCL : Miscellaneous
# BACCLm : Miscellaneous
# BALABETAtc : Transport
# BALAPAT1tc : Transport
# BALAtmr : Transport
# BALAVECSEC : Transport
# BAMPPALDOX : Miscellaneous
# BBHOX : Amino acid metabolism
# BCDO : Vitamin and cofactor metabolism
# BCRNe : Transport
# BDG2HCGHD : Miscellaneous
# BDHm : Miscellaneous
# BDMT : Glycan and glycosaminoglycan metabolism
# BETALDHx : Amino acid metabolism
# BETALDHxm : Amino acid metabolism
# BHBt : Transport
# BHBtm : Transport
# BHMT : Amino acid metabolism
# BILDGLCURt : Transport
# BILDGLCURte : Transport
# BILDGLCURtr : Transport
# BILGLCURt : Transport
# BILGLCURte : Transport
# BILIRED : Miscellaneous
# BILIRED2 : Miscellaneous
# BILIRUBt2 : Transport
# BILIRUBtr : Transport
# BIOCYTtn : Transport
# BMTer : Glycerophospholipid, sphingolipid and inositol metabolism
# BPNT : Nucelotide metabolism
# BPNT2 : Nucelotide metabolism
# BTND1 : Miscellaneous
# BTND1n : Miscellaneous
# BTNDe : Miscellaneous
# BTNDm : Miscellaneous
# BTNPL : Miscellaneous
# BTNPLm : Miscellaneous
# BTNt2 : Transport
# BTNt2m : Transport
# BTNt3 : Transport
# BTNt3i : Transport
# BTNTe : Transport
# BTNtn : Transport
# BUP2 : Nucelotide metabolism
# BUTt2m : Transport
# BUTt2r : Transport
# BZt : Transport
# BZtr : Transport
# C10DCc : Miscellaneous
# C10DCCACT : Transport
# C10DCe : Transport
# C10OHc : Miscellaneous
# C12OHc : Miscellaneous
# C14OHc : Miscellaneous
# C14STRr : Bile, eicosanoid and steroid metabolism
# C160CPT1 : Miscellaneous
# C160CPT2 : Miscellaneous
# C160CRNt : Transport
# C161CPT1 : Miscellaneous
# C161CPT12 : Miscellaneous
# C161CPT2 : Miscellaneous
# C161CPT22 : Miscellaneous
# C161CRN2t : Transport
# C161CRNt : Transport
# PMTCOAtxc : Transport
# C180CPT1 : Miscellaneous
# C180CPT2 : Miscellaneous
# C180CRNt : Transport
# C181CPT1 : Miscellaneous
# C181CPT2 : Miscellaneous
# C181CRNt : Transport
# C204CPT1 : Miscellaneous
# C204CPT2 : Miscellaneous
# C204CRNt : Transport
# CRVNCOAtx : Transport
# C226CPT1 : Miscellaneous
# C226CPT2 : Miscellaneous
# C226CRNt : Transport
# C2tcx : Transport
# C30CPT1 : Miscellaneous
# C3STDH1Pr : Bile, eicosanoid and steroid metabolism
# C3STDH1r : Bile, eicosanoid and steroid metabolism
# C3STKR2r : Bile, eicosanoid and steroid metabolism
# C40CPT1 : Miscellaneous
# C4CRNCPT2 : Miscellaneous
# C4CRNe : Transport
# C4DCCACT : Transport
# C4DCe : Transport
# C4OHc : Miscellaneous
# C4STMO1r : Bile, eicosanoid and steroid metabolism
# C4STMO2Pr : Bile, eicosanoid and steroid metabolism
# C4STMO2r : Bile, eicosanoid and steroid metabolism
# C4tmc : Transport
# C50CPT1 : Miscellaneous
# C51CPT1 : Miscellaneous
# C6DCc : Miscellaneous
# C6DCCACT : Transport
# C6DCe : Transport
# C80CPT1 : Miscellaneous
# C81_5ZCPT2m : Miscellaneous
# C81_5ZCPTx : Miscellaneous
# C81CRNtm : Transport
# C81CRNtx : Transport
# C8CRNe : Transport
# C8CRNt : Transport
# C8DCc : Miscellaneous
# C8DCe : Transport
# C9BRxtc : Transport
# CAATPaser : Transport
# CAATPS : Transport
# CACNAO : Other carbon metabolism
# CACNAO2 : Other carbon metabolism
# CAMPt : Transport
# CARhPTtc : Transport
# CARNS1 : Miscellaneous
# CAROtr : Transport
# CARPEPT1tc : Transport
# CARVEOLte : Transport
# CAT : Unassigned
# CAT2p : Central carbon and energy metabolism
# CAt7r : Transport
# CATm : Unassigned
# CATp : Unassigned
# CBASPte : Transport
# CBL2OR : Vitamin and cofactor metabolism
# CBL2tm : Transport
# CBL1tm : Transport
# ADOCBLtm : Transport
# CBLATm : Vitamin and cofactor metabolism
# CBLTDe : Transport
# CBPPer : Central carbon and energy metabolism
# CBPS : Nucelotide metabolism
# CBPSam : Amino acid metabolism
# CBPter : Transport
# CBR1 : Bile, eicosanoid and steroid metabolism
# CBR2 : Bile, eicosanoid and steroid metabolism
# CCA_D3t : Transport
# CCA_D3tm : Transport
# CDIPTr : Glycerophospholipid, sphingolipid and inositol metabolism
# CDPDAGtm : Transport
# CDS : Glycerophospholipid, sphingolipid and inositol metabolism
# CDSm : Glycerophospholipid, sphingolipid and inositol metabolism
# CEPTC : Glycerophospholipid, sphingolipid and inositol metabolism
# CEPTE : Glycerophospholipid, sphingolipid and inositol metabolism
# CERK : Glycerophospholipid, sphingolipid and inositol metabolism
# CERT1gt : Transport
# CERT1rt : Transport
# CERT2gt : Transport
# CERT2rt : Transport
# CGLYt3_2_ : Transport
# CGMPt : Transport
# CH25H : Bile, eicosanoid and steroid metabolism
# CHAT : Glycerophospholipid, sphingolipid and inositol metabolism
# CHATn : Glycerophospholipid, sphingolipid and inositol metabolism
# CHLP : Glycerophospholipid, sphingolipid and inositol metabolism
# CHLPCTD : Glycerophospholipid, sphingolipid and inositol metabolism
# CHLtm : Transport
# CHOLATEt : Transport
# CHOLATEt2 : Transport
# CHOLATEt3 : Transport
# CHOLD2m : Amino acid metabolism
# CHOLESACATc : Bile, eicosanoid and steroid metabolism
# CHOLESTle : Transport
# CHOLESTTDe : Transport
# CHOLK : Glycerophospholipid, sphingolipid and inositol metabolism
# CHOLPtg : Transport
# CHOLPtl : Transport
# CHOLt4 : Transport
# CHOLtg : Transport
# CHOLtn : Transport
# CHOLtr : Transport
# CHOLtu : Transport
# CHSTEROLSULT : Bile, eicosanoid and steroid metabolism
# CHSTEROLt : Transport
# CHSTEROLt1 : Transport
# CHSTEROLt2 : Transport
# CHSTEROLt3 : Transport
# CHSTEROLtg : Transport
# CHSTEROLtrc : Transport
# CHTNASE : Other carbon metabolism
# CHTNASEe : Other carbon metabolism
# CITMCOAHm : Other carbon metabolism
# CITMCOALm : Other carbon metabolism
# CITRt2m : Transport
# CITRtm : Transport
# CITt4_2 : Transport
# CITt4_3 : Transport
# CITt4_4 : Transport
# CITtam : Transport
# CITtbm : Transport
# CK : Miscellaneous
# CKc : Miscellaneous
# CLFORtex : Transport
# CLFORtex2 : Transport
# CLHCO3tex2 : Transport
# CLHCOtex : Transport
# CLI2tex : Transport
# CLOHtex2 : Transport
# CLOXAtex2 : Transport
# CLPNDCOAtbc : Transport
# CLPNDCPT1 : Miscellaneous
# CLPNDCPT2 : Miscellaneous
# CLPNDCRNt : Transport
# CLPNDt : Transport
# CLS_cho : Glycerophospholipid, sphingolipid and inositol metabolism
# CMPACNAtg : Transport
# CMPACNAtn : Transport
# CMPSAS : Other carbon metabolism
# CMPSASn : Other carbon metabolism
# CO2t : Transport
# CO2ter : Transport
# CO2tg : Transport
# CO2tm : Transport
# CO2tp : Transport
# COAtg : Transport
# COAtl : Transport
# COAtm : Transport
# COAtn : Transport
# COAtp : Transport
# COAtr : Transport
# COKECBESr : Miscellaneous
# COQ3m : Vitamin and cofactor metabolism
# COQ5m : Vitamin and cofactor metabolism
# COQ6m : Vitamin and cofactor metabolism
# COQ7m : Vitamin and cofactor metabolism
# Coqe : Transport
# CORE2GTg : Glycan and glycosaminoglycan metabolism
# CORE3GTg : Glycan and glycosaminoglycan metabolism
# CORE4GTg : Glycan and glycosaminoglycan metabolism
# CORE5GTg : Glycan and glycosaminoglycan metabolism
# CORE6GTg : Glycan and glycosaminoglycan metabolism
# CORE7GTg : Glycan and glycosaminoglycan metabolism
# CORE8GTg : Glycan and glycosaminoglycan metabolism
# COt : Transport
# COUCOAFm : Vitamin and cofactor metabolism
# COUMARINte : Transport
# CPPPGO : Miscellaneous
# CREATt4_2_r : Transport
# CREATtmdiffir : Miscellaneous
# CRMPte : Transport
# CRNCAR3tp : Transport
# CRNCARtp : Transport
# CRNrtx : Transport
# CRNt : Transport
# CRNtHa : Transport
# CRNtim : Transport
# CRNtuNa : Transport
# CRTNsyn : Miscellaneous
# CRTSLt : Transport
# CRTSLtm : Transport
# CRTSLtr : Transport
# CRTSTRNt : Transport
# CRTSTRNtm : Transport
# CRVNCtr : Transport
# CSAPASEly : Glycan and glycosaminoglycan metabolism
# CSBPASEly : Glycan and glycosaminoglycan metabolism
# CSCPASEly : Glycan and glycosaminoglycan metabolism
# CSDPASEly : Glycan and glycosaminoglycan metabolism
# CSEPASEly : Glycan and glycosaminoglycan metabolism
# CSm : Central carbon and energy metabolism
# CSNAT2m : Miscellaneous
# CSNAT2x : Miscellaneous
# CSNAT3x : Miscellaneous
# CSNATer : Miscellaneous
# CSNATm : Miscellaneous
# CSNATp : Miscellaneous
# CSNATr : Miscellaneous
# CSND : Nucelotide metabolism
# CSNt : Transport
# CSPG_At : Transport
# CSPG_Atly : Transport
# CSPG_Bt : Transport
# CSPG_Btly : Transport
# CSPG_Ct : Transport
# CSPG_Ctly : Transport
# CSPG_Dt : Transport
# CSPG_Dtly : Transport
# CSPG_Et : Transport
# CSPG_Etly : Transport
# CTPS2 : Nucelotide metabolism
# CTPtn : Transport
# CYANSTm : Miscellaneous
# CYANt : Transport
# CYANtm : Transport
# CYOOm2 : Central carbon and energy metabolism
# CYOOm3 : Central carbon and energy metabolism
# CYOR_u10m : Central carbon and energy metabolism
# CYP2R1 : Vitamin and cofactor metabolism
# CYSALANaEx : Transport
# CYSAMO : Vitamin and cofactor metabolism
# CYSASNNaEx : Transport
# CYSATB0tc : Transport
# CYSGLNNaEx : Transport
# CYSGLTH : Amino acid metabolism
# CYSGLUexR : Transport
# CYSGLYex : Transport
# CYSLYSL : Amino acid metabolism
# CYSO : Amino acid metabolism
# CYSPHELAT2tc : Transport
# CYSSERNaEx : Transport
# CYSSNAT5tc : Transport
# CYSt4 : Transport
# CYSTA : Amino acid metabolism
# CYSTALArBATtc : Transport
# CYSTAm : Amino acid metabolism
# CYStec : Transport
# CYSTGL : Amino acid metabolism
# CYSTGLUex : Transport
# CYSTHRNaEx : Transport
# CYSTLEUrBATtc : Transport
# CYSTS : Amino acid metabolism
# CYSTSERex : Transport
# CYTD : Nucelotide metabolism
# CYTDK1 : Nucelotide metabolism
# CYTDK2 : Nucelotide metabolism
# CYTDK2m : Nucelotide metabolism
# CYTDn : Nucelotide metabolism
# CYTDt : Transport
# CYTDt4 : Transport
# CYTDt5 : Transport
# CYTDtl : Transport
# CYTDtm : Transport
# CYTDtn : Transport
# CYTK1 : Nucelotide metabolism
# CYTK10 : Nucelotide metabolism
# CYTK10n : Nucelotide metabolism
# CYTK11 : Nucelotide metabolism
# CYTK11n : Nucelotide metabolism
# CYTK12 : Nucelotide metabolism
# CYTK12n : Nucelotide metabolism
# CYTK13 : Nucelotide metabolism
# CYTK13n : Nucelotide metabolism
# CYTK14 : Nucelotide metabolism
# CYTK14n : Nucelotide metabolism
# CYTK1m : Nucelotide metabolism
# CYTK1n : Nucelotide metabolism
# CYTK2 : Nucelotide metabolism
# CYTK2m : Nucelotide metabolism
# CYTK2n : Nucelotide metabolism
# CYTK3 : Nucelotide metabolism
# CYTK3n : Nucelotide metabolism
# CYTK4 : Nucelotide metabolism
# CYTK4n : Nucelotide metabolism
# CYTK5 : Nucelotide metabolism
# CYTK5n : Nucelotide metabolism
# CYTK6 : Nucelotide metabolism
# CYTK6n : Nucelotide metabolism
# CYTK7 : Nucelotide metabolism
# CYTK7n : Nucelotide metabolism
# CYTK8 : Nucelotide metabolism
# CYTK8n : Nucelotide metabolism
# CYTK9 : Nucelotide metabolism
# CYTK9n : Nucelotide metabolism
# D_3AIBt : Transport
# D_LACt2 : Transport
# D_LACtm : Transport
# D3AIBTm : Nucelotide metabolism
# DADA : Nucelotide metabolism
# DADAe : Nucelotide metabolism
# DADK1 : Nucelotide metabolism
# DADK3 : Nucelotide metabolism
# DADNK : Nucelotide metabolism
# DADNt4 : Transport
# DAG_HSter : Transport
# DAGK_cho : Glycerophospholipid, sphingolipid and inositol metabolism
# DAGKn_cho : Glycerophospholipid, sphingolipid and inositol metabolism
# DAGt : Transport
# DALAOXx : Miscellaneous
# DALAt2r : Transport
# DALAxt : Miscellaneous
# DARGOp : Amino acid metabolism
# DASCBH : Vitamin and cofactor metabolism
# DASCBR : Vitamin and cofactor metabolism
# DASPO1p : Amino acid metabolism
# DATPDP : Nucelotide metabolism
# DATPDPm : Nucelotide metabolism
# DATPDPn : Nucelotide metabolism
# DATPtm : Transport
# DATPtn : Transport
# DCATDc : Transport
# DCATDr : Transport
# DCK1i : Nucelotide metabolism
# DCK1mi : Nucelotide metabolism
# DCK1ni : Nucelotide metabolism
# DCK2ni : Nucelotide metabolism
# DCMPDA : Nucelotide metabolism
# DCSPTN1COAtx : Transport
# DCSPTN1COAtxc : Transport
# DCSPTN1CPT1 : Miscellaneous
# DCSPTN1CPT2 : Miscellaneous
# DCSPTN1CRNt : Transport
# DCSPTN1t : Transport
# DCT : Amino acid metabolism
# DCTPDP : Nucelotide metabolism
# DCTPDPm : Nucelotide metabolism
# DCTPDPn : Nucelotide metabolism
# DCTPtm : Transport
# DCTPtn : Transport
# DCYTD : Nucelotide metabolism
# DCYTDn : Nucelotide metabolism
# DCYTt : Transport
# DCYTtm : Transport
# DDCRNe : Transport
# DDPGAm : Amino acid metabolism
# DEBRISOQUINEt : Transport
# DECCRNe : Transport
# DECDPtm : Transport
# DEDOLP1 : Glycan and glycosaminoglycan metabolism
# DEDOLP2 : Glycan and glycosaminoglycan metabolism
# DEDOLR : Glycan and glycosaminoglycan metabolism
# DGAT : Glycerophospholipid, sphingolipid and inositol metabolism
# DGCHOLte : Transport
# DGCHOLtx : Transport
# DGK1i : Nucelotide metabolism
# DGK2mi : Nucelotide metabolism
# DGNSKm : Nucelotide metabolism
# DGSNt : Transport
# DGSNtm : Transport
# DGTPtm : Transport
# DGTPtn : Transport
# DGULND : Other carbon metabolism
# DHAAt1r : Transport
# DHAK : Glycerophospholipid, sphingolipid and inositol metabolism
# DHAPA : Glycerophospholipid, sphingolipid and inositol metabolism
# DHAPAx : Glycerophospholipid, sphingolipid and inositol metabolism
# DHAPtc : Transport
# DHCHOLESTANATEtm : Transport
# DHCR241r : Bile, eicosanoid and steroid metabolism
# DHCR242r : Bile, eicosanoid and steroid metabolism
# DHCR243r : Bile, eicosanoid and steroid metabolism
# DHCR71r : Bile, eicosanoid and steroid metabolism
# DHCR72r : Bile, eicosanoid and steroid metabolism
# DHCRD1 : Glycerophospholipid, sphingolipid and inositol metabolism
# DHCRD2 : Glycerophospholipid, sphingolipid and inositol metabolism
# DHDASCBtm : Transport
# DHDDH : Xenobiotics metabolism
# DHDDS : Glycan and glycosaminoglycan metabolism
# DHDPBMTm : Vitamin and cofactor metabolism
# DHEASt : Transport
# DHEAStr : Transport
# DHEASULT : Bile, eicosanoid and steroid metabolism
# DHEAtr : Transport
# DHFR : Vitamin and cofactor metabolism
# DHFtl : Transport
# DHFtm : Transport
# DHORD9 : Nucelotide metabolism
# DHORTS : Nucelotide metabolism
# DHPM1 : Nucelotide metabolism
# DHPM2 : Nucelotide metabolism
# DHPR : Miscellaneous
# DHPR2 : Miscellaneous
# DIDP : Nucelotide metabolism
# DIDPtn : Transport
# DIGALSGALSIDEte : Transport
# DIGALSGALSIDEtg : Transport
# DIGALSIDEtg : Transport
# DIGALSIDEtl : Transport
# DINt : Transport
# DITPtn : Transport
# DKMPPD2 : Amino acid metabolism
# DLNLCGCPT1 : Miscellaneous
# DLNLCGCPT2 : Miscellaneous
# DLNLCGCRNt : Transport
# DLNLCGt : Transport
# DM_13_cis_oretn[n] : Exchange/demand/sink reaction
# DM_13_cis_retn[n] : Exchange/demand/sink reaction
# DM_56iqcrbxlt[c] : Exchange/demand/sink reaction
# DM_Asn_X_Ser/Thr[ly] : Exchange/demand/sink reaction
# DM_atp[c] : Exchange/demand/sink reaction
# DM_avite1[c] : Exchange/demand/sink reaction
# DM_core5[g] : Exchange/demand/sink reaction
# DM_core7[g] : Exchange/demand/sink reaction
# DM_core8[g] : Exchange/demand/sink reaction
# DM_datp[m] : Exchange/demand/sink reaction
# DM_datp[n] : Exchange/demand/sink reaction
# DM_dctp[m] : Exchange/demand/sink reaction
# DM_dctp[n] : Exchange/demand/sink reaction
# DM_dem2emgacpail_prot_cho[r] : Exchange/demand/sink reaction
# DM_dgpi_prot_cho[r] : Exchange/demand/sink reaction
# DM_dgtp[m] : Exchange/demand/sink reaction
# DM_dgtp[n] : Exchange/demand/sink reaction
# DM_dsT_antigen[g] : Exchange/demand/sink reaction
# DM_dttp[m] : Exchange/demand/sink reaction
# DM_dttp[n] : Exchange/demand/sink reaction
# DM_epo[g] : Exchange/demand/sink reaction
# DM_ethamp[r] : Exchange/demand/sink reaction
# DM_gncore2[g] : Exchange/demand/sink reaction
# DM_gpi_sig[er] : Exchange/demand/sink reaction
# DM_hretn[n] : Exchange/demand/sink reaction
# DM_igg[g] : Exchange/demand/sink reaction
# DM_kdn[c] : Exchange/demand/sink reaction
# DM_n5m2masn[g] : Exchange/demand/sink reaction
# DM_oretn[n] : Exchange/demand/sink reaction
# DM_Ser/Thr[ly] : Exchange/demand/sink reaction
# DM_Ser_Gly/Ala_X_Gly[ly] : Exchange/demand/sink reaction
# DM_sprm[c] : Exchange/demand/sink reaction
# DM_sTn_antigen[g] : Exchange/demand/sink reaction
# DM_T_antigen[g] : Exchange/demand/sink reaction
# DMANTIPYRINEte : Transport
# DMARG : Unassigned
# DMATTx : Bile, eicosanoid and steroid metabolism
# DMGDHm : Amino acid metabolism
# DMGtm : Transport
# DMHPTCRNCPT1 : Miscellaneous
# DMHPTCRNCPT2 : Miscellaneous
# DMHPTCRNt : Transport
# DMHPTCRNte : Transport
# DMNONCOACRNCPT1 : Miscellaneous
# DMNONCRNCPT2 : Miscellaneous
# DMNONCRNt : Transport
# DNADDP : Vitamin and cofactor metabolism
# DNADtn : Transport
# DNAMTn : Amino acid metabolism
# DNAMTSEn : Miscellaneous
# DNDPt10m : Transport
# DNDPt11m : Transport
# DNDPt12m : Transport
# DNDPt13m : Transport
# DNDPt14m : Transport
# DNDPt15m : Transport
# DNDPt17m : Transport
# DNDPt18m : Transport
# DNDPt19m : Transport
# DNDPt1m : Transport
# DNDPt20m : Transport
# DNDPt21m : Transport
# DNDPt23m : Transport
# DNDPt25m : Transport
# DNDPt28m : Transport
# DNDPt2m : Transport
# DNDPt30m : Transport
# DNDPt31m : Transport
# DNDPt32m : Transport
# DNDPt37m : Transport
# DNDPt38m : Transport
# DNDPt39m : Transport
# DNDPt3m : Transport
# DNDPt40m : Transport
# DNDPt41m : Transport
# DNDPt42m : Transport
# DNDPt43m : Transport
# DNDPt44m : Transport
# DNDPt45m : Transport
# DNDPt46m : Transport
# DNDPt47m : Transport
# DNDPt48m : Transport
# DNDPt49m : Transport
# DNDPt4m : Transport
# DNDPt50m : Transport
# DNDPt51m : Transport
# DNDPt52m : Transport
# DNDPt53m : Transport
# DNDPt54m : Transport
# DNDPt55m : Transport
# DNDPt56m : Transport
# DNDPt57m : Transport
# DNDPt58m : Transport
# DNDPt59m : Transport
# DNDPt5m : Transport
# DNDPt60m : Transport
# DNDPt61m : Transport
# DNDPt62m : Transport
# DNDPt63m : Transport
# DNDPt6m : Transport
# DNDPt7m : Transport
# DNDPt8m : Transport
# DNDPt9m : Transport
# DNTP : Nucelotide metabolism
# DOCOSACTDe : Transport
# DOCOSCOAtxc : Transport
# DOGULND1 : Vitamin and cofactor metabolism
# DOGULND2 : Vitamin and cofactor metabolism
# DOGULNO1 : Vitamin and cofactor metabolism
# DOGULNO2 : Vitamin and cofactor metabolism
# DOLASNTer : Glycan and glycosaminoglycan metabolism
# DOLDPPer : Glycan and glycosaminoglycan metabolism
# DOLGLCP_ter : Glycan and glycosaminoglycan metabolism
# DOLGPP_er : Glycan and glycosaminoglycan metabolism
# DOLICHOL_ter : Glycan and glycosaminoglycan metabolism
# DOLK : Glycan and glycosaminoglycan metabolism
# DOLMANP_ter : Glycan and glycosaminoglycan metabolism
# DOLP_ter : Glycan and glycosaminoglycan metabolism
# DOLPGT1er : Glycan and glycosaminoglycan metabolism
# DOLPGT2er : Glycan and glycosaminoglycan metabolism
# DOLPGT3er : Glycan and glycosaminoglycan metabolism
# DOLPH_er : Glycan and glycosaminoglycan metabolism
# DOLPMT : Glycan and glycosaminoglycan metabolism
# DOLPMT1er : Glycan and glycosaminoglycan metabolism
# DOLPMT2_er : Glycan and glycosaminoglycan metabolism
# DOLPMT3er : Glycan and glycosaminoglycan metabolism
# DOLPMT4_er : Glycan and glycosaminoglycan metabolism
# DOPABMO : Amino acid metabolism
# DOPACHRMISO : Amino acid metabolism
# DOPAMT : Amino acid metabolism
# DOPAQNISO1 : Amino acid metabolism
# DOPASFt : Transport
# DOPASULT : Amino acid metabolism
# DOPAt4_2_r : Transport
# DOPAtu : Transport
# DOPAVESSEC : Transport
# DORNOp : Amino acid metabolism
# DPCOAK : Vitamin and cofactor metabolism
# DPCOAPP : Vitamin and cofactor metabolism
# DPGase : Central carbon and energy metabolism
# DPGM : Central carbon and energy metabolism
# DPHMBDCm : Vitamin and cofactor metabolism
# DPMVDc : Bile, eicosanoid and steroid metabolism
# DPMVDx : Bile, eicosanoid and steroid metabolism
# DPPS : Vitamin and cofactor metabolism
# DPROOp : Amino acid metabolism
# DRBK : Central carbon and energy metabolism
# DRIBt : Transport
# DRPA : Central carbon and energy metabolism
# DSAT : Glycerophospholipid, sphingolipid and inositol metabolism
# DTDPtn : Transport
# DTMPK : Nucelotide metabolism
# DTMPKm : Nucelotide metabolism
# DTTPDP : Nucelotide metabolism
# DTTPDPm : Nucelotide metabolism
# DTTPDPn : Nucelotide metabolism
# DTTPtm : Transport
# DTTPtn : Transport
# DUDPtn : Transport
# DUMPtn : Transport
# DURAD : Nucelotide metabolism
# DURAD2 : Nucelotide metabolism
# DURIK1 : Nucelotide metabolism
# DURIK1m : Nucelotide metabolism
# DURIPP : Nucelotide metabolism
# DURIt : Transport
# DURItn : Transport
# DUTPDP : Nucelotide metabolism
# DUTPDPm : Nucelotide metabolism
# DUTPDPn : Nucelotide metabolism
# EAFLATOXINte : Transport
# EBASTINEOHte : Transport
# EBASTINEOHtr : Transport
# EBASTINEte : Transport
# EBASTINEtr : Transport
# EBP1r : Bile, eicosanoid and steroid metabolism
# EBP2r : Bile, eicosanoid and steroid metabolism
# ECGISOr : Miscellaneous
# ECOAH12m : Amino acid metabolism
# ECOAH1m : Amino acid metabolism
# ECOAH1p : Amino acid metabolism
# ECOAH9m : Amino acid metabolism
# EGMESTr : Miscellaneous
# EHGLAT : Amino acid metabolism
# EHGLAT2m : Amino acid metabolism
# EHGLATm : Amino acid metabolism
# EICOSTETCPT1 : Miscellaneous
# EICOSTETCPT2 : Miscellaneous
# EICOSTETCRNt : Transport
# EICOSTETt : Transport
# ELAIDCPT1 : Miscellaneous
# ELAIDCPT2 : Miscellaneous
# ELAIDCRNt : Transport
# ELAIDt : Transport
# ENGASE : Glycan and glycosaminoglycan metabolism
# ENGASE2 : Glycan and glycosaminoglycan metabolism
# ENGASE2ly : Glycan and glycosaminoglycan metabolism
# ENGASE3ly : Glycan and glycosaminoglycan metabolism
# ENGASEly : Glycan and glycosaminoglycan metabolism
# ENMAN1g : Glycan and glycosaminoglycan metabolism
# ENMAN2g : Glycan and glycosaminoglycan metabolism
# ENMAN3g : Glycan and glycosaminoglycan metabolism
# ENMAN4g : Glycan and glycosaminoglycan metabolism
# ENMAN5g : Glycan and glycosaminoglycan metabolism
# ENMAN6g : Glycan and glycosaminoglycan metabolism
# ENO : Central carbon and energy metabolism
# EPCTX : Glycerophospholipid, sphingolipid and inositol metabolism
# epo_degradation : Miscellaneous
# epo_processing : Miscellaneous
# epo_translation : Miscellaneous
# EPOH : Xenobiotics metabolism
# ESTRADIOLGLCt : Transport
# ESTRADIOLGLCtabc : Transport
# ESTRADIOLGLCtr : Transport
# ESTRADIOLt : Transport
# ESTRADIOLtr : Transport
# ESTRIOLGLCte : Transport
# ESTRIOLGLCtr : Transport
# ESTRIOLtr : Transport
# ESTRONEGLCt : Transport
# ESTRONEGLCtr : Transport
# ESTRONESt : Transport
# ESTRONESt2 : Transport
# ESTRONEtr : Transport
# ESTSULT : Bile, eicosanoid and steroid metabolism
# ETF : Miscellaneous
# ETFQO : Miscellaneous
# ETHAK : Glycerophospholipid, sphingolipid and inositol metabolism
# ETHP : Glycerophospholipid, sphingolipid and inositol metabolism
# ETOHMO : Other carbon metabolism
# ETOHt : Transport
# ETOHtx : Transport
# EX_10fthf(e) : Exchange/demand/sink reaction
# EX_10fthf5glu(e) : Exchange/demand/sink reaction
# EX_10fthf6glu(e) : Exchange/demand/sink reaction
# EX_10fthf7glu(e) : Exchange/demand/sink reaction
# EX_11_cis_retfa(e) : Exchange/demand/sink reaction
# EX_13_cis_retnglc(e) : Exchange/demand/sink reaction
# EX_1glyc_cho(e) : Exchange/demand/sink reaction
# EX_1mncam(e) : Exchange/demand/sink reaction
# EX_23cump(e) : Exchange/demand/sink reaction
# EX_2425dhvitd2(e) : Exchange/demand/sink reaction
# EX_2425dhvitd3(e) : Exchange/demand/sink reaction
# EX_24nph(e) : Exchange/demand/sink reaction
# EX_25hvitd2(e) : Exchange/demand/sink reaction
# EX_25hvitd3(e) : Exchange/demand/sink reaction
# EX_2hb(e) : Exchange/demand/sink reaction
# EX_2mcit(e) : Exchange/demand/sink reaction
# EX_34dhoxpeg(e) : Exchange/demand/sink reaction
# EX_34dhphe(e) : Exchange/demand/sink reaction
# EX_34hpp : Exchange/demand/sink reaction
# EX_35cgmp(e) : Exchange/demand/sink reaction
# EX_3aib_D(e) : Exchange/demand/sink reaction
# EX_3aib(e) : Exchange/demand/sink reaction
# EX_3bcrn : Exchange/demand/sink reaction
# EX_3ddcrn : Exchange/demand/sink reaction
# EX_3deccrn : Exchange/demand/sink reaction
# EX_3mlda(e) : Exchange/demand/sink reaction
# EX_3mob(e) : Exchange/demand/sink reaction
# EX_3mop(e) : Exchange/demand/sink reaction
# EX_3tdcrn : Exchange/demand/sink reaction
# EX_3ump(e) : Exchange/demand/sink reaction
# EX_4abut(e) : Exchange/demand/sink reaction
# EX_4abutn(e) : Exchange/demand/sink reaction
# EX_4hdebrisoquine(e) : Exchange/demand/sink reaction
# EX_4hphac(e) : Exchange/demand/sink reaction
# EX_4hpro(e) : Exchange/demand/sink reaction
# EX_4mop(e) : Exchange/demand/sink reaction
# EX_4mptnl(e) : Exchange/demand/sink reaction
# EX_4mtolbutamide(e) : Exchange/demand/sink reaction
# EX_4nph(e) : Exchange/demand/sink reaction
# EX_4nphsf(e) : Exchange/demand/sink reaction
# EX_4pyrdx(e) : Exchange/demand/sink reaction
# EX_5adtststerone(e) : Exchange/demand/sink reaction
# EX_5adtststeroneglc(e) : Exchange/demand/sink reaction
# EX_5adtststerones(e) : Exchange/demand/sink reaction
# EX_5dhf(e) : Exchange/demand/sink reaction
# EX_5fthf(e) : Exchange/demand/sink reaction
# EX_5homeprazole(e) : Exchange/demand/sink reaction
# EX_5htrp(e) : Exchange/demand/sink reaction
# EX_5mta(e) : Exchange/demand/sink reaction
# EX_5mthf(e) : Exchange/demand/sink reaction
# EX_5oxpro(e) : Exchange/demand/sink reaction
# EX_5thf(e) : Exchange/demand/sink reaction
# EX_6dhf(e) : Exchange/demand/sink reaction
# EX_6htststerone(e) : Exchange/demand/sink reaction
# EX_6thf(e) : Exchange/demand/sink reaction
# EX_7dhf(e) : Exchange/demand/sink reaction
# EX_7thf(e) : Exchange/demand/sink reaction
# EX_9_cis_retfa(e) : Exchange/demand/sink reaction
# EX_abt(e) : Exchange/demand/sink reaction
# EX_ac(e) : Exchange/demand/sink reaction
# EX_acac(e) : Exchange/demand/sink reaction
# EX_acald(e) : Exchange/demand/sink reaction
# EX_acetone(e) : Exchange/demand/sink reaction
# EX_acgalfucgalacgalfuc12gal14acglcgalgluside_cho(e) : Exchange/demand/sink reaction
# EX_acgalfucgalacgalfucgalacglcgal14acglcgalgluside_cho(e) : Exchange/demand/sink reaction
# EX_acgam(e) : Exchange/demand/sink reaction
# EX_ach(e) : Exchange/demand/sink reaction
# EX_acmana(e) : Exchange/demand/sink reaction
# EX_acn13acngalgbside_cho(e) : Exchange/demand/sink reaction
# EX_acn23acngalgbside_cho(e) : Exchange/demand/sink reaction
# EX_acnacngal14acglcgalgluside_cho(e) : Exchange/demand/sink reaction
# EX_acnacngalgbside_cho(e) : Exchange/demand/sink reaction
# EX_acngalacglcgal14acglcgalgluside_cho(e) : Exchange/demand/sink reaction
# EX_ade(e) : Exchange/demand/sink reaction
# EX_adn(e) : Exchange/demand/sink reaction
# EX_adp : Exchange/demand/sink reaction
# EX_adpcbl(e) : Exchange/demand/sink reaction
# EX_adprbp(e) : Exchange/demand/sink reaction
# EX_adprib(e) : Exchange/demand/sink reaction
# EX_adrn(e) : Exchange/demand/sink reaction
# EX_adrnl(e) : Exchange/demand/sink reaction
# EX_aflatoxin(e) : Exchange/demand/sink reaction
# EX_ahandrostanglc(e) : Exchange/demand/sink reaction
# EX_ahcys(e) : Exchange/demand/sink reaction
# EX_ahdt(e) : Exchange/demand/sink reaction
# EX_aicar(e) : Exchange/demand/sink reaction
# EX_ak2lgchol_cho(e) : Exchange/demand/sink reaction
# EX_akg(e) : Exchange/demand/sink reaction
# EX_ala_B(e) : Exchange/demand/sink reaction
# EX_ala_D(e) : Exchange/demand/sink reaction
# EX_ala_L(e) : Exchange/demand/sink reaction
# EX_alaala(e) : Exchange/demand/sink reaction
# EX_aldstrn(e) : Exchange/demand/sink reaction
# EX_amp(e) : Exchange/demand/sink reaction
# EX_andrstrn(e) : Exchange/demand/sink reaction
# EX_andrstrnglc(e) : Exchange/demand/sink reaction
# EX_anth(e) : Exchange/demand/sink reaction
# EX_antipyrene(e) : Exchange/demand/sink reaction
# EX_apnnox(e) : Exchange/demand/sink reaction
# EX_appnn(e) : Exchange/demand/sink reaction
# EX_aprgstrn(e) : Exchange/demand/sink reaction
# EX_aqcobal(e) : Exchange/demand/sink reaction
# EX_arab_L(e) : Exchange/demand/sink reaction
# EX_arach(e) : Exchange/demand/sink reaction
# EX_arachd(e) : Exchange/demand/sink reaction
# EX_arg_L(e) : Exchange/demand/sink reaction
# EX_ascb_L(e) : Exchange/demand/sink reaction
# EX_asn_L(e) : Exchange/demand/sink reaction
# EX_asp_D(e) : Exchange/demand/sink reaction
# EX_asp_L(e) : Exchange/demand/sink reaction
# EX_atp(e) : Exchange/demand/sink reaction
# EX_avite1(e) : Exchange/demand/sink reaction
# EX_bhb(e) : Exchange/demand/sink reaction
# EX_bildglcur(e) : Exchange/demand/sink reaction
# EX_bilglcur(e) : Exchange/demand/sink reaction
# EX_bilirub(e) : Exchange/demand/sink reaction
# EX_biocyt(e) : Exchange/demand/sink reaction
# EX_btn(e) : Exchange/demand/sink reaction
# EX_but(e) : Exchange/demand/sink reaction
# EX_bz(e) : Exchange/demand/sink reaction
# EX_xanta(e) : Exchange/demand/sink reaction
# EX_cdchac(e) : Exchange/demand/sink reaction
# EX_c10dc : Exchange/demand/sink reaction
# EX_c4crn : Exchange/demand/sink reaction
# EX_c4dc : Exchange/demand/sink reaction
# EX_c51crn : Exchange/demand/sink reaction
# EX_c6dc : Exchange/demand/sink reaction
# EX_c8crn : Exchange/demand/sink reaction
# EX_c8dc : Exchange/demand/sink reaction
# EX_ca2(e) : Exchange/demand/sink reaction
# EX_camp(e) : Exchange/demand/sink reaction
# EX_carn(e) : Exchange/demand/sink reaction
# EX_caro(e) : Exchange/demand/sink reaction
# EX_carveol(e) : Exchange/demand/sink reaction
# EX_cbasp(e) : Exchange/demand/sink reaction
# EX_cca_d3(e) : Exchange/demand/sink reaction
# EX_cdp(e) : Exchange/demand/sink reaction
# EX_cgly(e) : Exchange/demand/sink reaction
# EX_chol(e) : Exchange/demand/sink reaction
# EX_cholate(e) : Exchange/demand/sink reaction
# EX_chopg(e) : Exchange/demand/sink reaction
# EX_chsterol(e) : Exchange/demand/sink reaction
# EX_chtn(e) : Exchange/demand/sink reaction
# EX_cit(e) : Exchange/demand/sink reaction
# EX_citr_L(e) : Exchange/demand/sink reaction
# EX_cl(e) : Exchange/demand/sink reaction
# EX_clpnd(e) : Exchange/demand/sink reaction
# EX_cmp(e) : Exchange/demand/sink reaction
# EX_co(e) : Exchange/demand/sink reaction
# EX_co2(e) : Exchange/demand/sink reaction
# EX_coumarin(e) : Exchange/demand/sink reaction
# EX_creat(e) : Exchange/demand/sink reaction
# EX_crm_cho(e) : Exchange/demand/sink reaction
# EX_crmp_cho(e) : Exchange/demand/sink reaction
# EX_crn(e) : Exchange/demand/sink reaction
# EX_crtsl(e) : Exchange/demand/sink reaction
# EX_crtstrn(e) : Exchange/demand/sink reaction
# EX_crvnc(e) : Exchange/demand/sink reaction
# EX_csn(e) : Exchange/demand/sink reaction
# EX_cspg_a(e) : Exchange/demand/sink reaction
# EX_cspg_b(e) : Exchange/demand/sink reaction
# EX_cspg_c(e) : Exchange/demand/sink reaction
# EX_cspg_d(e) : Exchange/demand/sink reaction
# EX_cspg(e)e_ : Exchange/demand/sink reaction
# EX_ctp(e) : Exchange/demand/sink reaction
# EX_cyan(e) : Exchange/demand/sink reaction
# EX_cys_L(e) : Exchange/demand/sink reaction
# EX_cytd(e) : Exchange/demand/sink reaction
# EX_dad_2(e) : Exchange/demand/sink reaction
# EX_dag_cho(e) : Exchange/demand/sink reaction
# EX_dca(e) : Exchange/demand/sink reaction
# EX_dcsptn1(e) : Exchange/demand/sink reaction
# EX_dcyt(e) : Exchange/demand/sink reaction
# EX_debrisoquine(e) : Exchange/demand/sink reaction
# EX_dgchol(e) : Exchange/demand/sink reaction
# EX_dgmp(e) : Exchange/demand/sink reaction
# EX_dgsn(e) : Exchange/demand/sink reaction
# EX_dgtp(e) : Exchange/demand/sink reaction
# EX_dha(e) : Exchange/demand/sink reaction
# EX_dhap(e) : Exchange/demand/sink reaction
# EX_dhdascb(e) : Exchange/demand/sink reaction
# EX_dheas(e) : Exchange/demand/sink reaction
# EX_dhf(e) : Exchange/demand/sink reaction
# EX_digalsgalside_cho(e) : Exchange/demand/sink reaction
# EX_din(e) : Exchange/demand/sink reaction
# EX_dlnlcg(e) : Exchange/demand/sink reaction
# EX_dmantipyrine(e) : Exchange/demand/sink reaction
# EX_dmhptcrn(e) : Exchange/demand/sink reaction
# EX_docosac : Exchange/demand/sink reaction
# EX_dopa(e) : Exchange/demand/sink reaction
# EX_dopasf(e) : Exchange/demand/sink reaction
# EX_drib(e) : Exchange/demand/sink reaction
# EX_dtdp(e) : Exchange/demand/sink reaction
# EX_dtmp(e) : Exchange/demand/sink reaction
# EX_dttp(e) : Exchange/demand/sink reaction
# EX_duri(e) : Exchange/demand/sink reaction
# EX_eaflatoxin(e) : Exchange/demand/sink reaction
# EX_ebastine(e) : Exchange/demand/sink reaction
# EX_ebastineoh(e) : Exchange/demand/sink reaction
# EX_eicostet(e) : Exchange/demand/sink reaction
# EX_elaid(e) : Exchange/demand/sink reaction
# EX_estradiol(e) : Exchange/demand/sink reaction
# EX_estradiolglc(e) : Exchange/demand/sink reaction
# EX_estriolglc(e) : Exchange/demand/sink reaction
# EX_estroneglc(e) : Exchange/demand/sink reaction
# EX_estrones(e) : Exchange/demand/sink reaction
# EX_etoh(e) : Exchange/demand/sink reaction
# EX_fad(e) : Exchange/demand/sink reaction
# EX_fald(e) : Exchange/demand/sink reaction
# EX_fe2(e) : Exchange/demand/sink reaction
# EX_fe3(e) : Exchange/demand/sink reaction
# EX_fmn(e) : Exchange/demand/sink reaction
# EX_fol(e) : Exchange/demand/sink reaction
# EX_for(e) : Exchange/demand/sink reaction
# EX_fru(e) : Exchange/demand/sink reaction
# EX_fuc_L(e) : Exchange/demand/sink reaction
# EX_fuc13galacglcgal14acglcgalgluside_cho(e) : Exchange/demand/sink reaction
# EX_fuc14galacglcgalgluside_cho(e) : Exchange/demand/sink reaction
# EX_fucacgalfucgalacglcgalgluside_cho(e) : Exchange/demand/sink reaction
# EX_fucacngal14acglcgalgluside_cho(e) : Exchange/demand/sink reaction
# EX_fucacngalacglcgalgluside_cho(e) : Exchange/demand/sink reaction
# EX_fucfuc12gal14acglcgalgluside_cho(e) : Exchange/demand/sink reaction
# EX_fucfuc132galacglcgal14acglcgalgluside_cho(e) : Exchange/demand/sink reaction
# ...
# LPGAT : Glycerophospholipid, sphingolipid and inositol metabolism
# MLCLAT : Glycerophospholipid, sphingolipid and inositol metabolism
# DLCLAT : Glycerophospholipid, sphingolipid and inositol metabolism
# CRTNte : Transport
# RETMO : Vitamin and cofactor metabolism
# LTB4DH : Bile, eicosanoid and steroid metabolism
# 15KPROSTGF2c : Bile, eicosanoid and steroid metabolism
# 15KPROSTGF2t : Transport
# EX_15KPROSTGF2 : Exchange/demand/sink reaction
# EX_crtn(e) : Exchange/demand/sink reaction
# EX_trypta(e) : Exchange/demand/sink reaction
# EX_tym(e) : Exchange/demand/sink reaction
# EX_doco13ac(e) : Exchange/demand/sink reaction
# DAG_Hstem : Transport
# AGK : Glycerophospholipid, sphingolipid and inositol metabolism
# ACGAMtg : Transport
# SK_Ser_Gly_Ala_X_Gly_ER : Exchange/demand/sink reaction
# WHTSTSTERONEtr : Transport
# UMPtn : Transport
# BILGLCURtr : Transport
# TRDOXtm : Transport
# TETPENT6COAtr : Transport
# SLDtm : Amino acid metabolism
# FALDtx : Transport
# PROSTE3S : Bile, eicosanoid and steroid metabolism
# PRSOTGEPS : Bile, eicosanoid and steroid metabolism
# PROSTA1I : Bile, eicosanoid and steroid metabolism
# PROSTC1I : Bile, eicosanoid and steroid metabolism
# PROSTA2I : Bile, eicosanoid and steroid metabolism
# PROSTC2I : Bile, eicosanoid and steroid metabolism
# PROSTE1S : Bile, eicosanoid and steroid metabolism
# PROSTE2S : Bile, eicosanoid and steroid metabolism
# THYRDI : Amino acid metabolism
# THYRDI2 : Amino acid metabolism
# TRITHYRSULFO : Amino acid metabolism
# TIDSSULF : Amino acid metabolism
# DITHYRSULFO : Amino acid metabolism
# THYRIDHD : Amino acid metabolism
# TXB2r : Bile, eicosanoid and steroid metabolism
# TXB2tr : Transport
# TXB2DH : Bile, eicosanoid and steroid metabolism
# TXB2c : Bile, eicosanoid and steroid metabolism
# TXB2t : Transport
# WHARACHDtr : Transport
# THCHOLSTOICATP : Transport
# THCHOLSTOICt : Transport
# EX_thcholstoic[e] : Exchange/demand/sink reaction
# DHCHOLESTANATEATP : Transport
# DHCHOLESTANATEt : Transport
# EX_dhcholestanate(e) : Exchange/demand/sink reaction
# ACGAMtl : Transport
# DHRT_ibcoa : Amino acid metabolism
# 2HYOXPLCte : Transport
# EX_2hyoxplac(e) : Exchange/demand/sink reaction
# PHPYRtm : Transport
# PHEACGLYtm : Transport
# PHEACGLYte : Transport
# EX_pheacgly(e) : Exchange/demand/sink reaction
# ACGLUtm : Transport
# ACGLUte : Transport
# EX_acglu(e) : Exchange/demand/sink reaction
# ACORNt : Transport
# EX_acorn(e) : Exchange/demand/sink reaction
# HSD17B412x : Bile, eicosanoid and steroid metabolism
# DKMPPD1 : Amino acid metabolism
# EX_coke(e) : Exchange/demand/sink reaction
# COKEte : Transport
# COKEtr : Transport
# ARG_Dtx : Transport
# B3GNT33g : Glycerophospholipid, sphingolipid and inositol metabolism
# B3GNT32g : Glycerophospholipid, sphingolipid and inositol metabolism
# B3GNT31g : Glycerophospholipid, sphingolipid and inositol metabolism
# GALTt : Transport
# EX_galt(e) : Exchange/demand/sink reaction
# GLYCLTtm : Transport
# ASCBtr : Transport
# GLUTCOAm : Amino acid metabolism
# GDPFPOFTr : Glycan and glycosaminoglycan metabolism
# UPDGOFUCBGTr : Glycan and glycosaminoglycan metabolism
# FSERterg : Glycan and glycosaminoglycan metabolism
# OFPGLCNACTg : Glycan and glycosaminoglycan metabolism
# GNOFPGALTg : Glycan and glycosaminoglycan metabolism
# ST6GALGNFTg : Glycan and glycosaminoglycan metabolism
# POGLUTr : Glycan and glycosaminoglycan metabolism
# GXYLTr : Glycan and glycosaminoglycan metabolism
# DOLPOMTr : Glycan and glycosaminoglycan metabolism
# POMGNTr : Glycan and glycosaminoglycan metabolism
# POMGNGALNTr : Glycan and glycosaminoglycan metabolism
# POMKr : Glycan and glycosaminoglycan metabolism
# RBT5PDH : Central carbon and energy metabolism
# RBT5PCYTr : Glycan and glycosaminoglycan metabolism
# CDPRBTLtg : Transport
# PCOREM3terg : Glycan and glycosaminoglycan metabolism
# POCDPRBTLTg : Glycan and glycosaminoglycan metabolism
# POCDPRBTLT2g : Glycan and glycosaminoglycan metabolism
# POXYLTg : Glycan and glycosaminoglycan metabolism
# POGLCNACTg : Glycan and glycosaminoglycan metabolism
# LARGEg : Glycan and glycosaminoglycan metabolism
# MSERterg : Glycan and glycosaminoglycan metabolism
# POMGNT2g : Glycan and glycosaminoglycan metabolism
# GNOFGALTg : Glycan and glycosaminoglycan metabolism
# MNSERGALTg : Glycan and glycosaminoglycan metabolism
# GNOFPGALT2g : Glycan and glycosaminoglycan metabolism
# 3HPRODHx : Amino acid metabolism
# RETNDHT : Vitamin and cofactor metabolism
# LEUKTNAA : Bile, eicosanoid and steroid metabolism
# SPMDSH : Miscellaneous
# DHSPMDNABUT : Miscellaneous
# DHPS : Miscellaneous
# 4ABUTNDH : Miscellaneous
# SPMDNAA : Miscellaneous
# SPMD2NAA : Miscellaneous
# SPRMNAA : Miscellaneous
# N1SPRMNAA : Miscellaneous
# N1ASPMDO : Miscellaneous
# N112SPRMO : Miscellaneous
# N1SPRMO : Miscellaneous
# ALATRS : Biomass synthesis
# ALATRSm : Biomass synthesis
# ARGTRS : Biomass synthesis
# ARGTRSm : Biomass synthesis
# ASNTRS : Biomass synthesis
# ASNTRSm : Biomass synthesis
# ASPTRS : Biomass synthesis
# ASPTRSm : Biomass synthesis
# CYSTRS : Biomass synthesis
# CYSTRSm : Biomass synthesis
# FMETTRSm : Biomass synthesis
# GLNTRS : Biomass synthesis
# GLNTRSm : Biomass synthesis
# GLYTRS : Biomass synthesis
# HISTRS : Biomass synthesis
# HISTRSm : Biomass synthesis
# ILETRS : Biomass synthesis
# ILETRSm : Biomass synthesis
# LEUTRS : Biomass synthesis
# LEUTRSm : Biomass synthesis
# LYSTRS : Biomass synthesis
# METTRS : Biomass synthesis
# METTRSm : Biomass synthesis
# PHETRS : Biomass synthesis
# PHETRSm : Biomass synthesis
# PROTRS : Biomass synthesis
# PROTRSm : Biomass synthesis
# SERTRS : Biomass synthesis
# SERTRSm : Biomass synthesis
# THRTRS : Biomass synthesis
# THRTRSm : Biomass synthesis
# TRPTRS : Biomass synthesis
# TRPTRSm : Biomass synthesis
# TYRTRS : Biomass synthesis
# TYRTRSm : Biomass synthesis
# VALTRS : Biomass synthesis
# VALTRSm : Biomass synthesis
# GLUTRS : Biomass synthesis
# GLUTRSm : Biomass synthesis
# DM_corem1[g] : Exchange/demand/sink reaction
# DM_corem2[g] : Exchange/demand/sink reaction
# CDPtg : Transport
# SK_Ser/Thr[r] : Exchange/demand/sink reaction
# GDPFUCtr : Transport
# GMPtr : Transport
# LKYNRtr2 : Transport
# LKYNRtr3 : Transport
# HKYNRtr : Transport
# EX_Lkynr(e) : Exchange/demand/sink reaction
# EX_hLkynr(e) : Exchange/demand/sink reaction
# KYNATEtr : Transport
# EX_kynate(e) : Exchange/demand/sink reaction
# PGLYCABCte : Transport
# RETABCtc : Transport
# VITD3t2 : Transport
# CLCFTRte : Transport
# UDPG3DOPA : Amino acid metabolism
# 34DHPEAR : Amino acid metabolism
# DOPACCL : Amino acid metabolism
# DOPAOQCYS : Amino acid metabolism
# FOLABCCte : Transport
# NTD5_a : Vitamin and cofactor metabolism
# GGTA1g : Glycan and glycosaminoglycan metabolism
# FUT121g : Glycan and glycosaminoglycan metabolism
# ACOD : Unassigned
# ALPAP : Glycerophospholipid, sphingolipid and inositol metabolism
# LPS3m : Glycerophospholipid, sphingolipid and inositol metabolism
# ASPDH : Amino acid metabolism
# ATAx : Unassigned
# ATAn : Unassigned
# CAATPasg : Transport
# GPCCPDE2 : Glycerophospholipid, sphingolipid and inositol metabolism
# GPCCPDE : Glycerophospholipid, sphingolipid and inositol metabolism
# SQOR2m : Central carbon and energy metabolism
# TSCTS : Central carbon and energy metabolism
# PRSDO : Central carbon and energy metabolism
# SDHPTK : Unassigned
# SUCGT : Unassigned
# HMGCH : Unassigned
# THYST : Amino acid metabolism
# UGALCG : Glycerophospholipid, sphingolipid and inositol metabolism
# 1A2425THVITD2t : Transport
# 1A2425THVITD2tm : Transport
# EX_1a2425thvitd2(e) : Exchange/demand/sink reaction
# DM_adystroglycan : Exchange/demand/sink reaction
# DM_xgser : Exchange/demand/sink reaction
# DM_slnfser : Exchange/demand/sink reaction
# DM_gfser : Exchange/demand/sink reaction
# GDPtr : Transport
# DARGt2r : Transport
# AGMO : Glycerophospholipid, sphingolipid and inositol metabolism
# FADRx2 : Miscellaneous
# DM_1a25dhvitd3[n] : Exchange/demand/sink reaction
# 34DHOXMANDte : Transport
# EX_34dhoxmand(e) : Exchange/demand/sink reaction
# 3MOX4HOXMte : Transport
# EX_3mox4hoxm(e) : Exchange/demand/sink reaction
# DM_5hoxnfkyn[c] : Exchange/demand/sink reaction
# GNCORE1t : Transport
# GNCORE1te : Transport
# EX_gncore1(e) : Exchange/demand/sink reaction
# B3GNT36g : Glycerophospholipid, sphingolipid and inositol metabolism
# IND3ACt : Transport
# IND3ACtm : Transport
# EX_ind3ac(e) : Exchange/demand/sink reaction
# 12HPETUPKt : Transport
# 12HPETATP : Transport
# EX_12HPET(e) : Exchange/demand/sink reaction
# 15HPETUPKt : Transport
# 15HPETATP : Transport
# EX_15HPET(e) : Exchange/demand/sink reaction
# 3HBCOARtc : Transport
# NH4tr : Transport
# CHTNte : Transport
# 5G2OXPTtx : Transport
# EX_arg_D(e) : Exchange/demand/sink reaction
# NAtm : Transport
# O2tl : Transport
# O2tg : Transport
# FE3tm : Transport
# ACGALtlg : Transport
# DM_oak2g_hs(c) : Exchange/demand/sink reaction
# STRDNCCOAtcx : Transport
# EICOSTETCOAtcx : Transport
# DLNLCGCOAtcx : Transport
# SUCRt2r : Transport
# MG2t : Transport
# MG2t4e : Transport
# MG2t4m : Transport
# MG2tm : Transport
# MG2t4g : Transport
# MG2tg : Transport
# EX_mg2(e) : Exchange/demand/sink reaction
# CUATPase : Transport
# CU22t : Transport
# EX_cu2(e) : Exchange/demand/sink reaction
# OGLCNACPt : Transport
# FCYTOB5OXRm : Unassigned
# FCYTOB5OXR : Unassigned
# FCYTOB5OXRy : Unassigned
# FCYTOB5OXRr : Unassigned
# FCYTOB5OXRyr : Unassigned
# PHEMEteir : Transport
# BGAL1l : Glycerophospholipid, sphingolipid and inositol metabolism
# BGAL2l : Glycerophospholipid, sphingolipid and inositol metabolism
# GLA2l : Glycerophospholipid, sphingolipid and inositol metabolism
# HEXA1l : Glycerophospholipid, sphingolipid and inositol metabolism
# HEXAHBl : Glycerophospholipid, sphingolipid and inositol metabolism
# CPP : Glycerophospholipid, sphingolipid and inositol metabolism
# LKTD4PEP : Bile, eicosanoid and steroid metabolism
# PROSTGA2S : Bile, eicosanoid and steroid metabolism
# PI35P4P : Glycerophospholipid, sphingolipid and inositol metabolism
# UDPGGPGTr : Glycerophospholipid, sphingolipid and inositol metabolism
# GLYC3PIPH : Glycerophospholipid, sphingolipid and inositol metabolism
# GLYC3PGPH : Glycerophospholipid, sphingolipid and inositol metabolism
# ALATRAH : Miscellaneous
# ALATRAHm : Miscellaneous
# ARGTRAH : Miscellaneous
# ARGTRAHm : Miscellaneous
# ASNTRAH : Miscellaneous
# ASNTRAHm : Miscellaneous
# ASPTRAH : Miscellaneous
# ASPTRAHm : Miscellaneous
# CYSTRAH : Miscellaneous
# CYSTRAHm : Miscellaneous
# GLNTRAH : Miscellaneous
# GLNTRAHm : Miscellaneous
# GLYTRAH : Miscellaneous
# HISTRAH : Miscellaneous
# HISTRAHm : Miscellaneous
# ILETRAH : Miscellaneous
# ILETRAHm : Miscellaneous
# LEUTRAH : Miscellaneous
# LEUTRAHm : Miscellaneous
# LYSTRAH : Miscellaneous
# METTRAH : Miscellaneous
# METTRAHm : Miscellaneous
# PHETRAH : Miscellaneous
# PHETRAHm : Miscellaneous
# PROTRAH : Miscellaneous
# PROTRAHm : Miscellaneous
# SERTRAH : Miscellaneous
# SERTRAHm : Miscellaneous
# THRTRAH : Miscellaneous
# THRTRAHm : Miscellaneous
# TRPTRAH : Miscellaneous
# TRPTRAHm : Miscellaneous
# TYRTRAH : Miscellaneous
# TYRTRAHm : Miscellaneous
# VALTRAH : Miscellaneous
# VALTRAHm : Miscellaneous
# GLUTRAH : Miscellaneous
# GLUTRAHm : Miscellaneous
# SIAOACET : Miscellaneous
# SIAACTE : Miscellaneous
# RBLP : Miscellaneous
# RBTLP : Miscellaneous
# ACOAD170m : Fatty acid metabolism
# 3HAD170m : Fatty acid metabolism
# 3HDH170m : Fatty acid metabolism
# ACACT170m : Fatty acid metabolism
# ACOAD150m : Fatty acid metabolism
# 3HAD150m : Fatty acid metabolism
# 3HDH150m : Fatty acid metabolism
# ACACT150m : Fatty acid metabolism
# ACOAD130m : Fatty acid metabolism
# 3HAD130m : Fatty acid metabolism
# 3HDH130m : Fatty acid metabolism
# ACACT130m : Fatty acid metabolism
# ACOAD110m : Fatty acid metabolism
# 3HAD110m : Fatty acid metabolism
# 3HDH110m : Fatty acid metabolism
# ACACT110m : Fatty acid metabolism
# ACOAD90m : Fatty acid metabolism
# 3HAD90m : Fatty acid metabolism
# 3HDH90m : Fatty acid metabolism
# ACACT90m : Fatty acid metabolism
# ACOAD70m : Fatty acid metabolism
# 3HAD70m : Fatty acid metabolism
# 3HDH70m : Fatty acid metabolism
# ACACT70m : Fatty acid metabolism
# ACOAD50m : Fatty acid metabolism
# 3HAD50m : Fatty acid metabolism
# 3HDH50m : Fatty acid metabolism
# ACACT50m : Fatty acid metabolism
# ACOAD182n6Em : Fatty acid metabolism
# 3HAD182n6Em : Fatty acid metabolism
# 3HDH182n6Em : Fatty acid metabolism
# ACACT182n6Em : Fatty acid metabolism
# ACOAD162n6em : Fatty acid metabolism
# 3HAD162n6em : Fatty acid metabolism
# 3HDH162n6em : Fatty acid metabolism
# ACACT162n6em : Fatty acid metabolism
# ACOAD142n6em : Fatty acid metabolism
# 3HAD142n6em : Fatty acid metabolism
# 3HDH142n6em : Fatty acid metabolism
# ACACT142n6em : Fatty acid metabolism
# DDCI122n6m : Fatty acid metabolism
# 3HAD121n6em : Fatty acid metabolism
# 3HDH121n6em : Fatty acid metabolism
# ACACT121n6em : Fatty acid metabolism
# ACOAD101n6em : Fatty acid metabolism
# 3HDH101n6em : Fatty acid metabolism
# DDCI101m : Fatty acid metabolism
# GNPT : Glycan and glycosaminoglycan metabolism
# NAGPA : Glycan and glycosaminoglycan metabolism
# M4MASNt : Transport
# M4MASNtly : Transport
# ARGt7l : Transport
# PROt2rL : Transport
# ILEt7l : Transport
# THRt7l : Transport
# ASNt7l : Transport
# ASPt7l : Transport
# CYSt7l : Transport
# GLNt7l : Transport
# LEUt7l : Transport
# LYSt7l : Transport
# METt7l : Transport
# PHEt7l : Transport
# SERt7l : Transport
# TRPt7l : Transport
# TYRt7l : Transport
# VALt7l : Transport
# EX_eicostri(e) : Exchange/demand/sink reaction
# EX_docastri(e) : Exchange/demand/sink reaction
# biomass_cho_prod : Biomass synthesis
# DNAsyn_prod : Biomass synthesis
# RNAsyn_prod : Biomass synthesis
# PROTsyn_prod : Biomass synthesis
# biomass_cho : Biomass synthesis
# DNAsyn : Biomass synthesis
# RNAsyn : Biomass synthesis
# PROTsyn : Biomass synthesis
# PEPTIDEtl : Exchange/demand/sink reaction
# ARTFR33 : Exchange/demand/sink reaction
# ARTFR43 : Exchange/demand/sink reaction
# ARTFR51 : Exchange/demand/sink reaction
# ARTCOAL1 : Exchange/demand/sink reaction
# ARTCOAL2 : Exchange/demand/sink reaction
# ARTCOAL3 : Exchange/demand/sink reaction
# ARTFR11 : Exchange/demand/sink reaction
# ARTFR12 : Exchange/demand/sink reaction
# ARTFR13 : Exchange/demand/sink reaction
# ARTFR202 : Exchange/demand/sink reaction
# ARTFR203 : Exchange/demand/sink reaction
# ARTFR204 : Exchange/demand/sink reaction
# ARTFR205 : Exchange/demand/sink reaction
# ARTFR206 : Exchange/demand/sink reaction
# ARTFR207 : Exchange/demand/sink reaction
# ARTFR208 : Exchange/demand/sink reaction
# ARTFR209 : Exchange/demand/sink reaction
# ARTFR210 : Exchange/demand/sink reaction
# ARTFR211 : Exchange/demand/sink reaction
# ARTFR212 : Exchange/demand/sink reaction
# ARTFR213 : Exchange/demand/sink reaction
# ARTFR31 : Exchange/demand/sink reaction
# ARTFR32 : Exchange/demand/sink reaction
# ARTFR34 : Exchange/demand/sink reaction
# ARTFR41 : Exchange/demand/sink reaction
# ARTFR42 : Exchange/demand/sink reaction
# ARTFR44 : Exchange/demand/sink reaction
# ARTFR45 : Exchange/demand/sink reaction
# ARTFR46 : Exchange/demand/sink reaction
# ARTFR52 : Exchange/demand/sink reaction
# ARTFR53 : Exchange/demand/sink reaction
# ARTFR54 : Exchange/demand/sink reaction
# ARTFR55 : Exchange/demand/sink reaction
# ARTFR56 : Exchange/demand/sink reaction
# ARTFR57 : Exchange/demand/sink reaction
# ARTFR61 : Exchange/demand/sink reaction
# ARTPLM1 : Exchange/demand/sink reaction
# ARTPLM1m : Exchange/demand/sink reaction
# ARTPLM2 : Exchange/demand/sink reaction
# ARTPLM2m : Exchange/demand/sink reaction
# ARTPLM3 : Exchange/demand/sink reaction
# ARTPLM3m : Exchange/demand/sink reaction
# RTOTAL2CRNCPT1 : Fatty acid metabolism
# RTOTAL2CRNCPT2 : Fatty acid metabolism
# RTOTAL2CRNt : Fatty acid metabolism
# RTOTAL3CRNCPT1 : Fatty acid metabolism
# RTOTAL3CRNCPT2 : Fatty acid metabolism
# RTOTAL3CRNt : Fatty acid metabolism
# RTOTALCRNCPT1 : Fatty acid metabolism
# RTOTALCRNCPT2 : Fatty acid metabolism
# RTOTALCRNt : Fatty acid metabolism
# EX_Rtotal(e) : Exchange/demand/sink reaction
# EX_Rtotal2(e) : Exchange/demand/sink reaction
# EX_Rtotal3(e) : Exchange/demand/sink reaction
# RTOT_2 : Exchange/demand/sink reaction
# RTOT_3 : Exchange/demand/sink reaction
# RTOT1 : Exchange/demand/sink reaction
# RTOT2 : Exchange/demand/sink reaction
# RTOT3 : Exchange/demand/sink reaction
# RTOT4 : Exchange/demand/sink reaction
# RTOT5 : Exchange/demand/sink reaction
# RTOT6 : Exchange/demand/sink reaction
# RTOTAL2FATPc : Exchange/demand/sink reaction
# RTOTAL2t : Transport
# RTOTAL3FATPc : Exchange/demand/sink reaction
# RTOTAL3t : Transport
# RTOTALFATPc : Exchange/demand/sink reaction
# RTOTALt : Transport
# Rtotaltl : Transport
# Rtotaltp : Transport
# Rtotalcoatx : Exchange/demand/sink reaction

# %% [markdown]
# Although as this project develops we may find reactions in an unbiased way which are important for the objective function, Since York and we are interested in glycan metabolism, let's scan the iCHO2291 model to see which reactions are included in the glycan metabolism subsystem:

# %%
for r in model.reactions:
    if r.subsystem == 'Glycan and glycosaminoglycan metabolism':
        print(r)
# Out:
# A_MANASE: 2.0 h2o[c] + m2mn[c] --> 2.0 man[c] + mn[c]
# A_MANASEly: 2.0 h2o[l] + m2mn[l] --> 2.0 man[l] + mn[l]
# A4GNT1g: T_antigen[g] + uacgam[g] --> gncore1[g] + h[g] + udp[g]
# A4GNT2g: core2[g] + uacgam[g] --> gncore2[g] + h[g] + udp[g]
# ABO1g: fucgalacglcgalgluside_cho[g] + udpacgal[g] --> acgalfucgalacglcgalgluside_cho[g] + h[g] + udp[g]
# ABO2g: fucgalacglcgalgluside_cho[g] + udpgal[g] --> galfucgalacglcgalgluside_cho[g] + h[g] + udp[g]
# ABO3g: fuc12gal14acglcgalgluside_cho[g] + udpgal[g] --> galfuc12gal14acglcgalgluside_cho[g] + h[g] + udp[g]
# ABO4g: fuc12gal14acglcgalgluside_cho[g] + udpacgal[g] --> acgalfuc12gal14acglcgalgluside_cho[g] + h[g] + udp[g]
# ABO5g: fucgalacgalfuc12gal14acglcgalgluside_cho[g] + udpacgal[g] --> acgalfucgalacgalfuc12gal14acglcgalgluside_cho[g] + h[g] + udp[g]
# ABO6g: fucgalacglcgal14acglcgalgluside_cho[g] + udpacgal[g] --> acgalfucgalacglcgal14acglcgalgluside_cho[g] + h[g] + udp[g]
# ABO7g: fucgalacgalfucgalacglcgal14acglcgalgluside_cho[g] + udpacgal[g] --> acgalfucgalacgalfucgalacglcgal14acglcgalgluside_cho[g] + h[g] + udp[g]
# ABO8g: fucgalacglcgal14acglcgalgluside_cho[g] + udpgal[g] --> galfucgalacglcgal14acglcgalgluside_cho[g] + h[g] + udp[g]
# ABO9g: fucfucgalacglcgalacglcgal14acglcgalgluside_cho[g] + 2.0 udpgal[g] --> galgalfucfucgalacglcgalacglcgal14acglcgalgluside_cho[g] + 2.0 h[g] + 2.0 udp[g]
# AG13T10g: ksi_pre18[g] + uacgam[g] --> h[g] + ksi_pre19[g] + udp[g]
# AG13T11g: ksi_pre21[g] + uacgam[g] --> h[g] + ksi_pre22[g] + udp[g]
# AG13T12g: ksi_pre24[g] + uacgam[g] --> h[g] + ksi_pre25[g] + udp[g]
# AG13T13g: ksi_pre27[g] + uacgam[g] --> h[g] + ksi_pre28[g] + udp[g]
# AG13T14g: ksi_pre30[g] + uacgam[g] --> h[g] + ksi_pre31[g] + udp[g]
# AG13T15g: ksi_pre33[g] + uacgam[g] --> h[g] + ksi_pre34[g] + udp[g]
# AG13T16g: ksii_core4_pre2[g] + uacgam[g] --> h[g] + ksii_core4_pre3[g] + udp[g]
# AG13T17g: ksii_core4_pre4[g] + uacgam[g] --> h[g] + ksii_core4_pre5[g] + udp[g]
# AG13T18g: ksii_core4_pre7[g] + uacgam[g] --> h[g] + ksii_core4_pre8[g] + udp[g]
# AG13T1g: ksii_core2_pre2[g] + uacgam[g] --> h[g] + ksii_core2_pre3[g] + udp[g]
# AG13T2g: ksii_core2_pre4[g] + uacgam[g] --> h[g] + ksii_core2_pre5[g] + udp[g]
# AG13T3g: ksii_core2_pre7[g] + uacgam[g] --> h[g] + ksii_core2_pre8[g] + udp[g]
# AG13T4g: ksi_pre1[g] + uacgam[g] --> h[g] + ksi_pre2[g] + udp[g]
# AG13T5g: ksi_pre3[g] + uacgam[g] --> h[g] + ksi_pre4[g] + udp[g]
# AG13T6g: ksi_pre6[g] + uacgam[g] --> h[g] + ksi_pre7[g] + udp[g]
# AG13T7g: ksi_pre9[g] + uacgam[g] --> h[g] + ksi_pre10[g] + udp[g]
# AG13T8g: ksi_pre12[g] + uacgam[g] --> h[g] + ksi_pre13[g] + udp[g]
# AG13T9g: ksi_pre15[g] + uacgam[g] --> h[g] + ksi_pre16[g] + udp[g]
# AHEXASE2ly: 3.0 h2o[l] + n2m2nmn[l] --> 3.0 acgam[l] + m2mn[l]
# AHEXASEly: 2.0 h2o[l] + n2m2mn[l] --> 2.0 acgam[l] + m2mn[l]
# B_MANNASEly: h2o[l] + mn[l] --> acgam[l] + man[l]
# B3GALTg: acglcgalgluside_cho[g] + udpgal[g] --> galacglcgalgluside_cho[g] + h[g] + udp[g]
# B3GNT11g: gal14acglcgalgluside_cho[g] + uacgam[g] --> acglcgal14acglcgalgluside_cho[g] + h[g] + udp[g]
# B3GNT12g: galacglcgal14acglcgalgluside_cho[g] + uacgam[g] --> acglc13galacglcgal14acglcgalgluside_cho[g] + h[g] + udp[g]
# B3GNT310g: acglcgalgluside_cho[g] + udpgal[g] --> gal14acglcgalgluside_cho[g] + h[g] + udp[g]
# B3GNT311g: acgalfuc12gal14acglcgalgluside_cho[g] + udpgal[g] --> galacgalfuc12gal14acglcgalgluside_cho[g] + h[g] + udp[g]
# B3GNT312g: acglcgal14acglcgalgluside_cho[g] + udpgal[g] --> galacglcgal14acglcgalgluside_cho[g] + h[g] + udp[g]
# B3GNT313g: acgalfucgalacglcgal14acglcgalgluside_cho[g] + udpgal[g] --> galacgalfucgalacglcgal14acglcgalgluside_cho[g] + h[g] + udp[g]
# B3GNT314g: acglcgalacglcgal14acglcgalgluside_cho[g] + udpgal[g] --> galacglcgalacglcgal14acglcgalgluside_cho[g] + h[g] + udp[g]
# B3GNT315g: acglc13galacglcgal14acglcgalgluside_cho[g] + udpgal[g] --> galacglc13galacglcgal14acglcgalgluside_cho[g] + h[g] + udp[g]
# B3GNT38g: galside_cho[g] + udpgal[g] --> digalside_cho[g] + h[g] + udp[g]
# B3GNT51g: galgluside_cho[g] + uacgam[g] --> acglcgalgluside_cho[g] + h[g] + udp[g]
# BDMT: chito2pdol[c] + gdpmann[c] --> gdp[c] + h[c] + mpdol[c]
# CORE2GTg: T_antigen[g] + uacgam[g] --> core2[g] + h[g] + udp[g]
# CORE3GTg: Tn_antigen[g] + uacgam[g] --> core3[g] + h[g] + udp[g]
# CORE4GTg: core3[g] + uacgam[g] --> core4[g] + h[g] + udp[g]
# CORE5GTg: Tn_antigen[g] + udpacgal[g] --> core5[g] + h[g] + udp[g]
# CORE6GTg: Tn_antigen[g] + uacgam[g] --> core6[g] + h[g] + udp[g]
# CORE7GTg: Tn_antigen[g] + udpacgal[g] --> core7[g] + h[g] + udp[g]
# CORE8GTg: Tn_antigen[g] + udpgal[g] --> core8[g] + h[g] + udp[g]
# CSAPASEly: cspg_a[l] + h2o[l] --> Ser_Gly_Ala_X_Gly[l] + cs_a[l]
# CSBPASEly: cspg_b[l] + h2o[l] --> Ser_Gly_Ala_X_Gly[l] + cs_b[l]
# CSCPASEly: cspg_c[l] + h2o[l] --> Ser_Gly_Ala_X_Gly[l] + cs_c[l]
# CSDPASEly: cspg_d[l] + h2o[l] --> Ser_Gly_Ala_X_Gly[l] + cs_d[l]
# CSEPASEly: cspg_e[l] + h2o[l] --> Ser_Gly_Ala_X_Gly[l] + cs_e[l]
# DEDOLP1: dedoldp[c] + h2o[c] --> dedolp[c] + h[c] + pi[c]
# DEDOLP2: dedolp[c] + h2o[c] --> dedol[c] + pi[c]
# DEDOLR: dedol[c] + h[c] + nadph[c] --> dolichol[c] + nadp[c]
# DHDDS: frdp[c] + 16.0 ipdp[c] --> dedoldp[c] + 16.0 ppi[c]
# DOLASNTer: Asn_X_Ser/Thr[r] + g3m8mpdol[r] --> doldp[r] + g3m8masn[r] + h[r]
# DOLDPPer: doldp[r] + h2o[r] --> dolp[r] + h[r] + pi[r]
# DOLGLCP_ter: dolglcp[c] --> dolglcp[r]
# DOLGPP_er: dolglcp[r] + h2o[r] --> dolp[r] + glc_D[r] + h[r]
# DOLICHOL_ter: dolichol[r] <=> dolichol[c]
# DOLK: ctp[c] + dolichol[c] --> cdp[c] + dolp[c] + h[c]
# DOLMANP_ter: dolmanp[c] --> dolmanp[r]
# DOLP_ter: dolp[r] --> dolp[c]
# DOLPGT1er: dolglcp[r] + m8mpdol[r] --> dolp[r] + g1m8mpdol[r] + h[r]
# DOLPGT2er: dolglcp[r] + g1m8mpdol[r] --> dolp[r] + g2m8mpdol[r] + h[r]
# DOLPGT3er: dolglcp[r] + g2m8mpdol[r] --> dolp[r] + g3m8mpdol[r] + h[r]
# DOLPH_er: dolp[r] + h2o[r] --> dolichol[r] + pi[r]
# DOLPMT: dolp[c] + gdpmann[c] --> dolmanp[c] + gdp[c]
# DOLPMT1er: dolmanp[r] + m4mpdol[r] --> dolp[r] + h[r] + m5mpdol[r]
# DOLPMT2_er: dolmanp[r] + m5mpdol[r] --> dolp[r] + h[r] + m6mpdol[r]
# DOLPMT3er: dolmanp[r] + m6mpdol[r] --> dolp[r] + h[r] + m7mpdol[r]
# DOLPMT4_er: dolmanp[r] + m7mpdol[r] --> dolp[r] + h[r] + m8mpdol[r]
# ENGASE: h2o[c] + s2l2n2m2m[c] --> acgam[c] + s2l2n2m2mn[c]
# ENGASE2: h2o[c] + n2m2nm[c] --> acgam[c] + n2m2nmn[c]
# ENGASE2ly: h2o[l] + n2m2nm[l] --> acgam[l] + n2m2nmn[l]
# ENGASE3ly: h2o[l] + ksi_deg2[l] --> acgam[l] + ksi_deg3[l]
# ENGASEly: h2o[l] + s2l2n2m2m[l] --> acgam[l] + s2l2n2m2mn[l]
# ENMAN1g: g1m8masn[g] + h2o[g] --> glc1man[g] + m7masnA[g]
# ENMAN2g: g2m8masn[g] + h2o[g] --> glc2man[g] + m7masnA[g]
# ENMAN3g: g3m8masn[g] + h2o[g] --> glc3man[g] + m7masnA[g]
# ENMAN4g: g1m7masnC[g] + h2o[g] --> glc1man[g] + m6masnC[g]
# ENMAN5g: g1m7masnB[g] + h2o[g] --> glc1man[g] + m6masnB2[g]
# ENMAN6g: g1m6masnB1[g] + h2o[g] --> glc1man[g] + m5masnB1[g]
# F6T2g: gdpfuc[g] + nm4masn[g] --> fnm4masn[g] + gdp[g] + h[g]
# F6T3g: gdpfuc[g] + nm2masn[g] --> fnm2masn[g] + gdp[g] + h[g]
# F6T4g: gdpfuc[g] + n3m2masn[g] --> fn3m2masn[g] + gdp[g] + h[g]
# F6T5g: gdpfuc[g] + n4m2masn[g] --> fn4m2masn[g] + gdp[g] + h[g]
# F6T6g: gdpfuc[g] + n3rm2masn[g] --> fn3rm2masn[g] + gdp[g] + h[g]
# F6Tg: gdpfuc[g] + n2m2masn[g] --> fn2m2masn[g] + gdp[g] + h[g]
# FUCASE2e: h2o[e] + ksi[e] --> fuc_L[e] + ksi_deg1[e]
# FUCASE2ly: h2o[l] + ksi[l] --> fuc_L[l] + ksi_deg1[l]
# FUCASEe: h2o[e] + s2l2fn2m2masn[e] --> fuc_L[e] + s2l2n2m2masn[e]
# FUCASEly: h2o[l] + s2l2fn2m2masn[l] --> fuc_L[l] + s2l2n2m2masn[l]
# FUT12g: galacglcgalgluside_cho[g] + gdpfuc[g] --> fucgalacglcgalgluside_cho[g] + gdp[g] + h[g]
# FUT14g: gal14acglcgalgluside_cho[g] + gdpfuc[g] --> fuc12gal14acglcgalgluside_cho[g] + gdp[g] + h[g]
# FUT15g: galacgalfuc12gal14acglcgalgluside_cho[g] + gdpfuc[g] --> fucgalacgalfuc12gal14acglcgalgluside_cho[g] + gdp[g] + h[g]
# FUT16g: galacglcgal14acglcgalgluside_cho[g] + gdpfuc[g] --> fucgalacglcgal14acglcgalgluside_cho[g] + gdp[g] + h[g]
# FUT17g: galacgalfucgalacglcgal14acglcgalgluside_cho[g] + gdpfuc[g] --> fucgalacgalfucgalacglcgal14acglcgalgluside_cho[g] + gdp[g] + h[g]
# FUT18g: galacglcgalacglcgal14acglcgalgluside_cho[g] + 2.0 gdpfuc[g] --> fucfucgalacglcgalacglcgal14acglcgalgluside_cho[g] + 2.0 gdp[g] + 2.0 h[g]
# FUT31g: galacglcgalgluside_cho[g] + gdpfuc[g] --> fuc14galacglcgalgluside_cho[g] + gdp[g] + h[g]
# FUT32g: acngalacglcgalgluside_cho[g] + gdpfuc[g] --> fucacngalacglcgalgluside_cho[g] + gdp[g] + h[g]
# FUT33g: acgalfucgalacglcgalgluside_cho[g] + gdpfuc[g] --> fucacgalfucgalacglcgalgluside_cho[g] + gdp[g] + h[g]
# FUT34g: fucgalacglcgalgluside_cho[g] + gdpfuc[g] --> fucfucgalacglcgalgluside_cho[g] + gdp[g] + h[g]
# FUT35g: galfucgalacglcgalgluside_cho[g] + gdpfuc[g] --> fucgalfucgalacglcgalgluside_cho[g] + gdp[g] + h[g]
# FUT910g: fucgalacglc13galacglcgal14acglcgalgluside_cho[g] + gdpfuc[g] --> fucfucgalacglc13galacglcgal14acglcgalgluside_cho[g] + gdp[g] + h[g]
# FUT911g: fucfucgalacglc13galacglcgal14acglcgalgluside_cho[g] + gdpfuc[g] --> fucfucfucgalacglc13galacglcgal14acglcgalgluside_cho[g] + gdp[g] + h[g]
# FUT91g: gal14acglcgalgluside_cho[g] + gdpfuc[g] --> fucgal14acglcgalgluside_cho[g] + gdp[g] + h[g]
# FUT92g: acngal14acglcgalgluside_cho[g] + gdpfuc[g] --> fucacngal14acglcgalgluside_cho[g] + gdp[g] + h[g]
# FUT93g: fuc12gal14acglcgalgluside_cho[g] + gdpfuc[g] --> fucfuc12gal14acglcgalgluside_cho[g] + gdp[g] + h[g]
# FUT94g: fucgalacglcgal14acglcgalgluside_cho[g] + gdpfuc[g] --> fucfucgalacglcgal14acglcgalgluside_cho[g] + gdp[g] + h[g]
# FUT95g: fucfucgalacglcgal14acglcgalgluside_cho[g] + gdpfuc[g] --> fucfucfucgalacglcgal14acglcgalgluside_cho[g] + gdp[g] + h[g]
# FUT96g: galacglcgal14acglcgalgluside_cho[g] + gdpfuc[g] --> fuc132galacglcgal14acglcgalgluside_cho[g] + gdp[g] + h[g]
# FUT97g: fuc132galacglcgal14acglcgalgluside_cho[g] + gdpfuc[g] --> fucfuc132galacglcgal14acglcgalgluside_cho[g] + gdp[g] + h[g]
# FUT98g: galacglcgal14acglcgalgluside_cho[g] + gdpfuc[g] --> fuc13galacglcgal14acglcgalgluside_cho[g] + gdp[g] + h[g]
# FUT99g: galacglc13galacglcgal14acglcgalgluside_cho[g] + gdpfuc[g] --> fucgalacglc13galacglcgal14acglcgalgluside_cho[g] + gdp[g] + h[g]
# G12MT1: gdpmann[c] + m2mpdol[c] --> gdp[c] + h[c] + m3mpdol[c]
# G12MT2: gdpmann[c] + m3mpdol[c] --> gdp[c] + h[c] + m4mpdol[c]
# G13MT: gdpmann[c] + mpdol[c] --> gdp[c] + h[c] + m1mpdol[c]
# G14N10g: ndl4fn4m2masn[g] + udpgal[g] --> h[g] + lndl4fn4m2masn[g] + udp[g]
# G14N11g: ndl4n4m2masn[g] + udpgal[g] --> h[g] + lndl4n4m2masn[g] + udp[g]
# G14N12g: ncl4fn4m2masn[g] + udpgal[g] --> h[g] + lncl4fn4m2masn[g] + udp[g]
# G14N13g: ncl4n4m2masn[g] + udpgal[g] --> h[g] + lncl4n4m2masn[g] + udp[g]
# G14N14g: nbl4fn4m2masn[g] + udpgal[g] --> h[g] + lnbl4fn4m2masn[g] + udp[g]
# G14N15g: nbl4n4m2masn[g] + udpgal[g] --> h[g] + lnbl4n4m2masn[g] + udp[g]
# G14N16g: n2cdl4fn4m2masn[g] + 2.0 udpgal[g] --> 2.0 h[g] + l2n2cdl4fn4m2masn[g] + 2.0 udp[g]
# G14N17g: n2cdl4n4m2masn[g] + 2.0 udpgal[g] --> 2.0 h[g] + l2n2cdl4n4m2masn[g] + 2.0 udp[g]
# G14N18g: n2bdl4fn4m2masn[g] + 2.0 udpgal[g] --> 2.0 h[g] + l2n2bdl4fn4m2masn[g] + 2.0 udp[g]
# G14N19g: n2bdl4n4m2masn[g] + 2.0 udpgal[g] --> 2.0 h[g] + l2n2bdl4n4m2masn[g] + 2.0 udp[g]
# G14N1g: n2m2masn[g] + 2.0 udpgal[g] --> 2.0 h[g] + l2n2m2masn[g] + 2.0 udp[g]
# G14N20g: n3l4fn4m2masn[g] + 3.0 udpgal[g] --> 3.0 h[g] + l3n3l4fn4m2masn[g] + 3.0 udp[g]
# G14N21g: n3l4n4m2masn[g] + 3.0 udpgal[g] --> 3.0 h[g] + l3n3l4n4m2masn[g] + 3.0 udp[g]
# G14N2g: n3m2masn[g] + 3.0 udpgal[g] --> 3.0 h[g] + l3n3m2masn[g] + 3.0 udp[g]
# G14N3g: n3rm2masn[g] + 3.0 udpgal[g] --> 3.0 h[g] + l3n3rm2masn[g] + 3.0 udp[g]
# G14N4g: fn3m2masn[g] + 3.0 udpgal[g] --> 3.0 h[g] + l3fn3m2masn[g] + 3.0 udp[g]
# G14N5g: fn3rm2masn[g] + 3.0 udpgal[g] --> 3.0 h[g] + l3fn3rm2masn[g] + 3.0 udp[g]
# G14N6g: fn4m2masn[g] + 4.0 udpgal[g] --> 4.0 h[g] + l4fn4m2masn[g] + 4.0 udp[g]
# G14N7g: nl3n3m2masn[g] + udpgal[g] --> h[g] + lnl3n3m2masn[g] + udp[g]
# G14N8g: n4m2masn[g] + 4.0 udpgal[g] --> 4.0 h[g] + l4n4m2masn[g] + 4.0 udp[g]
# G14N9g: nl3fn3m2masn[g] + udpgal[g] --> h[g] + lnl3fn3m2masn[g] + udp[g]
# G14T10g: ksi_pre14[g] + udpgal[g] --> h[g] + ksi_pre15[g] + udp[g]
# G14T11g: ksi_pre17[g] + udpgal[g] --> h[g] + ksi_pre18[g] + udp[g]
# G14T12g: ksi_pre20[g] + udpgal[g] --> h[g] + ksi_pre21[g] + udp[g]
# G14T13g: ksi_pre23[g] + udpgal[g] --> h[g] + ksi_pre24[g] + udp[g]
# G14T14g: ksi_pre26[g] + udpgal[g] --> h[g] + ksi_pre27[g] + udp[g]
# G14T15g: ksi_pre29[g] + udpgal[g] --> h[g] + ksi_pre30[g] + udp[g]
# G14T16g: ksi_pre32[g] + udpgal[g] --> h[g] + ksi_pre33[g] + udp[g]
# G14T17g: ksi_pre35[g] + udpgal[g] --> h[g] + ksi_pre36[g] + udp[g]
# G14T18g: core4[g] + 2.0 udpgal[g] --> 2.0 h[g] + ksii_core4_pre1[g] + 2.0 udp[g]
# G14T19g: ksii_core4_pre3[g] + udpgal[g] --> h[g] + ksii_core4_pre4[g] + udp[g]
# G14T20g: ksii_core4_pre6[g] + udpgal[g] --> h[g] + ksii_core4_pre7[g] + udp[g]
# G14T21g: ksii_core4_pre9[g] + udpgal[g] --> h[g] + ksii_core4_pre10[g] + udp[g]
# G14T2g: ksii_core2_pre1[g] + udpgal[g] --> h[g] + ksii_core2_pre2[g] + udp[g]
# G14T3g: ksii_core2_pre3[g] + udpgal[g] --> h[g] + ksii_core2_pre4[g] + udp[g]
# G14T4g: ksii_core2_pre6[g] + udpgal[g] --> h[g] + ksii_core2_pre7[g] + udp[g]
# G14T5g: ksii_core2_pre9[g] + udpgal[g] --> h[g] + ksii_core2_pre10[g] + udp[g]
# G14T6g: ksi_pre2[g] + udpgal[g] --> h[g] + ksi_pre3[g] + udp[g]
# G14T7g: ksi_pre5[g] + udpgal[g] --> h[g] + ksi_pre6[g] + udp[g]
# G14T8g: ksi_pre8[g] + udpgal[g] --> h[g] + ksi_pre9[g] + udp[g]
# G14T9g: ksi_pre11[g] + udpgal[g] --> h[g] + ksi_pre12[g] + udp[g]
# G14Tg: fn2m2masn[g] + 2.0 udpgal[g] --> 2.0 h[g] + l2fn2m2masn[g] + 2.0 udp[g]
# G14Tg_1: fn2m2masn[g] + udpgal[g] --> h[g] + lfn2m2masn[g] + udp[g]
# G14Tg_new2: fnm2masn[g] + udpgal[g] --> h[g] + lfnm2masn[g] + udp[g]
# G14Tg_new3: nm2masn[g] + udpgal[g] --> h[g] + lnm2masn[g] + udp[g]
# G14Tg_new4: l4fn4m2masn[g] + udpgal[g] --> h[g] + l5fn4m2masn[g] + udp[g]
# G14Tg_new5: l4fn4m2masn[g] + 2.0 udpgal[g] --> h[g] + l6fn4m2masn[g] + udp[g]
# G16MT: gdpmann[c] + m1mpdol[c] --> gdp[c] + h[c] + m2mpdol[c]
# G1M6MASNB1terg: g1m6masnB1[r] --> g1m6masnB1[g]
# G1M7MASNBterg: g1m7masnB[r] --> g1m7masnB[g]
# G1M7MASNCterg: g1m7masnC[r] --> g1m7masnC[g]
# G1M8MASNterg: g1m8masn[r] --> g1m8masn[g]
# G2M8MASNterg: g2m8masn[r] --> g2m8masn[g]
# G3M8MASNterg: g3m8masn[r] --> g3m8masn[g]
# GALASE10ly: h2o[l] + ksi_deg26[l] --> gal[l] + ksi_deg27[l]
# GALASE11ly: h2o[l] + ksi_deg29[l] --> gal[l] + ksi_deg30[l]
# GALASE12ly: h2o[l] + ksi_deg32[l] --> gal[l] + ksi_deg33[l]
# GALASE13ly: h2o[l] + ksi_deg35[l] --> gal[l] + ksi_deg36[l]
# GALASE14ly: h2o[l] + ksi_deg38[l] --> gal[l] + ksi_deg39[l]
# GALASE15ly: h2o[l] + ksi_deg40[l] --> gal[l] + ksi_deg41[l]
# GALASE16ly: 2.0 h2o[l] + ksii_core2_deg2[l] --> 2.0 gal[l] + ksii_core2_deg3[l]
# GALASE17ly: h2o[l] + ksii_core2_deg5[l] --> gal[l] + ksii_core2_deg6[l]
# GALASE18ly: h2o[l] + ksii_core2_deg8[l] --> gal[l] + ksii_core2_deg9[l]
# GALASE19ly: f1a[l] + h2o[l] --> core6[l] + gal[l]
# GALASE1ly: 2.0 h2o[l] + l2n2m2mn[l] --> 2.0 gal[l] + n2m2mn[l]
# GALASE20ly: 2.0 h2o[l] + ksii_core4_deg2[l] --> 2.0 gal[l] + ksii_core4_deg3[l]
# GALASE3ly: 2.0 h2o[l] + ksi_deg5[l] --> 2.0 gal[l] + ksi_deg6[l]
# GALASE4ly: h2o[l] + ksi_deg8[l] --> gal[l] + ksi_deg9[l]
# GALASE5ly: h2o[l] + ksi_deg11[l] --> gal[l] + ksi_deg12[l]
# GALASE6ly: h2o[l] + ksi_deg14[l] --> gal[l] + ksi_deg15[l]
# GALASE7ly: h2o[l] + ksi_deg17[l] --> gal[l] + ksi_deg18[l]
# GALASE8ly: h2o[l] + ksi_deg20[l] --> gal[l] + ksi_deg21[l]
# GALASE9ly: h2o[l] + ksi_deg23[l] --> gal[l] + ksi_deg24[l]
# GALNACT1g: cs_cho_linkage[g] + udpacgal[g] --> cs_pre[g] + h[g] + udp[g]
# GALNACT2g: cs_a_b_pre2[g] + uacgam[g] --> cs_a_b_pre3[g] + h[g] + udp[g]
# GALNACT3g: cs_c_pre2[g] + uacgam[g] --> cs_c_pre3[g] + h[g] + udp[g]
# GALNACT4g: cs_d_pre3[g] + uacgam[g] --> cs_d_pre4[g] + h[g] + udp[g]
# GALNACT5g: cs_e_pre3[g] + uacgam[g] --> cs_e_pre4[g] + h[g] + udp[g]
# GALNTg: Ser_Thr[g] + udpacgal[g] --> Tn_antigen[g] + h[g] + udp[g]
# GALT2g: lxser[g] + udpgal[g] --> h[g] + l2xser[g] + udp[g]
# GALTg: udpgal[g] + xser[g] --> h[g] + lxser[g] + udp[g]
# GASNASE2ly: h2o[l] + n2m2nmasn[l] --> Asn_X_Ser/Thr[l] + n2m2nm[l]
# GASNASE3ly: h2o[l] + ksi_deg1[l] --> Asn_X_Ser/Thr[l] + ksi_deg2[l]
# GASNASEly: h2o[l] + s2l2n2m2masn[l] --> Asn_X_Ser/Thr[l] + s2l2n2m2m[l]
# GCNTg: galacglcgal14acglcgalgluside_cho[g] + uacgam[g] --> acglcgalacglcgal14acglcgalgluside_cho[g] + h[g] + udp[g]
# GLCAASE1ly: h2o[l] + hs_deg9[l] --> glcur[l] + hs_deg10[l]
# GLCAASE4ly: cs_a_deg2[l] + h2o[l] --> cs_a_deg3[l] + glcur[l]
# GLCAASE5ly: cs_c_deg2[l] + h2o[l] --> cs_c_deg3[l] + glcur[l]
# GLCAASE6ly: cs_d_deg3[l] + h2o[l] --> cs_d_deg4[l] + glcur[l]
# GLCAASE7ly: cs_e_deg3[l] + h2o[l] --> cs_e_deg4[l] + glcur[l]
# GLCAASE8ly: h2o[l] + ha[l] --> glcur[l] + ha_deg1[l]
# GLCAASE9ly: 2.0 h2o[l] + ha_pre1[l] --> acgam[l] + glcur[l]
# GLCAE1g: cs_a_b_pre3[g] --> cs_b_pre4[g]
# GLCAE2g: hs_pre10[g] --> hs_pre11[g]
# GLCAT2g: cs_a_b_e_pre1[g] + udpglcur[g] --> cs_a_b_pre2[g] + h[g] + udp[g]
# GLCAT3g: cs_c_d_e_pre1[g] + udpglcur[g] --> cs_c_pre2[g] + h[g] + udp[g]
# GLCAT4g: cs_d_pre2[g] + udpglcur[g] --> cs_d_pre3[g] + h[g] + udp[g]
# GLCAT5g: cs_e_pre2[g] + udpglcur[g] --> cs_e_pre3[g] + h[g] + udp[g]
# GLCAT6g: hs_pre1[g] + udpglcur[g] --> h[g] + hs_pre2[g] + udp[g]
# GLCAT7g: hs_pre3[g] + udpglcur[g] --> h[g] + hs_pre4[g] + udp[g]
# GLCAT8g: hs_pre5[g] + udpglcur[g] --> h[g] + hs_pre6[g] + udp[g]
# GLCAT9g: hs_pre7[g] + udpglcur[g] --> h[g] + hs_pre8[g] + udp[g]
# GLCATg: l2xser[g] + udpglcur[g] --> cs_cho_linkage[g] + h[g] + udp[g]
# GLCNACASE1ly: h2o[l] + hs_deg3[l] --> acgam[l] + hs_deg4[l]
# GLCNACASE2ly: h2o[l] + hs_deg8[l] --> acgam[l] + hs_deg9[l]
# GLCNACASE3ly: h2o[l] + hs_deg14[l] --> acgam[l] + hs_deg15[l]
# GLCNACASE4ly: h2o[l] + hs_deg20[l] --> acgam[l] + hs_deg21[l]
# GLCNACASE5ly: h2o[l] + hs_deg24[l] --> acgam[l] + hs_deg25[l]
# GLCNACDASg: 4.0 h2o[g] + hs_pre9[g] + 4.0 paps[g] --> 4.0 ac[g] + 4.0 h[g] + hs_pre10[g] + 4.0 pap[g]
# GLCNACPT: dolp[c] + uacgam[c] --> naglc2p[c] + ump[c]
# GLCNACT: naglc2p[c] + uacgam[c] --> chito2pdol[c] + h[c] + udp[c]
# GLCNACT1g: cs_cho_linkage[g] + uacgam[g] --> h[g] + hs_pre1[g] + udp[g]
# GLCNACT2g: hs_pre2[g] + uacgam[g] --> h[g] + hs_pre3[g] + udp[g]
# GLCNACT3g: hs_pre4[g] + uacgam[g] --> h[g] + hs_pre5[g] + udp[g]
# GLCNACT4g: hs_pre6[g] + uacgam[g] --> h[g] + hs_pre7[g] + udp[g]
# GLCNACT5g: hs_pre8[g] + uacgam[g] --> h[g] + hs_pre9[g] + udp[g]
# HAS1: uacgam[c] + udpglcur[c] --> 2.0 h[c] + ha_pre1[e] + 2.0 udp[c]
# HAS2: ha_pre1[e] + uacgam[c] + udpglcur[c] --> 2.0 h[c] + ha[e] + 2.0 udp[c]
# HS1ly: h2o[l] + hs_deg1[l] --> h[l] + hs_deg2[l] + so4[l]
# HS2ly: h2o[l] + hs_deg6[l] --> h[l] + hs_deg7[l] + so4[l]
# HS3ly: h2o[l] + hs_deg12[l] --> h[l] + hs_deg13[l] + so4[l]
# HS4ly: h2o[l] + hs_deg18[l] --> h[l] + hs_deg19[l] + so4[l]
# HSAT1ly: accoa[c] + hs_deg2[l] --> coa[c] + h[l] + hs_deg3[l]
# HSAT2ly: accoa[c] + hs_deg7[l] --> coa[c] + h[l] + hs_deg8[l]
# HSAT3ly: accoa[c] + hs_deg13[l] --> coa[c] + h[l] + hs_deg14[l]
# HSAT4ly: accoa[c] + hs_deg19[l] --> coa[c] + h[l] + hs_deg20[l]
# HSPASEly: h2o[l] + hspg[l] --> Ser_Gly_Ala_X_Gly[l] + hs[l]
# IDOAASE1ly: h2o[l] + hs_deg4[l] --> hs_deg5[l] + idour[l]
# IDOAASE2ly: h2o[l] + hs_deg16[l] --> hs_deg17[l] + idour[l]
# IDOAASE3ly: h2o[l] + hs_deg22[l] --> hs_deg23[l] + idour[l]
# IDOAASE4ly: cs_b_deg3[l] + h2o[l] --> cs_a_deg3[l] + idour[l]
# LINKDEG1ly: 3.0 h2o[l] + hs_deg25[l] --> 2.0 gal[l] + glcur[l] + xyl_D[l]
# LINKDEG2ly: cs_a_deg5[l] + 4.0 h2o[l] --> 2.0 gal[l] + glcur[l] + h[l] + so4[l] + xyl_D[l]
# LINKDEG3ly: cs_c_deg5[l] + 4.0 h2o[l] --> 2.0 gal[l] + glcur[l] + h[l] + so4[l] + xyl_D[l]
# LINKDEG4ly: cs_e_deg7[l] + 5.0 h2o[l] --> 2.0 gal[l] + glcur[l] + 2.0 h[l] + 2.0 so4[l] + xyl_D[l]
# M1316M2g: fnm4masn[g] + h2o[g] --> fnm2masn[g] + 2.0 man[g]
# M1316Mg: 2.0 h2o[g] + nm4masn[g] --> 2.0 man[g] + nm2masn[g]
# M13N14N3T1g: l3n3m2masn[g] + uacgam[g] --> h[g] + nl3n3m2masn[g] + udp[g]
# M13N14N3T2g: l3fn3m2masn[g] + uacgam[g] --> h[g] + nl3fn3m2masn[g] + udp[g]
# M13N14N3T3g: l4n4m2masn[g] + uacgam[g] --> h[g] + nbl4n4m2masn[g] + udp[g]
# M13N14N3T4g: l4fn4m2masn[g] + uacgam[g] --> h[g] + nbl4fn4m2masn[g] + udp[g]
# M13N2Tg: m4masn[g] + uacgam[g] --> h[g] + nm4masn[g] + udp[g]
# M13N4T1g: fn2m2masn[g] + uacgam[g] --> fn3m2masn[g] + h[g] + udp[g]
# M13N4T2g: n3rm2masn[g] + uacgam[g] --> h[g] + n4m2masn[g] + udp[g]
# M13N4T3g: fn3rm2masn[g] + uacgam[g] --> fn4m2masn[g] + h[g] + udp[g]
# M13N4Tg: n2m2masn[g] + uacgam[g] --> h[g] + n3m2masn[g] + udp[g]
# M14NTg: n2m2masn[g] + uacgam[g] --> h[g] + n2m2nmasn[g] + udp[g]
# M1613N1614N3T1g: l4n4m2masn[g] + 2.0 uacgam[g] --> 2.0 h[g] + n2bdl4n4m2masn[g] + 2.0 udp[g]
# M1613N1614N3T2g: l4fn4m2masn[g] + 2.0 uacgam[g] --> 2.0 h[g] + n2bdl4fn4m2masn[g] + 2.0 udp[g]
# M1613N3xN3T1g: l4n4m2masn[g] + 3.0 uacgam[g] --> 3.0 h[g] + n3l4n4m2masn[g] + 3.0 udp[g]
# M1613N3xN3T2g: l4fn4m2masn[g] + 3.0 uacgam[g] --> 3.0 h[g] + n3l4fn4m2masn[g] + 3.0 udp[g]
# M16N1216N3T1g: l4n4m2masn[g] + 2.0 uacgam[g] --> 2.0 h[g] + n2cdl4n4m2masn[g] + 2.0 udp[g]
# M16N1216N3T2g: l4fn4m2masn[g] + 2.0 uacgam[g] --> 2.0 h[g] + n2cdl4fn4m2masn[g] + 2.0 udp[g]
# M16N12N3T1g: l4n4m2masn[g] + uacgam[g] --> h[g] + ncl4n4m2masn[g] + udp[g]
# M16N12N3T2g: l4fn4m2masn[g] + uacgam[g] --> h[g] + ncl4fn4m2masn[g] + udp[g]
# M16N16N3T1g: l4n4m2masn[g] + uacgam[g] --> h[g] + ndl4n4m2masn[g] + udp[g]
# M16N16N3T2g: l4fn4m2masn[g] + uacgam[g] --> h[g] + ndl4fn4m2masn[g] + udp[g]
# M16N4Tg: n4m2masn[g] + uacgam[g] --> h[g] + n5m2masn[g] + udp[g]
# M16N4Tg_new1: l5fn4m2masn[g] + uacgam[g] --> h[g] + l5fn5m2masn[g] + udp[g]
# M16N4Tg_new2: l6fn4m2masn[g] + 2.0 uacgam[g] --> 2.0 h[g] + l6fn6m2masn[g] + 2.0 udp[g]
# M16N6T1g: fn3m2masn[g] + uacgam[g] --> fn4m2masn[g] + h[g] + udp[g]
# M16N6T2g: n2m2masn[g] + uacgam[g] --> h[g] + n3rm2masn[g] + udp[g]
# M16N6T3g: fn2m2masn[g] + uacgam[g] --> fn3rm2masn[g] + h[g] + udp[g]
# M16N6Tg: n3m2masn[g] + uacgam[g] --> h[g] + n4m2masn[g] + udp[g]
# M16NT1g: fnm2masn[g] + uacgam[g] --> fn2m2masn[g] + h[g] + udp[g]
# M16NTg: nm2masn[g] + uacgam[g] --> h[g] + n2m2masn[g] + udp[g]
# M4MPDOL_ter: m4mpdol[c] --> m4mpdol[r]
# M7MASNBterg: m7masnB[r] --> m7masnB[g]
# M8MASNterg: m8masn[r] --> m8masn[g]
# MAN1_6B1er: g1m7masnC[r] + h2o[r] --> g1m6masnB1[r] + man[r]
# MAN1_7Ber: g1m8masn[r] + h2o[r] --> g1m7masnB[r] + man[r]
# MAN2_6B1er: g1m7masnB[r] + h2o[r] --> g1m6masnB1[r] + man[r]
# MAN2_7Cer: g1m8masn[r] + h2o[r] --> g1m7masnC[r] + man[r]
# MG1er: g3m8masn[r] + h2o[r] --> g2m8masn[r] + glc_D[r]
# MG2er: g2m8masn[r] + h2o[r] --> g1m8masn[r] + glc_D[r]
# MG3er: g1m8masn[r] + h2o[r] --> glc_D[r] + m8masn[r]
# MM5ag: h2o[g] + m5masnC[g] --> m4masn[g] + man[g]
# MM5bg: h2o[g] + m5masnB1[g] --> m4masn[g] + man[g]
# MM5cg: h2o[g] + m5masnB2[g] --> m4masn[g] + man[g]
# MM6ag: h2o[g] + m6masnA[g] --> m5masnC[g] + man[g]
# MM6B1ag: h2o[g] + m6masnB1[g] --> m5masnB1[g] + man[g]
# MM6B1bg: h2o[g] + m6masnB2[g] --> m5masnB1[g] + man[g]
# MM6B2g: h2o[g] + m6masnB2[g] --> m5masnB2[g] + man[g]
# MM6bg: h2o[g] + m6masnC[g] --> m5masnC[g] + man[g]
# MM7Ag: h2o[g] + m7masnA[g] --> m6masnA[g] + man[g]
# MM7B1g: h2o[g] + m7masnB[g] --> m6masnB1[g] + man[g]
# MM7B2g: h2o[g] + m7masnB[g] --> m6masnB2[g] + man[g]
# MM7Cag: h2o[g] + m7masnA[g] --> m6masnC[g] + man[g]
# MM7Cbg: h2o[g] + m7masnC[g] --> m6masnC[g] + man[g]
# MM8Ag: h2o[g] + m8masn[g] --> m7masnA[g] + man[g]
# MM8Ber: h2o[r] + m8masn[r] --> m7masnB[r] + man[r]
# MM8Cg: h2o[g] + m8masn[g] --> m7masnC[g] + man[g]
# N3Tg: Tn_antigen[g] + udpgal[g] --> T_antigen[g] + h[g] + udp[g]
# N4Tg: core6[g] + udpgal[g] --> f1a[g] + h[g] + udp[g]
# NACHEX10ly: 2.0 h2o[l] + ksi_deg7[l] --> 2.0 acgam[l] + ksi_deg8[l]
# NACHEX11ly: h2o[l] + ksi_deg10[l] --> acgam[l] + ksi_deg11[l]
# NACHEX12ly: h2o[l] + ksi_deg13[l] --> acgam[l] + ksi_deg14[l]
# NACHEX13ly: h2o[l] + ksi_deg16[l] --> acgam[l] + ksi_deg17[l]
# NACHEX14ly: h2o[l] + ksi_deg19[l] --> acgam[l] + ksi_deg20[l]
# NACHEX15ly: h2o[l] + ksi_deg22[l] --> acgam[l] + ksi_deg23[l]
# NACHEX16ly: h2o[l] + ksi_deg25[l] --> acgam[l] + ksi_deg26[l]
# NACHEX17ly: h2o[l] + ksi_deg28[l] --> acgam[l] + ksi_deg29[l]
# NACHEX18ly: h2o[l] + ksi_deg31[l] --> acgam[l] + ksi_deg32[l]
# NACHEX19ly: h2o[l] + ksi_deg34[l] --> acgam[l] + ksi_deg35[l]
# NACHEX1ly: cs_a_deg1[l] + h2o[l] --> acgal[l] + cs_a_deg2[l]
# NACHEX20ly: h2o[l] + ksi_deg37[l] --> acgam[l] + ksi_deg38[l]
# NACHEX21ly: h2o[l] + ksi_deg39[l] --> acgam[l] + ksi_deg40[l]
# NACHEX22ly: h2o[l] + ksi_deg41[l] --> acgam[l] + m2mn[l]
# NACHEX23ly: h2o[l] + ksii_core2_deg4[l] --> acgam[l] + ksii_core2_deg5[l]
# NACHEX24ly: h2o[l] + ksii_core2_deg7[l] --> acgam[l] + ksii_core2_deg8[l]
# NACHEX25ly: h2o[l] + ksii_core2_deg9[l] --> acgam[l] + f1a[l]
# NACHEX26ly: 2.0 h2o[l] + ksii_core4_deg4[l] --> 2.0 acgam[l] + ksii_core2_deg5[l]
# NACHEX27ly: h2o[l] + ha_deg1[l] --> acgam[l] + ha_pre1[l]
# NACHEX2ly: cs_a_deg4[l] + h2o[l] --> acgal[l] + cs_a_deg5[l]
# NACHEX3ly: cs_b_deg1[l] + h2o[l] --> acgal[l] + cs_b_deg2[l]
# NACHEX4ly: cs_c_deg1[l] + h2o[l] --> acgal[l] + cs_c_deg2[l]
# NACHEX5ly: cs_c_deg4[l] + h2o[l] --> acgal[l] + cs_c_deg5[l]
# NACHEX6ly: cs_d_deg1[l] + h2o[l] --> acgal[l] + cs_d_deg2[l]
# NACHEX7ly: cs_d_deg5[l] + h2o[l] --> acgal[l] + cs_d_deg6[l]
# NACHEX8ly: cs_e_deg2[l] + h2o[l] --> acgal[l] + cs_e_deg3[l]
# NACHEX9ly: cs_e_deg6[l] + h2o[l] --> acgal[l] + cs_e_deg7[l]
# NAGA2ly: Tn_antigen[l] + h[l] + udp[l] --> Ser_Thr[l] + udpacgal[l]
# NAGLCAly: core6[l] + h2o[l] --> Tn_antigen[l] + acgam[l]
# NS26T2g: cmpacna[g] + sT_antigen[g] --> cmp[g] + dsT_antigen[g] + h[g]
# NS26Tg: Tn_antigen[g] + cmpacna[g] --> cmp[g] + h[g] + sTn_antigen[g]
# S16Tg_1: cmpacna[g] + l2n2m2masn[g] --> cmp[g] + h[g] + sl2n2m2masn[g]
# S23T2g: cmpacna[g] + core2[g] --> cmp[g] + h[g] + ksii_core2_pre1[g]
# S23T3g: cmpacna[g] + l2fn2m2masn[g] --> cmp[g] + h[g] + ksi_pre1[g]
# S23T4g: cmpacna[g] + ksii_core4_pre1[g] --> cmp[g] + h[g] + ksii_core4_pre2[g]
# S23Tg: T_antigen[g] + cmpacna[g] --> cmp[g] + h[g] + sT_antigen[g]
# S23TN10g: 3.0 cmpacna[g] + lnl3fn3m2masn[g] --> 3.0 cmp[g] + 3.0 h[g] + s3lnl3fn3m2masn[g]
# S23TN11g: 4.0 cmpacna[g] + lndl4fn4m2masn[g] --> 4.0 cmp[g] + 4.0 h[g] + s4lndl4fn4m2masn[g]
# S23TN12g: 4.0 cmpacna[g] + lndl4n4m2masn[g] --> 4.0 cmp[g] + 4.0 h[g] + s4lndl4n4m2masn[g]
# S23TN13g: 4.0 cmpacna[g] + lncl4fn4m2masn[g] --> 4.0 cmp[g] + 4.0 h[g] + s4lncl4fn4m2masn[g]
# S23TN14g: 4.0 cmpacna[g] + lncl4n4m2masn[g] --> 4.0 cmp[g] + 4.0 h[g] + s4lncl4n4m2masn[g]
# S23TN15g: 4.0 cmpacna[g] + lnbl4fn4m2masn[g] --> 4.0 cmp[g] + 4.0 h[g] + s4lnbl4fn4m2masn[g]
# S23TN16g: 4.0 cmpacna[g] + lnbl4n4m2masn[g] --> 4.0 cmp[g] + 4.0 h[g] + s4lnbl4n4m2masn[g]
# S23TN17g: 4.0 cmpacna[g] + l2n2cdl4fn4m2masn[g] --> 4.0 cmp[g] + 4.0 h[g] + s4l2n2cdl4fn4m2masn[g]
# S23TN18g: 4.0 cmpacna[g] + l2n2cdl4n4m2masn[g] --> 4.0 cmp[g] + 4.0 h[g] + s4l2n2cdl4n4m2masn[g]
# S23TN19g: 4.0 cmpacna[g] + l2n2bdl4fn4m2masn[g] --> 4.0 cmp[g] + 4.0 h[g] + s4l2n2bdl4fn4m2masn[g]
# S23TN20g: 4.0 cmpacna[g] + l2n2bdl4n4m2masn[g] --> 4.0 cmp[g] + 4.0 h[g] + s4l2n2bdl4n4m2masn[g]
# S23TN21g: 4.0 cmpacna[g] + l3n3l4fn4m2masn[g] --> 4.0 cmp[g] + 4.0 h[g] + s4l3n3l4fn4m2masn[g]
# S23TN22g: 4.0 cmpacna[g] + l3n3l4n4m2masn[g] --> 4.0 cmp[g] + 4.0 h[g] + s4l3n3l4n4m2masn[g]
# S23TN2g: 2.0 cmpacna[g] + l2n2m2masn[g] --> 2.0 cmp[g] + 2.0 h[g] + s2l2n2m2masn[g]
# S23TN3g: 3.0 cmpacna[g] + l3n3m2masn[g] --> 3.0 cmp[g] + 3.0 h[g] + s3l3n3m2masn[g]
# S23TN4g: 3.0 cmpacna[g] + l3n3rm2masn[g] --> 3.0 cmp[g] + 3.0 h[g] + s3l3n3rm2masn[g]
# S23TN5g: 3.0 cmpacna[g] + l3fn3m2masn[g] --> 3.0 cmp[g] + 3.0 h[g] + s3l3fn3m2masn[g]
# S23TN6g: 3.0 cmpacna[g] + l3fn3rm2masn[g] --> 3.0 cmp[g] + 3.0 h[g] + s3l3fn3rm2masn[g]
# S23TN7g: 4.0 cmpacna[g] + l4fn4m2masn[g] --> 4.0 cmp[g] + 4.0 h[g] + s4l4fn4m2masn[g]
# S23TN8g: 3.0 cmpacna[g] + lnl3n3m2masn[g] --> 3.0 cmp[g] + 3.0 h[g] + s3lnl3n3m2masn[g]
# S23TN9g: 4.0 cmpacna[g] + l4n4m2masn[g] --> 4.0 cmp[g] + 4.0 h[g] + s4l4n4m2masn[g]
# S26Tg: 2.0 cmpacna[g] + l2fn2m2masn[g] --> 2.0 cmp[g] + 2.0 h[g] + s2l2fn2m2masn[g]
# S2T1g: cs_c_d_e_pre1[g] + paps[g] --> cs_d_pre2[g] + h[g] + pap[g]
# S2T2g: cs_d_pre5[g] + paps[g] --> cspg_d[g] + h[g] + pap[g]
# S2T3g: cs_b_pre5[g] + paps[g] --> cspg_b[g] + h[g] + pap[g]
# S2T4g: hs_pre11[g] + 2.0 paps[g] --> 2.0 h[g] + hs_pre12[g] + 2.0 pap[g]
# S2TASE1ly: h2o[l] + hs_deg15[l] --> h[l] + hs_deg16[l] + so4[l]
# S2TASE2ly: h2o[l] + hs_deg21[l] --> h[l] + hs_deg22[l] + so4[l]
# S2TASE3ly: cs_b_deg2[l] + h2o[l] --> cs_b_deg3[l] + h[l] + so4[l]
# S2TASE4ly: cs_d_deg2[l] + h2o[l] --> cs_d_deg3[l] + h[l] + so4[l]
# S2TASE5ly: cs_d_deg6[l] + h2o[l] --> cs_c_deg5[l] + h[l] + so4[l]
# S3T1g: hs_pre13[g] + paps[g] --> h[g] + hs_pre14[g] + pap[g]
# S3T2g: hs_pre14[g] + paps[g] --> h[g] + hs_pre15[g] + pap[g]
# S3T3g: hs_pre15[g] + paps[g] --> h[g] + hspg[g] + pap[g]
# S3TASE1ly: h2o[l] + hs_deg10[l] <=> h[l] + hs_deg11[l] + so4[l]
# S3TASE2ly: h2o[l] + hs_deg17[l] <=> h[l] + hs_deg18[l] + so4[l]
# S3TASE3ly: h2o[l] + hs_deg23[l] <=> h[l] + hs_deg24[l] + so4[l]
# S4T1g: cs_pre[g] + 2.0 paps[g] --> cs_a_b_e_pre1[g] + 2.0 h[g] + 2.0 pap[g]
# S4T2g: cs_a_b_pre3[g] + paps[g] --> cspg_a[g] + h[g] + pap[g]
# S4T3g: cs_e_pre4[g] + paps[g] --> cs_e_pre5a[g] + h[g] + pap[g]
# S4T4g: cs_c_d_e_pre1[g] + 2.0 paps[g] --> cs_e_pre2[g] + 2.0 h[g] + 2.0 pap[g]
# S4T5g: cs_e_pre5b[g] + paps[g] --> cspg_e[g] + h[g] + pap[g]
# S4T6g: cs_b_pre4[g] + paps[g] --> cs_b_pre5[g] + h[g] + pap[g]
# S4TASE1ly: cs_a[l] + h2o[l] <=> cs_a_deg1[l] + h[l] + so4[l]
# S4TASE2ly: cs_a_deg3[l] + h2o[l] <=> cs_a_deg4[l] + h[l] + so4[l]
# S4TASE3ly: cs_b[l] + h2o[l] <=> cs_b_deg1[l] + h[l] + so4[l]
# S4TASE4ly: cs_e[l] + h2o[l] <=> cs_e_deg1[l] + h[l] + so4[l]
# S4TASE5ly: cs_e_deg4[l] + h2o[l] <=> cs_e_deg5[l] + h[l] + so4[l]
# S6T10g: ksi_pre22[g] + paps[g] --> h[g] + ksi_pre23[g] + pap[g]
# S6T11g: ksi_pre25[g] + paps[g] --> h[g] + ksi_pre26[g] + pap[g]
# S6T12g: ksi_pre28[g] + paps[g] --> h[g] + ksi_pre29[g] + pap[g]
# S6T13g: ksi_pre31[g] + paps[g] --> h[g] + ksi_pre32[g] + pap[g]
# S6T14g: ksi_pre34[g] + paps[g] --> h[g] + ksi_pre35[g] + pap[g]
# S6T15g: ksi_pre36[g] + paps[g] --> h[g] + ksi[g] + pap[g]
# S6T16g: ksii_core4_pre5[g] + paps[g] --> h[g] + ksii_core4_pre6[g] + pap[g]
# S6T17g: ksii_core4_pre8[g] + paps[g] --> h[g] + ksii_core4_pre9[g] + pap[g]
# S6T18g: ksii_core4_pre10[g] + paps[g] --> h[g] + ksii_core4[g] + pap[g]
# S6T19g: cs_pre[g] + 2.0 paps[g] --> cs_c_d_e_pre1[g] + 2.0 h[g] + 2.0 pap[g]
# S6T1g: ksii_core2_pre5[g] + paps[g] --> h[g] + ksii_core2_pre6[g] + pap[g]
# S6T20g: cs_c_pre3[g] + paps[g] --> cspg_c[g] + h[g] + pap[g]
# S6T21g: cs_d_pre4[g] + paps[g] --> cs_d_pre5[g] + h[g] + pap[g]
# S6T22g: cs_a_b_e_pre1[g] + 2.0 paps[g] --> cs_e_pre2[g] + 2.0 h[g] + 2.0 pap[g]
# S6T23g: cs_e_pre5a[g] + paps[g] --> cspg_e[g] + h[g] + pap[g]
# S6T24g: cs_e_pre4[g] + paps[g] --> cs_e_pre5b[g] + h[g] + pap[g]
# S6T25g: hs_pre12[g] + 3.0 paps[g] --> 3.0 h[g] + hs_pre13[g] + 3.0 pap[g]
# S6T2g: ksii_core2_pre8[g] + paps[g] --> h[g] + ksii_core2_pre9[g] + pap[g]
# S6T3g: ksii_core2_pre10[g] + paps[g] --> h[g] + ksii_core2[g] + pap[g]
# S6T4g: ksi_pre4[g] + paps[g] --> h[g] + ksi_pre5[g] + pap[g]
# S6T5g: ksi_pre7[g] + paps[g] --> h[g] + ksi_pre8[g] + pap[g]
# S6T6g: ksi_pre10[g] + paps[g] --> h[g] + ksi_pre11[g] + pap[g]
# S6T7g: ksi_pre13[g] + paps[g] --> h[g] + ksi_pre14[g] + pap[g]
# S6T8g: ksi_pre16[g] + paps[g] --> h[g] + ksi_pre17[g] + pap[g]
# S6T9g: ksi_pre19[g] + paps[g] --> h[g] + ksi_pre20[g] + pap[g]
# S6TASE10ly: h2o[l] + ksi_deg4[l] --> h[l] + ksi_deg5[l] + so4[l]
# S6TASE11ly: h2o[l] + ksi_deg6[l] --> h[l] + ksi_deg7[l] + so4[l]
# S6TASE12ly: h2o[l] + ksi_deg9[l] --> h[l] + ksi_deg10[l] + so4[l]
# S6TASE13ly: h2o[l] + ksi_deg12[l] --> h[l] + ksi_deg13[l] + so4[l]
# S6TASE14ly: h2o[l] + ksi_deg15[l] --> h[l] + ksi_deg16[l] + so4[l]
# S6TASE15ly: h2o[l] + ksi_deg18[l] --> h[l] + ksi_deg19[l] + so4[l]
# S6TASE16ly: h2o[l] + ksi_deg21[l] --> h[l] + ksi_deg22[l] + so4[l]
# S6TASE17ly: h2o[l] + ksi_deg24[l] --> h[l] + ksi_deg25[l] + so4[l]
# S6TASE18ly: h2o[l] + ksi_deg27[l] --> h[l] + ksi_deg28[l] + so4[l]
# S6TASE19ly: h2o[l] + ksi_deg30[l] --> h[l] + ksi_deg31[l] + so4[l]
# S6TASE1ly: h2o[l] + hs[l] <=> h[l] + hs_deg1[l] + so4[l]
# S6TASE20ly: h2o[l] + ksi_deg33[l] --> h[l] + ksi_deg34[l] + so4[l]
# S6TASE21ly: h2o[l] + ksi_deg36[l] --> h[l] + ksi_deg37[l] + so4[l]
# S6TASE22ly: h2o[l] + ksii_core2_deg1[l] <=> h[l] + ksii_core2_deg2[l] + so4[l]
# S6TASE23ly: h2o[l] + ksii_core2_deg3[l] <=> h[l] + ksii_core2_deg4[l] + so4[l]
# S6TASE24ly: h2o[l] + ksii_core2_deg6[l] <=> h[l] + ksii_core2_deg7[l] + so4[l]
# S6TASE25ly: h2o[l] + ksii_core4_deg1[l] <=> h[l] + ksii_core4_deg2[l] + so4[l]
# S6TASE26ly: h2o[l] + ksii_core4_deg3[l] <=> h[l] + ksii_core4_deg4[l] + so4[l]
# S6TASE2ly: h2o[l] + hs_deg5[l] <=> h[l] + hs_deg6[l] + so4[l]
# S6TASE3ly: h2o[l] + hs_deg11[l] <=> h[l] + hs_deg12[l] + so4[l]
# S6TASE4ly: cs_c[l] + h2o[l] <=> cs_c_deg1[l] + h[l] + so4[l]
# S6TASE5ly: cs_c_deg3[l] + h2o[l] <=> cs_c_deg4[l] + h[l] + so4[l]
# S6TASE6ly: cs_d[l] + h2o[l] <=> cs_d_deg1[l] + h[l] + so4[l]
# S6TASE7ly: cs_d_deg4[l] + h2o[l] <=> cs_d_deg5[l] + h[l] + so4[l]
# S6TASE8ly: cs_e_deg1[l] + h2o[l] <=> cs_e_deg2[l] + h[l] + so4[l]
# S6TASE9ly: cs_e_deg5[l] + h2o[l] <=> cs_e_deg6[l] + h[l] + so4[l]
# SIAASE: 2.0 h2o[c] + s2l2n2m2mn[c] --> 2.0 acnam[c] + l2n2m2mn[c]
# SIAASE2ly: h2o[l] + ksi_deg3[l] --> acnam[l] + ksi_deg4[l]
# SIAASE3ly: h2o[l] + ksii_core2[l] --> acnam[l] + ksii_core2_deg1[l]
# SIAASE4ly: h2o[l] + ksii_core4[l] --> acnam[l] + ksii_core4_deg1[l]
# SIAASEly: 2.0 h2o[l] + s2l2n2m2mn[l] --> 2.0 acnam[l] + l2n2m2mn[l]
# ST3GAL31g: cmpacna[g] + galacglcgalgluside_cho[g] --> acngalacglcgalgluside_cho[g] + cmp[g] + h[g]
# ST3GAL61g: cmpacna[g] + gal14acglcgalgluside_cho[g] --> acngal14acglcgalgluside_cho[g] + cmp[g] + h[g]
# ST3GAL62g: cmpacna[g] + galacglcgal14acglcgalgluside_cho[g] --> acngalacglcgal14acglcgalgluside_cho[g] + cmp[g] + h[g]
# ST8SIA56g: acngal14acglcgalgluside_cho[g] + cmpacna[g] --> acnacngal14acglcgalgluside_cho[g] + cmp[g] + h[g]
# UDPDOLPT: dolp[c] + udpg[c] --> dolglcp[c] + udp[c]
# XYLTer: Ser_Gly_Ala_X_Gly[r] + udpxyl[r] --> h[r] + udp[r] + xser[r]
# GLCNCTg: Ser_Thr[g] + uacgam[g] --> h[g] + oglcnc_ser_thr[g] + udp[g]
# OGLNA: h2o[g] + oglcnc_ser_thr[g] --> Ser_Thr[g] + acgam[g]
# HYAL: 4.0 h2o[l] + ha[l] --> 2.0 acgam[l] + 2.0 glcur[l]
# HYALe: 4.0 h2o[e] + ha[e] --> 2.0 acgam[e] + 2.0 glcur[e]
# GDPFPOFTr: Ser_Thr[r] + gdpfuc[r] --> fser[r] + gdp[r] + h[r]
# UPDGOFUCBGTr: fser[r] + udpg[r] --> gfser[r] + h[r] + udp[r]
# FSERterg: fser[r] --> fser[g]
# OFPGLCNACTg: fser[g] + uacgam[g] --> h[g] + nfser[g] + udp[g]
# GNOFPGALTg: nfser[g] + udpgal[g] --> h[g] + lnfser[g] + udp[g]
# ST6GALGNFTg: cmpacna[g] + lnfser[g] --> cmp[g] + slnfser[g]
# POGLUTr: Ser_Thr[r] + udpg[r] --> gser[r] + udp[r]
# GXYLTr: gser[r] + udpxyl[r] --> udp[r] + xgser[r]
# DOLPOMTr: Ser_Thr[r] + dolmanp[r] --> dolp[r] + h[r] + mser[r]
# POMGNTr: mser[r] + uacgam[r] --> n(m)ser[r] + udp[r]
# POMGNGALNTr: n(m)ser[r] + udpacgal[r] --> corem3[r] + udp[r]
# POMKr: atp[r] + corem3[r] --> adp[r] + pcorem3[r]
# RBT5PCYTr: ctp[c] + rbt5p[c] --> cdprbtl[c] + ppi[c]
# PCOREM3terg: pcorem3[r] --> pcorem3[g]
# POCDPRBTLTg: cdprbtl[g] + pcorem3[g] --> cdp[g] + rbtlpgalnmser[g]
# POCDPRBTLT2g: cdprbtl[g] + rbtlpgalnmser[g] --> cdp[g] + rbtlprbtlpgalnmser[g]
# POXYLTg: rbtlprbtlpgalnmser[g] + udpxyl[g] --> udp[g] + xylrbtlprbtlpgalnmser[g]
# POGLCNACTg: uacgam[g] + xylrbtlprbtlpgalnmser[g] --> nxylrbtlprbtlpgalnmser[g] + udp[g]
# LARGEg: nxylrbtlprbtlpgalnmser[g] + udpxyl[g] --> adystroglycan[g] + udp[g]
# MSERterg: mser[r] --> mser[g]
# POMGNT2g: mser[g] + uacgam[g] --> nmser[g] + udp[g]
# GNOFGALTg: nmser[g] + udpgal[g] --> corem1[g] + udp[g]
# MNSERGALTg: nmser[g] + uacgam[g] --> n2mser[g] + udp[g]
# GNOFPGALT2g: n2mser[g] + udpgal[g] --> corem2[g] + udp[g]
# GGTA1g: galacglcgalgluside_cho[g] + udpacgal[g] --> acgalgalacglcgalgluside_cho[g] + h[g] + udp[g]
# FUT121g: acgalgalacglcgalgluside_cho[g] + gdpfuc[g] --> acgalfucgalacglcgalgluside_cho[g] + gdp[g] + h[g]
# GNPT: m4masn[l] + uacgam[l] --> h[l] + nm4masn[l] + udp[l]
# NAGPA: h2o[l] + nm4masn[l] --> acgam[l] + m4masn[l]

# %% [markdown]
# If we wanted to understand the metabolites in these reactions we could print something like this:

# %%
for r in model.reactions:
    if r.subsystem == 'Glycan and glycosaminoglycan metabolism':
        print(r.id)
        for m in r.metabolites:
            print(m.name)
        print('\n')
# Out:
# A_MANASE
# H2O
# (alpha-D-mannosyl)2-beta-D-mannosyl-N-acetylglucosamine
# D-Mannose
# beta-1,4-mannose-N-acetylglucosamine
#
#
# A_MANASEly
# H2O
# (alpha-D-mannosyl)2-beta-D-mannosyl-N-acetylglucosamine
# beta-1,4-mannose-N-acetylglucosamine
# D-Mannose
#
#
# A4GNT1g
# UDP-N-acetyl-alpha-D-glucosamine(2-)
# T antigen (core 1)
# proton
# UDP
# GlcNAc-alpha-1,4-Core 1
#
#
# A4GNT2g
# UDP-N-acetyl-alpha-D-glucosamine(2-)
# Core 2
# proton
# UDP
# GlcNAc-alpha-1,4-Core 2
#
#
# ABO1g
# UDP-N-acetyl-D-galactosamine(2-)
# Type IH glycolipid
# proton
# UDP
# Type IA glycolipid
#
#
# ABO2g
# UDP-D-galactose(2-)
# Type IH glycolipid
# proton
# UDP
# Type IB glycolipid
#
#
# ABO3g
# UDP-D-galactose(2-)
# Type IIH glycolipid
# proton
# UDP
# (Gal)3 (Glc)1 (GlcNAc)1 (LFuc)1 (Cer)1
#
#
# ABO4g
# UDP-N-acetyl-D-galactosamine(2-)
# Type IIH glycolipid
# proton
# UDP
# (Gal)2 (GalNAc)1 (Glc)1 (GlcNAc)1 (LFuc)1 (Cer)1
#
#
# ABO5g
# UDP-N-acetyl-D-galactosamine(2-)
# Type IIIH glycolipid
# proton
# UDP
# Type IIIA glycolipid
#
#
# ABO6g
# UDP-N-acetyl-D-galactosamine(2-)
# VI2Fuc-nLc6
# proton
# UDP
# (Gal)3 (GalNAc)1 (Glc)1 (GlcNAc)2 (LFuc)1 (Cer)1
#
#
# ABO7g
# UDP-N-acetyl-D-galactosamine(2-)
# (Gal)4 (GalNAc)1 (Glc)1 (GlcNAc)2 (LFuc)2 (Cer)1
# proton
# UDP
# Type IIIAb
#
#
# ABO8g
# UDP-D-galactose(2-)
# VI2Fuc-nLc6
# proton
# UDP
# (Gal)4 (Glc)1 (GlcNAc)2 (LFuc)1 (Cer)1
#
#
# ABO9g
# UDP-D-galactose(2-)
# (Gal)4 (Glc)1 (GlcNAc)3 (LFuc)2 (Cer)1
# proton
# UDP
# (Gal)6 (Glc)1 (GlcNAc)3 (LFuc)2 (Cer)1
#
#
# AG13T10g
# UDP-N-acetyl-alpha-D-glucosamine(2-)
# keratan sulfate I biosynthesis, precursor 18
# proton
# UDP
# keratan sulfate I biosynthesis, precursor 19
#
#
# AG13T11g
# UDP-N-acetyl-alpha-D-glucosamine(2-)
# keratan sulfate I biosynthesis, precursor 21
# proton
# UDP
# keratan sulfate I biosynthesis, precursor 22
#
#
# AG13T12g
# UDP-N-acetyl-alpha-D-glucosamine(2-)
# keratan sulfate I biosynthesis, precursor 24
# proton
# UDP
# keratan sulfate I biosynthesis, precursor 25
#
#
# AG13T13g
# UDP-N-acetyl-alpha-D-glucosamine(2-)
# keratan sulfate I biosynthesis, precursor 27
# proton
# UDP
# keratan sulfate I biosynthesis, precursor 28
#
#
# AG13T14g
# UDP-N-acetyl-alpha-D-glucosamine(2-)
# keratan sulfate I biosynthesis, precursor 30
# proton
# UDP
# keratan sulfate I biosynthesis, precursor 31
#
#
# AG13T15g
# UDP-N-acetyl-alpha-D-glucosamine(2-)
# keratan sulfate I biosynthesis, precursor 33
# proton
# UDP
# keratan sulfate I biosynthesis, precursor 34
#
#
# AG13T16g
# UDP-N-acetyl-alpha-D-glucosamine(2-)
# keratan sulfate II boisynthesis, precursor 2
# proton
# UDP
# keratan sulfate II biosynthesis, precursor 3
#
#
# AG13T17g
# UDP-N-acetyl-alpha-D-glucosamine(2-)
# keratan sulfate II biosynthesis, precursor 4
# proton
# UDP
# keratan sulfate II biosynthesis, precursor 5
#
#
# AG13T18g
# UDP-N-acetyl-alpha-D-glucosamine(2-)
# keratan sulfate II biosynthesis, precursor 7
# proton
# UDP
# keratan sulfate II biosynthesis, precursor 8
#
#
# AG13T1g
# UDP-N-acetyl-alpha-D-glucosamine(2-)
# keratan sulfate II biosynthesis, precursor 2
# proton
# UDP
# keratan sulfate II biosynthesis, precursor 3
#
#
# AG13T2g
# UDP-N-acetyl-alpha-D-glucosamine(2-)
# keratan sulfate II biosynthesis, precursor 4
# proton
# UDP
# keratan sulfate II biosynthesis, precursor 5
#
#
# AG13T3g
# UDP-N-acetyl-alpha-D-glucosamine(2-)
# keratan sulfate II biosynthesis, precursor 7
# proton
# UDP
# keratan sulfate II biosynthesis, precursor 8
#
#
# AG13T4g
# UDP-N-acetyl-alpha-D-glucosamine(2-)
# keratan sulfate I biosynthesis, precursor 1
# proton
# UDP
# keratan sulfate I biosynthesis, precursor 2
#
#
# AG13T5g
# UDP-N-acetyl-alpha-D-glucosamine(2-)
# keratan sulfate I biosynthesis, precursor 3
# proton
# UDP
# keratan sulfate I biosynthesis, precursor 4
#
#
# AG13T6g
# UDP-N-acetyl-alpha-D-glucosamine(2-)
# keratan sulfate I biosynthesis, precursor 6
# proton
# UDP
# keratan sulfate I biosynthesis, precursor 7
#
#
# AG13T7g
# UDP-N-acetyl-alpha-D-glucosamine(2-)
# keratan sulfate I biosynthesis, precursor 9
# proton
# UDP
# keratan sulfate I biosynthesis, precursor 10
#
#
# AG13T8g
# UDP-N-acetyl-alpha-D-glucosamine(2-)
# keratan sulfate I biosynthesis, precursor 12
# proton
# UDP
# keratan sulfate I biosynthesis, precursor 13
#
#
# AG13T9g
# UDP-N-acetyl-alpha-D-glucosamine(2-)
# keratan sulfate I biosynthesis, precursor 15
# proton
# UDP
# keratan sulfate I biosynthesis, precursor 16
#
#
# AHEXASE2ly
# H2O
# reducing GlcNAc removed form of n2m2nmasn (w/o peptide)
# (alpha-D-mannosyl)2-beta-D-mannosyl-N-acetylglucosamine
# N-acetyl-D-glucosamine
#
#
# AHEXASEly
# H2O
# de-Fuc, reducing GlcNAc removed, de-Sia, de-Gal form of PA6 (w/o peptide linkage)
# (alpha-D-mannosyl)2-beta-D-mannosyl-N-acetylglucosamine
# N-acetyl-D-glucosamine
#
#
# B_MANNASEly
# H2O
# beta-1,4-mannose-N-acetylglucosamine
# D-Mannose
# N-acetyl-D-glucosamine
#
#
# B3GALTg
# UDP-D-galactose(2-)
# N-acetyl-beta-D-glucosaminyl-(1->3)-beta-D-galactosyl-(1->4)-beta-D-glucosylceramide
# proton
# UDP
# Lc4Cer
#
#
# B3GNT11g
# UDP-N-acetyl-alpha-D-glucosamine(2-)
# Lactoneotetraosylceramide
# proton
# UDP
# nLc5Cer
#
#
# B3GNT12g
# UDP-N-acetyl-alpha-D-glucosamine(2-)
# i-antigen
# proton
# UDP
# nLc7Cer
#
#
# B3GNT310g
# UDP-D-galactose(2-)
# N-acetyl-beta-D-glucosaminyl-(1->3)-beta-D-galactosyl-(1->4)-beta-D-glucosylceramide
# proton
# UDP
# Lactoneotetraosylceramide
#
#
# B3GNT311g
# UDP-D-galactose(2-)
# (Gal)2 (GalNAc)1 (Glc)1 (GlcNAc)1 (LFuc)1 (Cer)1
# proton
# UDP
# (Gal)3 (GalNAc)1 (Glc)1 (GlcNAc)1 (LFuc)1 (Cer)1
#
#
# B3GNT312g
# UDP-D-galactose(2-)
# nLc5Cer
# proton
# UDP
# i-antigen
#
#
# B3GNT313g
# UDP-D-galactose(2-)
# (Gal)3 (GalNAc)1 (Glc)1 (GlcNAc)2 (LFuc)1 (Cer)1
# proton
# UDP
# (Gal)4 (GalNAc)1 (Glc)1 (GlcNAc)2 (LFuc)1 (Cer)1
#
#
# B3GNT314g
# UDP-D-galactose(2-)
# (Gal)3 (Glc)1 (GlcNAc)3 (Cer)1
# proton
# UDP
# I-antigen
#
#
# B3GNT315g
# UDP-D-galactose(2-)
# nLc7Cer
# proton
# UDP
# nLc8Cer
#
#
# B3GNT38g
# UDP-D-galactose(2-)
# D-galactosyl-N-acylsphingosine
# proton
# UDP
# Digalactosylceramide
#
#
# B3GNT51g
# galactosyl glucosyl ceramide
# UDP-N-acetyl-alpha-D-glucosamine(2-)
# proton
# UDP
# N-acetyl-beta-D-glucosaminyl-(1->3)-beta-D-galactosyl-(1->4)-beta-D-glucosylceramide
#
#
# BDMT
# N,N'-Diacetylchitobiosyldiphosphodolichol
# GDP-alpha-D-mannose(2-)
# proton
# GDP
# beta-D-Mannosyldiacetylchitobiosyldiphosphodolichol
#
#
# CORE2GTg
# UDP-N-acetyl-alpha-D-glucosamine(2-)
# T antigen (core 1)
# proton
# UDP
# Core 2
#
#
# CORE3GTg
# UDP-N-acetyl-alpha-D-glucosamine(2-)
# Tn antigen
# proton
# UDP
# Core 3
#
#
# CORE4GTg
# UDP-N-acetyl-alpha-D-glucosamine(2-)
# Core 3
# proton
# UDP
# Core 4
#
#
# CORE5GTg
# UDP-N-acetyl-D-galactosamine(2-)
# Tn antigen
# proton
# UDP
# Core 5
#
#
# CORE6GTg
# UDP-N-acetyl-alpha-D-glucosamine(2-)
# Tn antigen
# proton
# UDP
# Core 6
#
#
# CORE7GTg
# UDP-N-acetyl-D-galactosamine(2-)
# Tn antigen
# proton
# UDP
# Core 7
#
#
# CORE8GTg
# UDP-D-galactose(2-)
# Tn antigen
# proton
# UDP
# Core 8
#
#
# CSAPASEly
# H2O
# chondroitin sulfate A (GalNAc4S-GlcA) proteoglycan
# chondroitin sulfate A (GalNAc4S-GlcA), free chain
# protein-linked serine residue (glycosaminoglycan attachment site)
#
#
# CSBPASEly
# H2O
# chondroitin sulfate B / dermatan sulfate (IdoA2S-GalNAc4S) proteoglycan
# protein-linked serine residue (glycosaminoglycan attachment site)
# chondroitin sulfate B / dermatan sulfate (IdoA2S-GalNAc4S), free chain
#
#
# CSCPASEly
# H2O
# chondroitin sulfate C (GalNAc6S-GlcA) proteoglycan
# protein-linked serine residue (glycosaminoglycan attachment site)
# chondroitin sulfate C (GalNAc6S-GlcA), free chain
#
#
# CSDPASEly
# H2O
# chondroitin sulfate D (GlcNAc6S-GlcA2S) proteoglycan
# protein-linked serine residue (glycosaminoglycan attachment site)
# chondroitin sulfate D (GlcNAc6S-GlcA2S), free chain
#
#
# CSEPASEly
# H2O
# chondroitin sulfate E (GalNAc4,6diS-GlcA) proteoglycan
# protein-linked serine residue (glycosaminoglycan attachment site)
# chondroitin sulfate E (GalNAc4,6diS-GlcA), free chain
#
#
# DEDOLP1
# H2O
# Dehydrodolichol diphosphate
# proton
# hydrogenphosphate
# Dehydrodolichol phosphate
#
#
# DEDOLP2
# H2O
# Dehydrodolichol phosphate
# hydrogenphosphate
# Dehydrodolichol
#
#
# DEDOLR
# proton
# NADPH(-4)
# Dehydrodolichol
# NADP(-3)
# Dolichol
#
#
# DHDDS
# Isopentenyl diphosphate
# Farnesyl diphosphate
# Diphosphate(3-)
# Dehydrodolichol diphosphate
#
#
# DOLASNTer
# protein-linked asparagine residue (N-glycosylation site)
# (alpha-D-Glucosyl)3-(alpha-D-mannosyl)8-beta-D-mannosyl-diacetylchitobiosyldiphosphodolichol
# proton
# Dolichol diphosphate
# (alpha-D-Glucosyl)3-(alpha-D-mannosyl)8-beta-D-mannosyl-diacetylchitobiosyl-L-asparagine (protein)
#
#
# DOLDPPer
# H2O
# Dolichol diphosphate
# proton
# dolichyl phosphate(2-)
# hydrogenphosphate
#
#
# DOLGLCP_ter
# Dolichyl beta-D-glucosyl phosphate
# Dolichyl beta-D-glucosyl phosphate
#
#
# DOLGPP_er
# H2O
# Dolichyl beta-D-glucosyl phosphate
# proton
# dolichyl phosphate(2-)
# D-glucose
#
#
# DOLICHOL_ter
# Dolichol
# Dolichol
#
#
# DOLK
# CTP
# Dolichol
# proton
# CDP
# dolichyl phosphate(2-)
#
#
# DOLMANP_ter
# Dolichyl phosphate D-mannose
# Dolichyl phosphate D-mannose
#
#
# DOLP_ter
# dolichyl phosphate(2-)
# dolichyl phosphate(2-)
#
#
# DOLPGT1er
# Dolichyl beta-D-glucosyl phosphate
# (alpha-D-Mannosyl)8-beta-D-mannosyl-diacetylchitobiosyldiphosphodolichol
# proton
# dolichyl phosphate(2-)
# alpha-D-Glucosyl-(alpha-D-mannosyl)8-beta-D-mannosyl-diacetylchitobiosyldiphosphodolichol
#
#
# DOLPGT2er
# Dolichyl beta-D-glucosyl phosphate
# alpha-D-Glucosyl-(alpha-D-mannosyl)8-beta-D-mannosyl-diacetylchitobiosyldiphosphodolichol
# proton
# dolichyl phosphate(2-)
# (alpha-D-Glucosyl)2-(alpha-D-mannosyl)8-beta-D-mannosyl-diacetylchitobiosyldiphosphodolichol
#
#
# DOLPGT3er
# Dolichyl beta-D-glucosyl phosphate
# (alpha-D-Glucosyl)2-(alpha-D-mannosyl)8-beta-D-mannosyl-diacetylchitobiosyldiphosphodolichol
# proton
# dolichyl phosphate(2-)
# (alpha-D-Glucosyl)3-(alpha-D-mannosyl)8-beta-D-mannosyl-diacetylchitobiosyldiphosphodolichol
#
#
# DOLPH_er
# dolichyl phosphate(2-)
# H2O
# hydrogenphosphate
# Dolichol
#
#
# DOLPMT
# GDP-alpha-D-mannose(2-)
# dolichyl phosphate(2-)
# GDP
# Dolichyl phosphate D-mannose
#
#
# DOLPMT1er
# Dolichyl phosphate D-mannose
# (alpha-D-Mannosyl)4-beta-D-mannosyl-diacetylchitobiosyldiphosphodolichol
# proton
# dolichyl phosphate(2-)
# (alpha-D-Mannosyl)5-beta-D-mannosyl-diacetylchitobiosyldiphosphodolichol
#
#
# DOLPMT2_er
# Dolichyl phosphate D-mannose
# (alpha-D-Mannosyl)5-beta-D-mannosyl-diacetylchitobiosyldiphosphodolichol
# proton
# dolichyl phosphate(2-)
# (alpha-D-Mannosyl)6-beta-D-mannosyl-diacetylchitobiosyldiphosphodolichol
#
#
# DOLPMT3er
# Dolichyl phosphate D-mannose
# (alpha-D-Mannosyl)6-beta-D-mannosyl-diacetylchitobiosyldiphosphodolichol
# proton
# dolichyl phosphate(2-)
# (alpha-D-Mannosyl)7-beta-D-mannosyl-diacetylchitobiosyldiphosphodolichol
#
#
# DOLPMT4_er
# Dolichyl phosphate D-mannose
# (alpha-D-Mannosyl)7-beta-D-mannosyl-diacetylchitobiosyldiphosphodolichol
# proton
# dolichyl phosphate(2-)
# (alpha-D-Mannosyl)8-beta-D-mannosyl-diacetylchitobiosyldiphosphodolichol
#
#
# ENGASE
# H2O
# de-Fuc form of PA6 (w/o peptide linkage)
# N-acetyl-D-glucosamine
# de-Fuc, reducing GlcNAc removed form of PA6 (w/o peptide linkage)
#
#
# ENGASE2
# H2O
# n2m2nmasn (w/o peptide linkage)
# N-acetyl-D-glucosamine
# reducing GlcNAc removed form of n2m2nmasn (w/o peptide)
#
#
# ENGASE2ly
# H2O
# n2m2nmasn (w/o peptide linkage)
# N-acetyl-D-glucosamine
# reducing GlcNAc removed form of n2m2nmasn (w/o peptide)
#
#
# ENGASE3ly
# H2O
# keratan sulfate I, degradation product 2
# N-acetyl-D-glucosamine
# keratan sulfate I, degradation product 3
#
#
# ENGASEly
# H2O
# de-Fuc form of PA6 (w/o peptide linkage)
# N-acetyl-D-glucosamine
# de-Fuc, reducing GlcNAc removed form of PA6 (w/o peptide linkage)
#
#
# ENMAN1g
# H2O
# (alpha-D-Glucosyl)-(alpha-D-mannosyl)8-beta-D-mannosyl-diacetylchitobiosyl-L-asparagine (protein)
# (alpha-D-mannosyl)7-beta-D-mannosyl-diacetylchitobiosyl-L-asparagine, isoform A (protein)
# glucose-1,3-mannose oligosaccharide
#
#
# ENMAN2g
# H2O
# (alpha-D-Glucosyl)2-(alpha-D-mannosyl)8-beta-D-mannosyl-diacetylchitobiosyl-L-asparagine (protein)
# (alpha-D-mannosyl)7-beta-D-mannosyl-diacetylchitobiosyl-L-asparagine, isoform A (protein)
# (2)[glucose-1,3]-mannose oligosaccharide
#
#
# ENMAN3g
# H2O
# (alpha-D-Glucosyl)3-(alpha-D-mannosyl)8-beta-D-mannosyl-diacetylchitobiosyl-L-asparagine (protein)
# (alpha-D-mannosyl)7-beta-D-mannosyl-diacetylchitobiosyl-L-asparagine, isoform A (protein)
# glucose-1,2-(2)[glucose-1,3]-mannose oligosaccharide
#
#
# ENMAN4g
# H2O
# glucosyl-(alpha-D-mannosyl)7-beta-D-mannosyl-diacetylchitobiosyl-L-asparagine, isoform C (protein)
# glucose-1,3-mannose oligosaccharide
# (alpha-D-mannosyl)6-beta-D-mannosyl-diacetylchitobiosyl-L-asparagine (protein)
#
#
# ENMAN5g
# H2O
# glucosyl-(alpha-D-mannosyl)7-beta-D-mannosyl-diacetylchitobiosyl-L-asparagine, isoform B (protein)
# glucose-1,3-mannose oligosaccharide
# (alpha-D-mannosyl)6-beta-D-mannosyl-diacetylchitobiosyl-L-asparagine (protein)
#
#
# ENMAN6g
# H2O
# glucosyl-(alpha-D-mannosyl)6-beta-D-mannosyl-diacetylchitobiosyl-L-asparagine (protein)
# glucose-1,3-mannose oligosaccharide
# (alpha-D-mannosyl)5-beta-D-mannosyl-diacetylchitobiosyl-L-asparagine (protein)
#
#
# F6T2g
# (N-acetyl-D-glucosaminyl-(alpha-D-mannosyl)4-beta-D-mannosyl-diacetylchitobiosyl)-L-asparagine (protein)
# GDP-L-fucose(2-)
# proton
# fnm4masn[g]
# GDP
#
#
# F6T3g
# GDP-L-fucose(2-)
# (N-acetyl-D-glucosaminyl-(alpha-D-mannosyl)2-beta-D-mannosyl-diacetylchitobiosyl)-L-asparagine (protein)
# proton
# GDP
# fnm2masn[g]
#
#
# F6T4g
# GDP-L-fucose(2-)
# ((N-acetyl-D-glucosaminyl)3-(alpha-D-mannosyl)2-beta-D-mannosyl-diacetylchitobiosyl)-L-asparagine (protein)
# proton
# GDP
# fn3m2masn[g]
#
#
# F6T5g
# GDP-L-fucose(2-)
# ((N-acetyl-D-glucosaminyl)4-(alpha-D-mannosyl)2-beta-D-mannosyl-diacetylchitobiosyl)-L-asparagine (protein)
# proton
# GDP
# fn4m2masn[g]
#
#
# F6T6g
# GDP-L-fucose(2-)
# n3rm2masn[g]
# proton
# GDP
# fn3rm2masn[g]
#
#
# F6Tg
# GDP-L-fucose(2-)
# ((N-acetyl-D-glucosaminyl)2-(alpha-D-mannosyl)2-beta-D-mannosyl-diacetylchitobiosyl)-L-asparagine (protein)
# proton
# GDP
# N4-{N-Acetyl-beta-D-glucosaminyl-(1,2)-alpha-D-mannosyl-(1,3)-[N-acetyl-beta-D-glucosaminyl-(1,2)-alpha-D-mannosyl-(1,6)]-beta-D-mannosyl-(1,4)-N-acetyl-beta-D-glucosaminyl-(1,4)-[alpha-L-fucosyl-(1,6)]-N-acetyl-beta-D-glucosaminyl}asparagine
#
#
# FUCASE2e
# H2O
# keratan sulfate I
# L-fucose
# keratan sulfate I, degradation product 1
#
#
# FUCASE2ly
# H2O
# keratan sulfate I
# L-fucose
# keratan sulfate I, degradation product 1
#
#
# FUCASEe
# H2O
# PA6
# L-fucose
# de-Fuc form of PA6
#
#
# FUCASEly
# H2O
# PA6
# L-fucose
# de-Fuc form of PA6
#
#
# FUT12g
# Lc4Cer
# GDP-L-fucose(2-)
# proton
# Type IH glycolipid
# GDP
#
#
# FUT14g
# Lactoneotetraosylceramide
# GDP-L-fucose(2-)
# proton
# Type IIH glycolipid
# GDP
#
#
# FUT15g
# (Gal)3 (GalNAc)1 (Glc)1 (GlcNAc)1 (LFuc)1 (Cer)1
# GDP-L-fucose(2-)
# proton
# Type IIIH glycolipid
# GDP
#
#
# FUT16g
# i-antigen
# GDP-L-fucose(2-)
# proton
# VI2Fuc-nLc6
# GDP
#
#
# FUT17g
# (Gal)4 (GalNAc)1 (Glc)1 (GlcNAc)2 (LFuc)1 (Cer)1
# GDP-L-fucose(2-)
# proton
# (Gal)4 (GalNAc)1 (Glc)1 (GlcNAc)2 (LFuc)2 (Cer)1
# GDP
#
#
# FUT18g
# I-antigen
# GDP-L-fucose(2-)
# proton
# (Gal)4 (Glc)1 (GlcNAc)3 (LFuc)2 (Cer)1
# GDP
#
#
# FUT31g
# Lc4Cer
# GDP-L-fucose(2-)
# proton
# GDP
# Lea glycolipid
#
#
# FUT32g
# GDP-L-fucose(2-)
# (Gal)3 (Glc)1 (GlcNAc)1 (Cer)1
# proton
# GDP
# IV3-a-Neu5Ac,III4-a-Fuc-Lc4Cer
#
#
# FUT33g
# Type IA glycolipid
# GDP-L-fucose(2-)
# proton
# GDP
# (Gal)2 (GalNAc)1 (Glc)1 (GlcNAc)1 (LFuc)2 (Cer)1
#
#
# FUT34g
# Type IH glycolipid
# GDP-L-fucose(2-)
# proton
# GDP
# Leb glycolipid
#
#
# FUT35g
# Type IB glycolipid
# GDP-L-fucose(2-)
# proton
# GDP
# (Gal)3 (Glc)1 (GlcNAc)1 (LFuc)2 (Cer)1
#
#
# FUT910g
# GDP-L-fucose(2-)
# (Gal)4 (Glc)1 (GlcNAc)3 (LFuc)1 (Cer)1
# proton
# GDP
# (Gal)4 (Glc)1 (GlcNAc)3 (LFuc)2 (Cer)1
#
#
# FUT911g
# GDP-L-fucose(2-)
# (Gal)4 (Glc)1 (GlcNAc)3 (LFuc)2 (Cer)1
# proton
# GDP
# (Gal)4 (Glc)1 (GlcNAc)3 (LFuc)3 (Cer)1
#
#
# FUT91g
# Lactoneotetraosylceramide
# GDP-L-fucose(2-)
# proton
# GDP
# Lacto-N-fucopentaosyl III ceramide
#
#
# FUT92g
# GDP-L-fucose(2-)
# alpha-N-acetylneuraminosyl-(2->3)-beta-D-galactosyl-(1->4)-N-acetyl-beta-D-glucosaminyl-(1->3)-beta-D-galactosyl-(1->4)-beta-D-glucosylceramide(1-)
# proton
# GDP
# IV3-a-NeuAc,III3-a-Fuc-nLc4Cer
#
#
# FUT93g
# Type IIH glycolipid
# GDP-L-fucose(2-)
# proton
# GDP
# Ley glycolipid
#
#
# FUT94g
# VI2Fuc-nLc6
# GDP-L-fucose(2-)
# proton
# GDP
# (Gal)3 (Glc)1 (GlcNAc)2 (LFuc)2 (Cer)1
#
#
# FUT95g
# GDP-L-fucose(2-)
# (Gal)3 (Glc)1 (GlcNAc)2 (LFuc)2 (Cer)1
# proton
# GDP
# (Gal)3 (Glc)1 (GlcNAc)2 (LFuc)3 (Cer)1
#
#
# FUT96g
# i-antigen
# GDP-L-fucose(2-)
# proton
# GDP
# V3Fuc-nLc6Cer
#
#
# FUT97g
# GDP-L-fucose(2-)
# V3Fuc-nLc6Cer
# proton
# GDP
# V3Fuc,III3Fuc-nLc6Cer
#
#
# FUT98g
# i-antigen
# GDP-L-fucose(2-)
# proton
# GDP
# III3Fuc-nLc6Cer
#
#
# FUT99g
# nLc8Cer
# GDP-L-fucose(2-)
# proton
# GDP
# (Gal)4 (Glc)1 (GlcNAc)3 (LFuc)1 (Cer)1
#
#
# G12MT1
# GDP-alpha-D-mannose(2-)
# (alpha-D-mannosyl)2-beta-D-mannosyl-diacetylchitobiosyldiphosphodolichol
# proton
# GDP
# (alpha-D-mannosyl)3-beta-D-mannosyl-diacetylchitodiphosphodolichol
#
#
# G12MT2
# GDP-alpha-D-mannose(2-)
# (alpha-D-mannosyl)3-beta-D-mannosyl-diacetylchitodiphosphodolichol
# proton
# GDP
# (alpha-D-Mannosyl)4-beta-D-mannosyl-diacetylchitobiosyldiphosphodolichol
#
#
# G13MT
# GDP-alpha-D-mannose(2-)
# beta-D-Mannosyldiacetylchitobiosyldiphosphodolichol
# proton
# GDP
# alpha-D-mannosyl-beta-D-mannosyl-diacylchitobiosyldiphosphodolichol
#
#
# G14N10g
# UDP-D-galactose(2-)
# ndl4fn4m2masn[g]
# proton
# UDP
# lndl4fn4m2masn[g]
#
#
# G14N11g
# UDP-D-galactose(2-)
# ndl4n4m2masn[g]
# proton
# UDP
# lndl4n4m2masn[g]
#
#
# G14N12g
# UDP-D-galactose(2-)
# ncl4fn4m2masn[g]
# proton
# UDP
# lncl4fn4m2masn[g]
#
#
# G14N13g
# UDP-D-galactose(2-)
# ncl4n4m2masn[g]
# proton
# UDP
# lncl4n4m2masn[g]
#
#
# G14N14g
# UDP-D-galactose(2-)
# nbl4fn4m2masn[g]
# proton
# UDP
# lnbl4fn4m2masn[g]
#
#
# G14N15g
# UDP-D-galactose(2-)
# nbl4n4m2masn[g]
# proton
# UDP
# lnbl4n4m2masn[g]
#
#
# G14N16g
# UDP-D-galactose(2-)
# n2cdl4fn4m2masn[g]
# proton
# UDP
# l2n2cdl4fn4m2masn[g]
#
#
# G14N17g
# UDP-D-galactose(2-)
# n2cdl4n4m2masn[g]
# proton
# UDP
# l2n2cdl4n4m2masn[g]
#
#
# G14N18g
# UDP-D-galactose(2-)
# n2bdl4fn4m2masn[g]
# proton
# UDP
# l2n2bdl4fn4m2masn[g]
#
#
# G14N19g
# UDP-D-galactose(2-)
# n2bdl4n4m2masn[g]
# proton
# UDP
# l2n2bdl4n4m2masn[g]
#
#
# G14N1g
# UDP-D-galactose(2-)
# ((N-acetyl-D-glucosaminyl)2-(alpha-D-mannosyl)2-beta-D-mannosyl-diacetylchitobiosyl)-L-asparagine (protein)
# proton
# UDP
# de-Fuc, reducing GlcNAc removed, de-Sia form of PA6 (w/o peptide linkage)
#
#
# G14N20g
# UDP-D-galactose(2-)
# n3l4fn4m2masn[g]
# proton
# UDP
# l3n3l4fn4m2masn[g]
#
#
# G14N21g
# UDP-D-galactose(2-)
# n3l4n4m2masn[g]
# proton
# UDP
# l3n3l4n4m2masn[g]
#
#
# G14N2g
# UDP-D-galactose(2-)
# ((N-acetyl-D-glucosaminyl)3-(alpha-D-mannosyl)2-beta-D-mannosyl-diacetylchitobiosyl)-L-asparagine (protein)
# proton
# UDP
# l3n3m2masn[g]
#
#
# G14N3g
# UDP-D-galactose(2-)
# n3rm2masn[g]
# proton
# UDP
# l3n3rm2masn[g]
#
#
# G14N4g
# UDP-D-galactose(2-)
# fn3m2masn[g]
# proton
# UDP
# l3fn3m2masn[g]
#
#
# G14N5g
# UDP-D-galactose(2-)
# fn3rm2masn[g]
# proton
# UDP
# l3fn3rm2masn[g]
#
#
# G14N6g
# UDP-D-galactose(2-)
# fn4m2masn[g]
# proton
# UDP
# l4fn4m2masn[g]
#
#
# G14N7g
# UDP-D-galactose(2-)
# nl3n3m2masn[g]
# proton
# UDP
# lnl3n3m2masn[g]
#
#
# G14N8g
# UDP-D-galactose(2-)
# ((N-acetyl-D-glucosaminyl)4-(alpha-D-mannosyl)2-beta-D-mannosyl-diacetylchitobiosyl)-L-asparagine (protein)
# proton
# UDP
# l4n4m2masn[g]
#
#
# G14N9g
# UDP-D-galactose(2-)
# nl3fn3m2masn[g]
# proton
# UDP
# lnl3fn3m2masn[g]
#
#
# G14T10g
# UDP-D-galactose(2-)
# keratan sulfate I biosynthesis, precursor 14
# proton
# UDP
# keratan sulfate I biosynthesis, precursor 15
#
#
# G14T11g
# UDP-D-galactose(2-)
# keratan sulfate I biosynthesis, precursor 17
# proton
# UDP
# keratan sulfate I biosynthesis, precursor 18
#
#
# G14T12g
# UDP-D-galactose(2-)
# keratan sulfate I biosynthesis, precursor 20
# proton
# UDP
# keratan sulfate I biosynthesis, precursor 21
#
#
# G14T13g
# UDP-D-galactose(2-)
# keratan sulfate I biosynthesis, precursor 23
# proton
# UDP
# keratan sulfate I biosynthesis, precursor 24
#
#
# G14T14g
# UDP-D-galactose(2-)
# keratan sulfate I biosynthesis, precursor 26
# proton
# UDP
# keratan sulfate I biosynthesis, precursor 27
#
#
# G14T15g
# UDP-D-galactose(2-)
# keratan sulfate I biosynthesis, precursor 29
# proton
# UDP
# keratan sulfate I biosynthesis, precursor 30
#
#
# G14T16g
# UDP-D-galactose(2-)
# keratan sulfate I biosynthesis, precursor 32
# proton
# UDP
# keratan sulfate I biosynthesis, precursor 33
#
#
# G14T17g
# UDP-D-galactose(2-)
# keratan sulfate I biosynthesis, precursor 35
# proton
# UDP
# keratan sulfate I biosynthesis, precursor 36
#
#
# G14T18g
# UDP-D-galactose(2-)
# Core 4
# proton
# UDP
# keratan sulfate II biosynthesis, precursor 1
#
#
# G14T19g
# UDP-D-galactose(2-)
# keratan sulfate II biosynthesis, precursor 3
# proton
# UDP
# keratan sulfate II biosynthesis, precursor 4
#
#
# G14T20g
# UDP-D-galactose(2-)
# keratan sulfate II biosynthesis, precursor 6
# proton
# UDP
# keratan sulfate II biosynthesis, precursor 7
#
#
# G14T21g
# UDP-D-galactose(2-)
# keratan sulfate II biosynthesis, precursor 9
# proton
# UDP
# keratan sulfate II biosynthesis, precursor 10
#
#
# G14T2g
# UDP-D-galactose(2-)
# keratan sulfate II biosynthesis, precursor 1
# proton
# UDP
# keratan sulfate II biosynthesis, precursor 2
#
#
# G14T3g
# UDP-D-galactose(2-)
# keratan sulfate II biosynthesis, precursor 3
# proton
# UDP
# keratan sulfate II biosynthesis, precursor 4
#
#
# G14T4g
# UDP-D-galactose(2-)
# keratan sulfate II biosynthesis, precursor 6
# proton
# UDP
# keratan sulfate II biosynthesis, precursor 7
#
#
# G14T5g
# UDP-D-galactose(2-)
# keratan sulfate II biosynthesis, precursor 9
# proton
# UDP
# keratan sulfate II biosynthesis, precursor 10
#
#
# G14T6g
# UDP-D-galactose(2-)
# keratan sulfate I biosynthesis, precursor 2
# proton
# UDP
# keratan sulfate I biosynthesis, precursor 3
#
#
# G14T7g
# UDP-D-galactose(2-)
# keratan sulfate I biosynthesis, precursor 5
# proton
# UDP
# keratan sulfate I biosynthesis, precursor 6
#
#
# G14T8g
# UDP-D-galactose(2-)
# keratan sulfate I biosynthesis, precursor 8
# proton
# UDP
# keratan sulfate I biosynthesis, precursor 9
#
#
# G14T9g
# UDP-D-galactose(2-)
# keratan sulfate I biosynthesis, precursor 11
# proton
# UDP
# keratan sulfate I biosynthesis, precursor 12
#
#
# G14Tg
# UDP-D-galactose(2-)
# N4-{N-Acetyl-beta-D-glucosaminyl-(1,2)-alpha-D-mannosyl-(1,3)-[N-acetyl-beta-D-glucosaminyl-(1,2)-alpha-D-mannosyl-(1,6)]-beta-D-mannosyl-(1,4)-N-acetyl-beta-D-glucosaminyl-(1,4)-[alpha-L-fucosyl-(1,6)]-N-acetyl-beta-D-glucosaminyl}asparagine
# proton
# UDP
# {[galactosyl-(1,4)-N-Acetyl-glucosaminyl-(1,2)-mannosyl-(1,3)-],[N-acetyl-glucosaminyl-(1,2)-mannosyl-(1,6)-]mannosyl-(1,4)-N-acetyl-glucosaminyl-(1,4)-[fucosyl-(1,6)]-N-acetyl-glucosaminyl}asparagine
#
#
# G14Tg_1
# UDP-D-galactose(2-)
# N4-{N-Acetyl-beta-D-glucosaminyl-(1,2)-alpha-D-mannosyl-(1,3)-[N-acetyl-beta-D-glucosaminyl-(1,2)-alpha-D-mannosyl-(1,6)]-beta-D-mannosyl-(1,4)-N-acetyl-beta-D-glucosaminyl-(1,4)-[alpha-L-fucosyl-(1,6)]-N-acetyl-beta-D-glucosaminyl}asparagine
# proton
# UDP
# lfn2m2masn[g]
#
#
# G14Tg_new2
# UDP-D-galactose(2-)
# fnm2masn[g]
# proton
# UDP
# lfnm2masn[g]
#
#
# G14Tg_new3
# UDP-D-galactose(2-)
# (N-acetyl-D-glucosaminyl-(alpha-D-mannosyl)2-beta-D-mannosyl-diacetylchitobiosyl)-L-asparagine (protein)
# proton
# UDP
# lnm2masn[g]
#
#
# G14Tg_new4
# UDP-D-galactose(2-)
# l4fn4m2masn[g]
# proton
# UDP
# l5fn4m2masn[g]
#
#
# G14Tg_new5
# UDP-D-galactose(2-)
# l4fn4m2masn[g]
# proton
# UDP
# l6fn4m2masn[g]
#
#
# G16MT
# GDP-alpha-D-mannose(2-)
# alpha-D-mannosyl-beta-D-mannosyl-diacylchitobiosyldiphosphodolichol
# proton
# GDP
# (alpha-D-mannosyl)2-beta-D-mannosyl-diacetylchitobiosyldiphosphodolichol
#
#
# G1M6MASNB1terg
# glucosyl-(alpha-D-mannosyl)6-beta-D-mannosyl-diacetylchitobiosyl-L-asparagine (protein)
# glucosyl-(alpha-D-mannosyl)6-beta-D-mannosyl-diacetylchitobiosyl-L-asparagine (protein)
#
#
# G1M7MASNBterg
# glucosyl-(alpha-D-mannosyl)7-beta-D-mannosyl-diacetylchitobiosyl-L-asparagine, isoform B (protein)
# glucosyl-(alpha-D-mannosyl)7-beta-D-mannosyl-diacetylchitobiosyl-L-asparagine, isoform B (protein)
#
#
# G1M7MASNCterg
# glucosyl-(alpha-D-mannosyl)7-beta-D-mannosyl-diacetylchitobiosyl-L-asparagine, isoform C (protein)
# glucosyl-(alpha-D-mannosyl)7-beta-D-mannosyl-diacetylchitobiosyl-L-asparagine, isoform C (protein)
#
#
# G1M8MASNterg
# (alpha-D-Glucosyl)-(alpha-D-mannosyl)8-beta-D-mannosyl-diacetylchitobiosyl-L-asparagine (protein)
# (alpha-D-Glucosyl)-(alpha-D-mannosyl)8-beta-D-mannosyl-diacetylchitobiosyl-L-asparagine (protein)
#
#
# G2M8MASNterg
# (alpha-D-Glucosyl)2-(alpha-D-mannosyl)8-beta-D-mannosyl-diacetylchitobiosyl-L-asparagine (protein)
# (alpha-D-Glucosyl)2-(alpha-D-mannosyl)8-beta-D-mannosyl-diacetylchitobiosyl-L-asparagine (protein)
#
#
# G3M8MASNterg
# (alpha-D-Glucosyl)3-(alpha-D-mannosyl)8-beta-D-mannosyl-diacetylchitobiosyl-L-asparagine (protein)
# (alpha-D-Glucosyl)3-(alpha-D-mannosyl)8-beta-D-mannosyl-diacetylchitobiosyl-L-asparagine (protein)
#
#
# GALASE10ly
# H2O
# keratan sulfate I, degradation product 26
# D-Galactose
# keratan sulfate I, degradation product 27
#
#
# GALASE11ly
# H2O
# keratan sulfate I, degradation product 29
# D-Galactose
# keratan sulfate I, degradation product 30
#
#
# GALASE12ly
# H2O
# keratan sulfate I, degradation product 32
# D-Galactose
# keratan sulfate I, degradation product 33
#
#
# GALASE13ly
# H2O
# keratan sulfate I, degradation product 35
# D-Galactose
# keratan sulfate I, degradation product 36
#
#
# GALASE14ly
# H2O
# keratan sulfate I, degradation product 38
# D-Galactose
# keratan sulfate I, degradation product 39
#
#
# GALASE15ly
# H2O
# keratan sulfate I, degradation product 40
# D-Galactose
# keratan sulfate I, degradation product 41
#
#
# GALASE16ly
# H2O
# keratan sulfate II (core 2-linked), degradation product 2
# D-Galactose
# keratan sulfate II (core 2-linked), degradation product 3
#
#
# GALASE17ly
# H2O
# keratan sulfate II (core 2-linked), degradation product 5
# D-Galactose
# keratan sulfate II (core 2-linked), degradation product 6
#
#
# GALASE18ly
# H2O
# keratan sulfate II (core 2-linked), degradation product 8
# D-Galactose
# keratan sulfate II (core 2-linked), degradation product 9
#
#
# GALASE19ly
# H2O
# F1alpha
# D-Galactose
# Core 6
#
#
# GALASE1ly
# H2O
# de-Fuc, reducing GlcNAc removed, de-Sia form of PA6 (w/o peptide linkage)
# de-Fuc, reducing GlcNAc removed, de-Sia, de-Gal form of PA6 (w/o peptide linkage)
# D-Galactose
#
#
# GALASE20ly
# H2O
# keratan sulfate II (core 4-linked), degradation product 2
# D-Galactose
# keratan sulfate II (core 4-linked), degradation product 3
#
#
# GALASE3ly
# H2O
# keratan sulfate I, degradation product 5
# D-Galactose
# keratan sulfate I, degradation product 6
#
#
# GALASE4ly
# H2O
# keratan sulfate I, degradation product 8
# D-Galactose
# keratan sulfate I, degradation product 9
#
#
# GALASE5ly
# H2O
# keratan sulfate I, degradation product 11
# D-Galactose
# keratan sulfate I, degradation product 12
#
#
# GALASE6ly
# H2O
# keratan sulfate I, degradation product 14
# D-Galactose
# keratan sulfate I, degradation product 15
#
#
# GALASE7ly
# H2O
# keratan sulfate I, degradation product 17
# D-Galactose
# keratan sulfate I, degradation product 18
#
#
# GALASE8ly
# H2O
# keratan sulfate I, degradation product 20
# D-Galactose
# keratan sulfate I, degradation product 21
#
#
# GALASE9ly
# H2O
# keratan sulfate I, degradation product 23
# D-Galactose
# keratan sulfate I, degradation product 24
#
#
# GALNACT1g
# UDP-N-acetyl-D-galactosamine(2-)
# chondroitin sulfate/heparan sulfate linkage region (GlcA-(Gal)2-Xyl-L-Ser (protein))
# proton
# UDP
# chondroitin sulfate precursor (GalNAc-GlcA-(Gal)2-Xyl-L-Ser (protein))
#
#
# GALNACT2g
# UDP-N-acetyl-alpha-D-glucosamine(2-)
# chondroitin sulfate A (GalNAc4S-GlcA) and B (IdoA2S-GalNAc4S), precursor 2
# proton
# UDP
# chondroitin sulfate A (GalNAc4S-GlcA) and B (IdoA2S-GalNAc4S), precursor 3
#
#
# GALNACT3g
# UDP-N-acetyl-alpha-D-glucosamine(2-)
# chondroitin sulfate C (GalNAc6S-GlcA), precursor 2
# proton
# UDP
# chondroitin sulfate C (GalNAc6S-GlcA), precursor 3
#
#
# GALNACT4g
# UDP-N-acetyl-alpha-D-glucosamine(2-)
# chondroitin sulfate D (GlcNAc6S-GlcA2S), precursor 3
# proton
# UDP
# chondroitin sulfate D (GlcNAc6S-GlcA2S), precursor 4
#
#
# GALNACT5g
# UDP-N-acetyl-alpha-D-glucosamine(2-)
# chondroitin sulfate E (GalNAc4,6diS-GlcA), precursor 3
# proton
# UDP
# chondroitin sulfate E (GalNAc4,6diS-GlcA), precursor 4
#
#
# GALNTg
# UDP-N-acetyl-D-galactosamine(2-)
# protein-linked serine or threonine residue (O-glycosylation site)
# proton
# UDP
# Tn antigen
#
#
# GALT2g
# UDP-D-galactose(2-)
# Gal-Xyl-L-Ser (protein)
# proton
# UDP
# (Gal)2-Xyl-L-Ser (protein)
#
#
# GALTg
# UDP-D-galactose(2-)
# Xyl-L-Ser (protein)
# proton
# UDP
# Gal-Xyl-L-Ser (protein)
#
#
# GASNASE2ly
# H2O
# N-Acetyl-beta-D-glucosaminyl-1,2-alpha-D-mannosyl-1,3-(N-acetyl-beta-D-glucosaminyl-1,2-alpha-D-mannosyl-1,6)-(N-acetyl-beta-D-glucosaminyl-1,4)-beta-D-mannosyl-1,4-N-acetyl-beta-D-glucosaminyl-R
# protein-linked asparagine residue (N-glycosylation site)
# n2m2nmasn (w/o peptide linkage)
#
#
# GASNASE3ly
# H2O
# keratan sulfate I, degradation product 1
# protein-linked asparagine residue (N-glycosylation site)
# keratan sulfate I, degradation product 2
#
#
# GASNASEly
# H2O
# de-Fuc form of PA6
# protein-linked asparagine residue (N-glycosylation site)
# de-Fuc form of PA6 (w/o peptide linkage)
#
#
# GCNTg
# UDP-N-acetyl-alpha-D-glucosamine(2-)
# i-antigen
# proton
# UDP
# (Gal)3 (Glc)1 (GlcNAc)3 (Cer)1
#
#
# GLCAASE1ly
# H2O
# heparan sulfate, degradation product 9
# D-glucuronate
# heparan sulfate, degradation product 10
#
#
# GLCAASE4ly
# H2O
# chondroitin sulfate A (GalNAc4S-GlcA), degradation product 2
# D-glucuronate
# chondroitin sulfate A (GalNAc4S-GlcA), degradation product 3
#
#
# GLCAASE5ly
# H2O
# chondroitin sulfate C (GalNAc6S-GlcA), degradation product 2
# D-glucuronate
# chondroitin sulfate C (GalNAc6S-GlcA), degradation product 3
#
#
# GLCAASE6ly
# H2O
# chondroitin sulfate D (GlcNAc6S-GlcA2S), degradation product 3
# D-glucuronate
# chondroitin sulfate D (GlcNAc6S-GlcA2S), degradation product 4
#
#
# GLCAASE7ly
# H2O
# chondroitin sulfate E (GalNAc4,6diS-GlcA), degradation product 3
# D-glucuronate
# chondroitin sulfate E (GalNAc4,6diS-GlcA), degradation product 4
#
#
# GLCAASE8ly
# H2O
# hyaluronan
# D-glucuronate
# hyaluronan degradation product 1
#
#
# GLCAASE9ly
# H2O
# hyaluronan biosynthesis, precursor 1
# N-acetyl-D-glucosamine
# D-glucuronate
#
#
# GLCAE1g
# chondroitin sulfate A (GalNAc4S-GlcA) and B (IdoA2S-GalNAc4S), precursor 3
# chondroitin sulfate B (IdoA2S-GalNAc4S), precursor 4
#
#
# GLCAE2g
# (GlcN2S-GlcA)4-GlcNAc-GlcA-Gal-Gal-Xyl-L-Ser (protein)
# (GlcN2S-IdoA-GlcN2S-GlcA)2-GlcNAc-GlcA-Gal-Gal-Xyl-L-Ser (protein)
#
#
# GLCAT2g
# UDP-alpha-D-glucuronate(3-)
# chondroitin sulfate A (GalNAc4S-GlcA), B (IdoA2S-GalNAc4S), and E (GalNAc4,6diS-GlcA), precursor 1
# proton
# UDP
# chondroitin sulfate A (GalNAc4S-GlcA) and B (IdoA2S-GalNAc4S), precursor 2
#
#
# GLCAT3g
# UDP-alpha-D-glucuronate(3-)
# chondroitin sulfate C (GalNAc6S-GlcA) and D (GlcNAc6S-GlcA2S), precursor 1
# proton
# UDP
# chondroitin sulfate C (GalNAc6S-GlcA), precursor 2
#
#
# GLCAT4g
# UDP-alpha-D-glucuronate(3-)
# chondroitin sulfate D (GlcNAc6S-GlcA2S) precursor 2
# proton
# UDP
# chondroitin sulfate D (GlcNAc6S-GlcA2S), precursor 3
#
#
# GLCAT5g
# UDP-alpha-D-glucuronate(3-)
# chondroitin sulfate E (GalNAc4,6diS-GlcA), precursor 2
# proton
# UDP
# chondroitin sulfate E (GalNAc4,6diS-GlcA), precursor 3
#
#
# GLCAT6g
# UDP-alpha-D-glucuronate(3-)
# heparan sulfate, precursor 1
# proton
# UDP
# heparan sulfate, precursor 2
#
#
# GLCAT7g
# UDP-alpha-D-glucuronate(3-)
# GlcNAc-GlcA-GlcNAc-GlcA-Gal-Gal-Xyl-L-Ser (protein)
# proton
# UDP
# GlcA-GlcNAc-GlcA-GlcNAc-GlcA-Gal-Gal-Xyl-L-Ser (protein)
#
#
# GLCAT8g
# UDP-alpha-D-glucuronate(3-)
# (GlcNAc-GlcA)2-GlcNAc-GlcA-Gal-Gal-Xyl-L-Ser (protein)
# proton
# UDP
# GlcA-(GlcNAc-GlcA)2-GlcNAc-GlcA-Gal-Gal-Xyl-L-Ser (protein)
#
#
# GLCAT9g
# UDP-alpha-D-glucuronate(3-)
# (GlcNAc-GlcA)3-GlcNAc-GlcA-Gal-Gal-Xyl-L-Ser (protein)
# proton
# UDP
# GlcA-(GlcNAc-GlcA)3-GlcNAc-GlcA-Gal-Gal-Xyl-L-Ser (protein)
#
#
# GLCATg
# (Gal)2-Xyl-L-Ser (protein)
# UDP-alpha-D-glucuronate(3-)
# proton
# UDP
# chondroitin sulfate/heparan sulfate linkage region (GlcA-(Gal)2-Xyl-L-Ser (protein))
#
#
# GLCNACASE1ly
# H2O
# heparan sulfate, degradation product 3
# N-acetyl-D-glucosamine
# heparan sulfate, degradation product 4
#
#
# GLCNACASE2ly
# H2O
# heparan sulfate, degradation product 8
# N-acetyl-D-glucosamine
# heparan sulfate, degradation product 9
#
#
# GLCNACASE3ly
# H2O
# heparan sulfate, degradation product 14
# N-acetyl-D-glucosamine
# heparan sulfate, degradation product 15
#
#
# GLCNACASE4ly
# H2O
# heparan sulfate, degradation product 20
# N-acetyl-D-glucosamine
# IdoA2S-beta-1,4-GlcNAc(3S)-alpha-1,4-GlcA-beta-1,3-Gal-beta-1,3-Gal-beta-1,4-Xylose
#
#
# GLCNACASE5ly
# H2O
# GlcNAc-GlcA-(Gal)2-Xyl
# N-acetyl-D-glucosamine
# GlcA-beta-1,3-Gal-beta-1,3-Gal-beta-1,4-Xylose
#
#
# GLCNACDASg
# H2O
# 3'-Phosphoadenosine 5'-phosphosulfate; (2R,3S,4R,5R)-5-(6-amino-9H-purin-9-yl)-4-hydroxy-2-({[(sulfonatooxy)phosphinato]oxy}methyl)oxolan-3-yl phosphate
# (GlcNAc-GlcA)4-GlcNAc-GlcA-Gal-Gal-Xyl-L-Ser (protein)
# proton
# acetate
# adenosine 3',5'-bismonophosphate(4-)
# (GlcN2S-GlcA)4-GlcNAc-GlcA-Gal-Gal-Xyl-L-Ser (protein)
#
#
# GLCNACPT
# dolichyl phosphate(2-)
# UDP-N-acetyl-alpha-D-glucosamine(2-)
# N-Acetyl-D-glucosaminyldiphosphodolichol
# UMP(2-)
#
#
# GLCNACT
# UDP-N-acetyl-alpha-D-glucosamine(2-)
# N-Acetyl-D-glucosaminyldiphosphodolichol
# proton
# N,N'-Diacetylchitobiosyldiphosphodolichol
# UDP
#
#
# GLCNACT1g
# UDP-N-acetyl-alpha-D-glucosamine(2-)
# chondroitin sulfate/heparan sulfate linkage region (GlcA-(Gal)2-Xyl-L-Ser (protein))
# proton
# UDP
# heparan sulfate, precursor 1
#
#
# GLCNACT2g
# UDP-N-acetyl-alpha-D-glucosamine(2-)
# heparan sulfate, precursor 2
# proton
# UDP
# GlcNAc-GlcA-GlcNAc-GlcA-Gal-Gal-Xyl-L-Ser (protein)
#
#
# GLCNACT3g
# UDP-N-acetyl-alpha-D-glucosamine(2-)
# GlcA-GlcNAc-GlcA-GlcNAc-GlcA-Gal-Gal-Xyl-L-Ser (protein)
# proton
# UDP
# (GlcNAc-GlcA)2-GlcNAc-GlcA-Gal-Gal-Xyl-L-Ser (protein)
#
#
# GLCNACT4g
# UDP-N-acetyl-alpha-D-glucosamine(2-)
# GlcA-(GlcNAc-GlcA)2-GlcNAc-GlcA-Gal-Gal-Xyl-L-Ser (protein)
# proton
# UDP
# (GlcNAc-GlcA)3-GlcNAc-GlcA-Gal-Gal-Xyl-L-Ser (protein)
#
#
# GLCNACT5g
# UDP-N-acetyl-alpha-D-glucosamine(2-)
# GlcA-(GlcNAc-GlcA)3-GlcNAc-GlcA-Gal-Gal-Xyl-L-Ser (protein)
# proton
# UDP
# (GlcNAc-GlcA)4-GlcNAc-GlcA-Gal-Gal-Xyl-L-Ser (protein)
#
#
# HAS1
# UDP-N-acetyl-alpha-D-glucosamine(2-)
# UDP-alpha-D-glucuronate(3-)
# proton
# UDP
# hyaluronan biosynthesis, precursor 1
#
#
# HAS2
# hyaluronan biosynthesis, precursor 1
# UDP-N-acetyl-alpha-D-glucosamine(2-)
# UDP-alpha-D-glucuronate(3-)
# proton
# UDP
# hyaluronan
#
#
# HS1ly
# H2O
# heparan sulfate, degradation product 1
# proton
# sulfate
# heparan sulfate, degradation product 2
#
#
# HS2ly
# H2O
# heparan sulfate, degradation product 6
# proton
# sulfate
# heparan sulfate, degradation product 7
#
#
# HS3ly
# H2O
# heparan sulfate, degradation product 12
# proton
# sulfate
# heparan sulfate, degradation product 13
#
#
# HS4ly
# H2O
# heparan sulfate, degradation product 18
# proton
# sulfate
# heparan sulfate, degradation product 19
#
#
# HSAT1ly
# Acetyl-CoA
# heparan sulfate, degradation product 2
# Coenzyme A
# proton
# heparan sulfate, degradation product 3
#
#
# HSAT2ly
# Acetyl-CoA
# heparan sulfate, degradation product 7
# Coenzyme A
# proton
# heparan sulfate, degradation product 8
#
#
# HSAT3ly
# Acetyl-CoA
# heparan sulfate, degradation product 13
# Coenzyme A
# proton
# heparan sulfate, degradation product 14
#
#
# HSAT4ly
# Acetyl-CoA
# heparan sulfate, degradation product 19
# Coenzyme A
# proton
# heparan sulfate, degradation product 20
#
#
# HSPASEly
# H2O
# heparan sulfate proteoglycan
# protein-linked serine residue (glycosaminoglycan attachment site)
# heparan sulfate, free chain
#
#
# IDOAASE1ly
# H2O
# heparan sulfate, degradation product 4
# L-iduronate
# heparan sulfate, degradation product 5
#
#
# IDOAASE2ly
# H2O
# heparan sulfate, degradation product 16
# L-iduronate
# heparan sulfate, degradation product 17
#
#
# IDOAASE3ly
# H2O
# IdoA-beta-1,4-GlcNAc(3S)-alpha-1,4-GlcA-beta-1,3-Gal-beta-1,3-Gal-beta-1,4-Xylose
# L-iduronate
# GlcNAc(3S)-alpha-1,4-GlcA-beta-1,3-Gal-beta-1,3-Gal-beta-1,4-Xylose
#
#
# IDOAASE4ly
# H2O
# chondroitin sulfate B / dermatan sulfate (IdoA2S-GalNAc4S), degradation product 3
# chondroitin sulfate A (GalNAc4S-GlcA), degradation product 3
# L-iduronate
#
#
# LINKDEG1ly
# H2O
# GlcA-beta-1,3-Gal-beta-1,3-Gal-beta-1,4-Xylose
# D-Galactose
# D-glucuronate
# aldehydo-D-xylose
#
#
# LINKDEG2ly
# H2O
# chondroitin sulfate A (GalNAc4S-GlcA), degradation product 5
# proton
# sulfate
# D-Galactose
# D-glucuronate
# aldehydo-D-xylose
#
#
# LINKDEG3ly
# H2O
# chondroitin sulfate C (GalNAc6S-GlcA), degradation product 5
# proton
# sulfate
# D-Galactose
# D-glucuronate
# aldehydo-D-xylose
#
#
# LINKDEG4ly
# H2O
# chondroitin sulfate E (GalNAc4,6diS-GlcA), degradation product 7
# proton
# sulfate
# D-Galactose
# D-glucuronate
# aldehydo-D-xylose
#
#
# M1316M2g
# H2O
# fnm4masn[g]
# fnm2masn[g]
# D-Mannose
#
#
# M1316Mg
# H2O
# (N-acetyl-D-glucosaminyl-(alpha-D-mannosyl)4-beta-D-mannosyl-diacetylchitobiosyl)-L-asparagine (protein)
# (N-acetyl-D-glucosaminyl-(alpha-D-mannosyl)2-beta-D-mannosyl-diacetylchitobiosyl)-L-asparagine (protein)
# D-Mannose
#
#
# M13N14N3T1g
# UDP-N-acetyl-alpha-D-glucosamine(2-)
# l3n3m2masn[g]
# proton
# UDP
# nl3n3m2masn[g]
#
#
# M13N14N3T2g
# UDP-N-acetyl-alpha-D-glucosamine(2-)
# l3fn3m2masn[g]
# proton
# UDP
# nl3fn3m2masn[g]
#
#
# M13N14N3T3g
# UDP-N-acetyl-alpha-D-glucosamine(2-)
# l4n4m2masn[g]
# proton
# UDP
# nbl4n4m2masn[g]
#
#
# M13N14N3T4g
# UDP-N-acetyl-alpha-D-glucosamine(2-)
# l4fn4m2masn[g]
# proton
# UDP
# nbl4fn4m2masn[g]
#
#
# M13N2Tg
# UDP-N-acetyl-alpha-D-glucosamine(2-)
# (alpha-D-mannosyl)4-beta-D-mannosyl-diacetylchitobiosyl-L-asparagine (protein)
# proton
# UDP
# (N-acetyl-D-glucosaminyl-(alpha-D-mannosyl)4-beta-D-mannosyl-diacetylchitobiosyl)-L-asparagine (protein)
#
#
# M13N4T1g
# UDP-N-acetyl-alpha-D-glucosamine(2-)
# N4-{N-Acetyl-beta-D-glucosaminyl-(1,2)-alpha-D-mannosyl-(1,3)-[N-acetyl-beta-D-glucosaminyl-(1,2)-alpha-D-mannosyl-(1,6)]-beta-D-mannosyl-(1,4)-N-acetyl-beta-D-glucosaminyl-(1,4)-[alpha-L-fucosyl-(1,6)]-N-acetyl-beta-D-glucosaminyl}asparagine
# proton
# UDP
# fn3m2masn[g]
#
#
# M13N4T2g
# UDP-N-acetyl-alpha-D-glucosamine(2-)
# n3rm2masn[g]
# proton
# UDP
# ((N-acetyl-D-glucosaminyl)4-(alpha-D-mannosyl)2-beta-D-mannosyl-diacetylchitobiosyl)-L-asparagine (protein)
#
#
# M13N4T3g
# UDP-N-acetyl-alpha-D-glucosamine(2-)
# fn3rm2masn[g]
# proton
# UDP
# fn4m2masn[g]
#
#
# M13N4Tg
# UDP-N-acetyl-alpha-D-glucosamine(2-)
# ((N-acetyl-D-glucosaminyl)2-(alpha-D-mannosyl)2-beta-D-mannosyl-diacetylchitobiosyl)-L-asparagine (protein)
# proton
# UDP
# ((N-acetyl-D-glucosaminyl)3-(alpha-D-mannosyl)2-beta-D-mannosyl-diacetylchitobiosyl)-L-asparagine (protein)
#
#
# M14NTg
# UDP-N-acetyl-alpha-D-glucosamine(2-)
# ((N-acetyl-D-glucosaminyl)2-(alpha-D-mannosyl)2-beta-D-mannosyl-diacetylchitobiosyl)-L-asparagine (protein)
# proton
# UDP
# N-Acetyl-beta-D-glucosaminyl-1,2-alpha-D-mannosyl-1,3-(N-acetyl-beta-D-glucosaminyl-1,2-alpha-D-mannosyl-1,6)-(N-acetyl-beta-D-glucosaminyl-1,4)-beta-D-mannosyl-1,4-N-acetyl-beta-D-glucosaminyl-R
#
#
# M1613N1614N3T1g
# UDP-N-acetyl-alpha-D-glucosamine(2-)
# l4n4m2masn[g]
# proton
# UDP
# n2bdl4n4m2masn[g]
#
#
# M1613N1614N3T2g
# UDP-N-acetyl-alpha-D-glucosamine(2-)
# l4fn4m2masn[g]
# proton
# UDP
# n2bdl4fn4m2masn[g]
#
#
# M1613N3xN3T1g
# UDP-N-acetyl-alpha-D-glucosamine(2-)
# l4n4m2masn[g]
# proton
# UDP
# n3l4n4m2masn[g]
#
#
# M1613N3xN3T2g
# UDP-N-acetyl-alpha-D-glucosamine(2-)
# l4fn4m2masn[g]
# proton
# UDP
# n3l4fn4m2masn[g]
#
#
# M16N1216N3T1g
# UDP-N-acetyl-alpha-D-glucosamine(2-)
# l4n4m2masn[g]
# proton
# UDP
# n2cdl4n4m2masn[g]
#
#
# M16N1216N3T2g
# UDP-N-acetyl-alpha-D-glucosamine(2-)
# l4fn4m2masn[g]
# proton
# UDP
# n2cdl4fn4m2masn[g]
#
#
# M16N12N3T1g
# UDP-N-acetyl-alpha-D-glucosamine(2-)
# l4n4m2masn[g]
# proton
# UDP
# ncl4n4m2masn[g]
#
#
# M16N12N3T2g
# UDP-N-acetyl-alpha-D-glucosamine(2-)
# l4fn4m2masn[g]
# proton
# UDP
# ncl4fn4m2masn[g]
#
#
# M16N16N3T1g
# UDP-N-acetyl-alpha-D-glucosamine(2-)
# l4n4m2masn[g]
# proton
# UDP
# ndl4n4m2masn[g]
#
#
# M16N16N3T2g
# UDP-N-acetyl-alpha-D-glucosamine(2-)
# l4fn4m2masn[g]
# proton
# UDP
# ndl4fn4m2masn[g]
#
#
# M16N4Tg
# UDP-N-acetyl-alpha-D-glucosamine(2-)
# ((N-acetyl-D-glucosaminyl)4-(alpha-D-mannosyl)2-beta-D-mannosyl-diacetylchitobiosyl)-L-asparagine (protein)
# proton
# UDP
# ((N-acetyl-D-glucosaminyl)5-(alpha-D-mannosyl)2-beta-D-mannosyl-diacetylchitobiosyl)-L-asparagine (protein)
#
#
# M16N4Tg_new1
# UDP-N-acetyl-alpha-D-glucosamine(2-)
# l5fn4m2masn[g]
# proton
# UDP
# l5fn5m2masn[g]
#
#
# M16N4Tg_new2
# UDP-N-acetyl-alpha-D-glucosamine(2-)
# l6fn4m2masn[g]
# proton
# UDP
# l6fn6m2masn[g]
#
#
# M16N6T1g
# UDP-N-acetyl-alpha-D-glucosamine(2-)
# fn3m2masn[g]
# proton
# UDP
# fn4m2masn[g]
#
#
# M16N6T2g
# UDP-N-acetyl-alpha-D-glucosamine(2-)
# ((N-acetyl-D-glucosaminyl)2-(alpha-D-mannosyl)2-beta-D-mannosyl-diacetylchitobiosyl)-L-asparagine (protein)
# proton
# UDP
# n3rm2masn[g]
#
#
# M16N6T3g
# UDP-N-acetyl-alpha-D-glucosamine(2-)
# N4-{N-Acetyl-beta-D-glucosaminyl-(1,2)-alpha-D-mannosyl-(1,3)-[N-acetyl-beta-D-glucosaminyl-(1,2)-alpha-D-mannosyl-(1,6)]-beta-D-mannosyl-(1,4)-N-acetyl-beta-D-glucosaminyl-(1,4)-[alpha-L-fucosyl-(1,6)]-N-acetyl-beta-D-glucosaminyl}asparagine
# proton
# UDP
# fn3rm2masn[g]
#
#
# M16N6Tg
# UDP-N-acetyl-alpha-D-glucosamine(2-)
# ((N-acetyl-D-glucosaminyl)3-(alpha-D-mannosyl)2-beta-D-mannosyl-diacetylchitobiosyl)-L-asparagine (protein)
# proton
# UDP
# ((N-acetyl-D-glucosaminyl)4-(alpha-D-mannosyl)2-beta-D-mannosyl-diacetylchitobiosyl)-L-asparagine (protein)
#
#
# M16NT1g
# UDP-N-acetyl-alpha-D-glucosamine(2-)
# fnm2masn[g]
# proton
# UDP
# N4-{N-Acetyl-beta-D-glucosaminyl-(1,2)-alpha-D-mannosyl-(1,3)-[N-acetyl-beta-D-glucosaminyl-(1,2)-alpha-D-mannosyl-(1,6)]-beta-D-mannosyl-(1,4)-N-acetyl-beta-D-glucosaminyl-(1,4)-[alpha-L-fucosyl-(1,6)]-N-acetyl-beta-D-glucosaminyl}asparagine
#
#
# M16NTg
# UDP-N-acetyl-alpha-D-glucosamine(2-)
# (N-acetyl-D-glucosaminyl-(alpha-D-mannosyl)2-beta-D-mannosyl-diacetylchitobiosyl)-L-asparagine (protein)
# proton
# UDP
# ((N-acetyl-D-glucosaminyl)2-(alpha-D-mannosyl)2-beta-D-mannosyl-diacetylchitobiosyl)-L-asparagine (protein)
#
#
# M4MPDOL_ter
# (alpha-D-Mannosyl)4-beta-D-mannosyl-diacetylchitobiosyldiphosphodolichol
# (alpha-D-Mannosyl)4-beta-D-mannosyl-diacetylchitobiosyldiphosphodolichol
#
#
# M7MASNBterg
# (alpha-D-mannosyl)7-beta-D-mannosyl-diacetylchitobiosyl-L-asparagine, isoform B (protein)
# (alpha-D-mannosyl)7-beta-D-mannosyl-diacetylchitobiosyl-L-asparagine, isoform B (protein)
#
#
# M8MASNterg
# (alpha-D-mannosyl)8-beta-D-mannosyl-diacetylchitobiosyl-L-asparagine (protein)
# (alpha-D-mannosyl)8-beta-D-mannosyl-diacetylchitobiosyl-L-asparagine (protein)
#
#
# MAN1_6B1er
# H2O
# glucosyl-(alpha-D-mannosyl)7-beta-D-mannosyl-diacetylchitobiosyl-L-asparagine, isoform C (protein)
# glucosyl-(alpha-D-mannosyl)6-beta-D-mannosyl-diacetylchitobiosyl-L-asparagine (protein)
# D-Mannose
#
#
# MAN1_7Ber
# H2O
# (alpha-D-Glucosyl)-(alpha-D-mannosyl)8-beta-D-mannosyl-diacetylchitobiosyl-L-asparagine (protein)
# glucosyl-(alpha-D-mannosyl)7-beta-D-mannosyl-diacetylchitobiosyl-L-asparagine, isoform B (protein)
# D-Mannose
#
#
# MAN2_6B1er
# H2O
# glucosyl-(alpha-D-mannosyl)7-beta-D-mannosyl-diacetylchitobiosyl-L-asparagine, isoform B (protein)
# glucosyl-(alpha-D-mannosyl)6-beta-D-mannosyl-diacetylchitobiosyl-L-asparagine (protein)
# D-Mannose
#
#
# MAN2_7Cer
# H2O
# (alpha-D-Glucosyl)-(alpha-D-mannosyl)8-beta-D-mannosyl-diacetylchitobiosyl-L-asparagine (protein)
# glucosyl-(alpha-D-mannosyl)7-beta-D-mannosyl-diacetylchitobiosyl-L-asparagine, isoform C (protein)
# D-Mannose
#
#
# MG1er
# H2O
# (alpha-D-Glucosyl)3-(alpha-D-mannosyl)8-beta-D-mannosyl-diacetylchitobiosyl-L-asparagine (protein)
# D-glucose
# (alpha-D-Glucosyl)2-(alpha-D-mannosyl)8-beta-D-mannosyl-diacetylchitobiosyl-L-asparagine (protein)
#
#
# MG2er
# H2O
# (alpha-D-Glucosyl)2-(alpha-D-mannosyl)8-beta-D-mannosyl-diacetylchitobiosyl-L-asparagine (protein)
# D-glucose
# (alpha-D-Glucosyl)-(alpha-D-mannosyl)8-beta-D-mannosyl-diacetylchitobiosyl-L-asparagine (protein)
#
#
# MG3er
# H2O
# (alpha-D-Glucosyl)-(alpha-D-mannosyl)8-beta-D-mannosyl-diacetylchitobiosyl-L-asparagine (protein)
# D-glucose
# (alpha-D-mannosyl)8-beta-D-mannosyl-diacetylchitobiosyl-L-asparagine (protein)
#
#
# MM5ag
# H2O
# (alpha-D-mannosyl)5-beta-D-mannosyl-diacetylchitobiosyl-L-asparagine (protein)
# D-Mannose
# (alpha-D-mannosyl)4-beta-D-mannosyl-diacetylchitobiosyl-L-asparagine (protein)
#
#
# MM5bg
# H2O
# (alpha-D-mannosyl)5-beta-D-mannosyl-diacetylchitobiosyl-L-asparagine (protein)
# D-Mannose
# (alpha-D-mannosyl)4-beta-D-mannosyl-diacetylchitobiosyl-L-asparagine (protein)
#
#
# MM5cg
# H2O
# (alpha-D-mannosyl)5-beta-D-mannosyl-diacetylchitobiosyl-L-asparagine (protein)
# D-Mannose
# (alpha-D-mannosyl)4-beta-D-mannosyl-diacetylchitobiosyl-L-asparagine (protein)
#
#
# MM6ag
# H2O
# (alpha-D-mannosyl)6-beta-D-mannosyl-diacetylchitobiosyl-L-asparagine (protein)
# D-Mannose
# (alpha-D-mannosyl)5-beta-D-mannosyl-diacetylchitobiosyl-L-asparagine (protein)
#
#
# MM6B1ag
# H2O
# (alpha-D-mannosyl)6-beta-D-mannosyl-diacetylchitobiosyl-L-asparagine (protein)
# (alpha-D-mannosyl)5-beta-D-mannosyl-diacetylchitobiosyl-L-asparagine (protein)
# D-Mannose
#
#
# MM6B1bg
# H2O
# (alpha-D-mannosyl)6-beta-D-mannosyl-diacetylchitobiosyl-L-asparagine (protein)
# (alpha-D-mannosyl)5-beta-D-mannosyl-diacetylchitobiosyl-L-asparagine (protein)
# D-Mannose
#
#
# MM6B2g
# H2O
# (alpha-D-mannosyl)6-beta-D-mannosyl-diacetylchitobiosyl-L-asparagine (protein)
# D-Mannose
# (alpha-D-mannosyl)5-beta-D-mannosyl-diacetylchitobiosyl-L-asparagine (protein)
#
#
# MM6bg
# H2O
# (alpha-D-mannosyl)6-beta-D-mannosyl-diacetylchitobiosyl-L-asparagine (protein)
# D-Mannose
# (alpha-D-mannosyl)5-beta-D-mannosyl-diacetylchitobiosyl-L-asparagine (protein)
#
#
# MM7Ag
# H2O
# (alpha-D-mannosyl)7-beta-D-mannosyl-diacetylchitobiosyl-L-asparagine, isoform A (protein)
# D-Mannose
# (alpha-D-mannosyl)6-beta-D-mannosyl-diacetylchitobiosyl-L-asparagine (protein)
#
#
# MM7B1g
# H2O
# (alpha-D-mannosyl)7-beta-D-mannosyl-diacetylchitobiosyl-L-asparagine, isoform B (protein)
# D-Mannose
# (alpha-D-mannosyl)6-beta-D-mannosyl-diacetylchitobiosyl-L-asparagine (protein)
#
#
# MM7B2g
# H2O
# (alpha-D-mannosyl)7-beta-D-mannosyl-diacetylchitobiosyl-L-asparagine, isoform B (protein)
# (alpha-D-mannosyl)6-beta-D-mannosyl-diacetylchitobiosyl-L-asparagine (protein)
# D-Mannose
#
#
# MM7Cag
# H2O
# (alpha-D-mannosyl)7-beta-D-mannosyl-diacetylchitobiosyl-L-asparagine, isoform A (protein)
# (alpha-D-mannosyl)6-beta-D-mannosyl-diacetylchitobiosyl-L-asparagine (protein)
# D-Mannose
#
#
# MM7Cbg
# H2O
# (alpha-D-mannosyl)7-beta-D-mannosyl-diacetylchitobiosyl-L-asparagine, isoform C (protein)
# (alpha-D-mannosyl)6-beta-D-mannosyl-diacetylchitobiosyl-L-asparagine (protein)
# D-Mannose
#
#
# MM8Ag
# H2O
# (alpha-D-mannosyl)8-beta-D-mannosyl-diacetylchitobiosyl-L-asparagine (protein)
# (alpha-D-mannosyl)7-beta-D-mannosyl-diacetylchitobiosyl-L-asparagine, isoform A (protein)
# D-Mannose
#
#
# MM8Ber
# H2O
# (alpha-D-mannosyl)8-beta-D-mannosyl-diacetylchitobiosyl-L-asparagine (protein)
# (alpha-D-mannosyl)7-beta-D-mannosyl-diacetylchitobiosyl-L-asparagine, isoform B (protein)
# D-Mannose
#
#
# MM8Cg
# H2O
# (alpha-D-mannosyl)8-beta-D-mannosyl-diacetylchitobiosyl-L-asparagine (protein)
# D-Mannose
# (alpha-D-mannosyl)7-beta-D-mannosyl-diacetylchitobiosyl-L-asparagine, isoform C (protein)
#
#
# N3Tg
# UDP-D-galactose(2-)
# Tn antigen
# proton
# UDP
# T antigen (core 1)
#
#
# N4Tg
# UDP-D-galactose(2-)
# Core 6
# proton
# UDP
# F1alpha
#
#
# NACHEX10ly
# H2O
# keratan sulfate I, degradation product 7
# N-acetyl-D-glucosamine
# keratan sulfate I, degradation product 8
#
#
# NACHEX11ly
# H2O
# keratan sulfate I, degradation product 10
# N-acetyl-D-glucosamine
# keratan sulfate I, degradation product 11
#
#
# NACHEX12ly
# H2O
# keratan sulfate I, degradation product 13
# N-acetyl-D-glucosamine
# keratan sulfate I, degradation product 14
#
#
# NACHEX13ly
# H2O
# keratan sulfate I, degradation product 16
# N-acetyl-D-glucosamine
# keratan sulfate I, degradation product 17
#
#
# NACHEX14ly
# H2O
# keratan sulfate I, degradation product 19
# N-acetyl-D-glucosamine
# keratan sulfate I, degradation product 20
#
#
# NACHEX15ly
# H2O
# keratan sulfate I, degradation product 22
# N-acetyl-D-glucosamine
# keratan sulfate I, degradation product 23
#
#
# NACHEX16ly
# H2O
# keratan sulfate I, degradation product 25
# N-acetyl-D-glucosamine
# keratan sulfate I, degradation product 26
#
#
# NACHEX17ly
# H2O
# keratan sulfate I, degradation product 28
# N-acetyl-D-glucosamine
# keratan sulfate I, degradation product 29
#
#
# NACHEX18ly
# H2O
# keratan sulfate I, degradation product 31
# N-acetyl-D-glucosamine
# keratan sulfate I, degradation product 32
#
#
# NACHEX19ly
# H2O
# keratan sulfate I, degradation product 34
# N-acetyl-D-glucosamine
# keratan sulfate I, degradation product 35
#
#
# NACHEX1ly
# H2O
# chondroitin sulfate A (GalNAc4S-GlcA), degradation product 1
# N-acetyl-D-galactosamine
# chondroitin sulfate A (GalNAc4S-GlcA), degradation product 2
#
#
# NACHEX20ly
# H2O
# keratan sulfate I, degradation product 37
# N-acetyl-D-glucosamine
# keratan sulfate I, degradation product 38
#
#
# NACHEX21ly
# H2O
# keratan sulfate I, degradation product 39
# N-acetyl-D-glucosamine
# keratan sulfate I, degradation product 40
#
#
# NACHEX22ly
# H2O
# keratan sulfate I, degradation product 41
# (alpha-D-mannosyl)2-beta-D-mannosyl-N-acetylglucosamine
# N-acetyl-D-glucosamine
#
#
# NACHEX23ly
# H2O
# keratan sulfate II (core 2-linked), degradation product 4
# N-acetyl-D-glucosamine
# keratan sulfate II (core 2-linked), degradation product 5
#
#
# NACHEX24ly
# H2O
# keratan sulfate II (core 2-linked), degradation product 7
# N-acetyl-D-glucosamine
# keratan sulfate II (core 2-linked), degradation product 8
#
#
# NACHEX25ly
# H2O
# keratan sulfate II (core 2-linked), degradation product 9
# N-acetyl-D-glucosamine
# F1alpha
#
#
# NACHEX26ly
# H2O
# keratan sulfate II (core 4-linked), degradation product 4
# N-acetyl-D-glucosamine
# keratan sulfate II (core 2-linked), degradation product 5
#
#
# NACHEX27ly
# H2O
# hyaluronan degradation product 1
# N-acetyl-D-glucosamine
# hyaluronan biosynthesis, precursor 1
#
#
# NACHEX2ly
# H2O
# chondroitin sulfate A (GalNAc4S-GlcA), degradation product 4
# N-acetyl-D-galactosamine
# chondroitin sulfate A (GalNAc4S-GlcA), degradation product 5
#
#
# NACHEX3ly
# H2O
# chondroitin sulfate B / dermatan sulfate (IdoA2S-GalNAc4S), degradation product 1
# N-acetyl-D-galactosamine
# chondroitin sulfate B / dermatan sulfate (IdoA2S-GalNAc4S), degradation product 2
#
#
# NACHEX4ly
# H2O
# chondroitin sulfate C (GalNAc6S-GlcA), degradation product 1
# N-acetyl-D-galactosamine
# chondroitin sulfate C (GalNAc6S-GlcA), degradation product 2
#
#
# NACHEX5ly
# H2O
# chondroitin sulfate C (GalNAc6S-GlcA), degradation product 4
# N-acetyl-D-galactosamine
# chondroitin sulfate C (GalNAc6S-GlcA), degradation product 5
#
#
# NACHEX6ly
# H2O
# chondroitin sulfate D (GlcNAc6S-GlcA2S), degradation product 1
# N-acetyl-D-galactosamine
# chondroitin sulfate D (GlcNAc6S-GlcA2S), degradation product 2
#
#
# NACHEX7ly
# H2O
# chondroitin sulfate D (GlcNAc6S-GlcA2S), degradation product 5
# N-acetyl-D-galactosamine
# ...
#
#
# S4TASE4ly
# H2O
# chondroitin sulfate E (GalNAc4,6diS-GlcA), free chain
# proton
# sulfate
# chondroitin sulfate E (GalNAc4,6diS-GlcA), degradation product 1
#
#
# S4TASE5ly
# H2O
# chondroitin sulfate E (GalNAc4,6diS-GlcA), degradation product 4
# proton
# sulfate
# chondroitin sulfate E (GalNAc4,6diS-GlcA), degradation product 5
#
#
# S6T10g
# keratan sulfate I biosynthesis, precursor 22
# 3'-Phosphoadenosine 5'-phosphosulfate; (2R,3S,4R,5R)-5-(6-amino-9H-purin-9-yl)-4-hydroxy-2-({[(sulfonatooxy)phosphinato]oxy}methyl)oxolan-3-yl phosphate
# proton
# keratan sulfate I biosynthesis, precursor 23
# adenosine 3',5'-bismonophosphate(4-)
#
#
# S6T11g
# keratan sulfate I biosynthesis, precursor 25
# 3'-Phosphoadenosine 5'-phosphosulfate; (2R,3S,4R,5R)-5-(6-amino-9H-purin-9-yl)-4-hydroxy-2-({[(sulfonatooxy)phosphinato]oxy}methyl)oxolan-3-yl phosphate
# proton
# keratan sulfate I biosynthesis, precursor 26
# adenosine 3',5'-bismonophosphate(4-)
#
#
# S6T12g
# keratan sulfate I biosynthesis, precursor 28
# 3'-Phosphoadenosine 5'-phosphosulfate; (2R,3S,4R,5R)-5-(6-amino-9H-purin-9-yl)-4-hydroxy-2-({[(sulfonatooxy)phosphinato]oxy}methyl)oxolan-3-yl phosphate
# proton
# keratan sulfate I biosynthesis, precursor 29
# adenosine 3',5'-bismonophosphate(4-)
#
#
# S6T13g
# keratan sulfate I biosynthesis, precursor 31
# 3'-Phosphoadenosine 5'-phosphosulfate; (2R,3S,4R,5R)-5-(6-amino-9H-purin-9-yl)-4-hydroxy-2-({[(sulfonatooxy)phosphinato]oxy}methyl)oxolan-3-yl phosphate
# proton
# keratan sulfate I biosynthesis, precursor 32
# adenosine 3',5'-bismonophosphate(4-)
#
#
# S6T14g
# keratan sulfate I biosynthesis, precursor 34
# 3'-Phosphoadenosine 5'-phosphosulfate; (2R,3S,4R,5R)-5-(6-amino-9H-purin-9-yl)-4-hydroxy-2-({[(sulfonatooxy)phosphinato]oxy}methyl)oxolan-3-yl phosphate
# proton
# keratan sulfate I biosynthesis, precursor 35
# adenosine 3',5'-bismonophosphate(4-)
#
#
# S6T15g
# keratan sulfate I biosynthesis, precursor 36
# 3'-Phosphoadenosine 5'-phosphosulfate; (2R,3S,4R,5R)-5-(6-amino-9H-purin-9-yl)-4-hydroxy-2-({[(sulfonatooxy)phosphinato]oxy}methyl)oxolan-3-yl phosphate
# proton
# adenosine 3',5'-bismonophosphate(4-)
# keratan sulfate I
#
#
# S6T16g
# keratan sulfate II biosynthesis, precursor 5
# 3'-Phosphoadenosine 5'-phosphosulfate; (2R,3S,4R,5R)-5-(6-amino-9H-purin-9-yl)-4-hydroxy-2-({[(sulfonatooxy)phosphinato]oxy}methyl)oxolan-3-yl phosphate
# proton
# keratan sulfate II biosynthesis, precursor 6
# adenosine 3',5'-bismonophosphate(4-)
#
#
# S6T17g
# keratan sulfate II biosynthesis, precursor 8
# 3'-Phosphoadenosine 5'-phosphosulfate; (2R,3S,4R,5R)-5-(6-amino-9H-purin-9-yl)-4-hydroxy-2-({[(sulfonatooxy)phosphinato]oxy}methyl)oxolan-3-yl phosphate
# proton
# keratan sulfate II biosynthesis, precursor 9
# adenosine 3',5'-bismonophosphate(4-)
#
#
# S6T18g
# keratan sulfate II biosynthesis, precursor 10
# 3'-Phosphoadenosine 5'-phosphosulfate; (2R,3S,4R,5R)-5-(6-amino-9H-purin-9-yl)-4-hydroxy-2-({[(sulfonatooxy)phosphinato]oxy}methyl)oxolan-3-yl phosphate
# proton
# adenosine 3',5'-bismonophosphate(4-)
# keratan sulfate II (core 4-linked)
#
#
# S6T19g
# 3'-Phosphoadenosine 5'-phosphosulfate; (2R,3S,4R,5R)-5-(6-amino-9H-purin-9-yl)-4-hydroxy-2-({[(sulfonatooxy)phosphinato]oxy}methyl)oxolan-3-yl phosphate
# chondroitin sulfate precursor (GalNAc-GlcA-(Gal)2-Xyl-L-Ser (protein))
# proton
# adenosine 3',5'-bismonophosphate(4-)
# chondroitin sulfate C (GalNAc6S-GlcA) and D (GlcNAc6S-GlcA2S), precursor 1
#
#
# S6T1g
# keratan sulfate II biosynthesis, precursor 5
# 3'-Phosphoadenosine 5'-phosphosulfate; (2R,3S,4R,5R)-5-(6-amino-9H-purin-9-yl)-4-hydroxy-2-({[(sulfonatooxy)phosphinato]oxy}methyl)oxolan-3-yl phosphate
# proton
# keratan sulfate II biosynthesis, precursor 6
# adenosine 3',5'-bismonophosphate(4-)
#
#
# S6T20g
# 3'-Phosphoadenosine 5'-phosphosulfate; (2R,3S,4R,5R)-5-(6-amino-9H-purin-9-yl)-4-hydroxy-2-({[(sulfonatooxy)phosphinato]oxy}methyl)oxolan-3-yl phosphate
# chondroitin sulfate C (GalNAc6S-GlcA), precursor 3
# proton
# chondroitin sulfate C (GalNAc6S-GlcA) proteoglycan
# adenosine 3',5'-bismonophosphate(4-)
#
#
# S6T21g
# 3'-Phosphoadenosine 5'-phosphosulfate; (2R,3S,4R,5R)-5-(6-amino-9H-purin-9-yl)-4-hydroxy-2-({[(sulfonatooxy)phosphinato]oxy}methyl)oxolan-3-yl phosphate
# chondroitin sulfate D (GlcNAc6S-GlcA2S), precursor 4
# proton
# adenosine 3',5'-bismonophosphate(4-)
# chondroitin sulfate D (GlcNAc6S-GlcA2S), precursor 5
#
#
# S6T22g
# 3'-Phosphoadenosine 5'-phosphosulfate; (2R,3S,4R,5R)-5-(6-amino-9H-purin-9-yl)-4-hydroxy-2-({[(sulfonatooxy)phosphinato]oxy}methyl)oxolan-3-yl phosphate
# chondroitin sulfate A (GalNAc4S-GlcA), B (IdoA2S-GalNAc4S), and E (GalNAc4,6diS-GlcA), precursor 1
# proton
# adenosine 3',5'-bismonophosphate(4-)
# chondroitin sulfate E (GalNAc4,6diS-GlcA), precursor 2
#
#
# S6T23g
# 3'-Phosphoadenosine 5'-phosphosulfate; (2R,3S,4R,5R)-5-(6-amino-9H-purin-9-yl)-4-hydroxy-2-({[(sulfonatooxy)phosphinato]oxy}methyl)oxolan-3-yl phosphate
# chondroitin sulfate E (GalNAc4,6diS-GlcA), precursor 5a
# proton
# chondroitin sulfate E (GalNAc4,6diS-GlcA) proteoglycan
# adenosine 3',5'-bismonophosphate(4-)
#
#
# S6T24g
# 3'-Phosphoadenosine 5'-phosphosulfate; (2R,3S,4R,5R)-5-(6-amino-9H-purin-9-yl)-4-hydroxy-2-({[(sulfonatooxy)phosphinato]oxy}methyl)oxolan-3-yl phosphate
# chondroitin sulfate E (GalNAc4,6diS-GlcA), precursor 4
# proton
# adenosine 3',5'-bismonophosphate(4-)
# chondroitin sulfate E (GalNAc4,6diS-GlcA), precursor 5b
#
#
# S6T25g
# 3'-Phosphoadenosine 5'-phosphosulfate; (2R,3S,4R,5R)-5-(6-amino-9H-purin-9-yl)-4-hydroxy-2-({[(sulfonatooxy)phosphinato]oxy}methyl)oxolan-3-yl phosphate
# GlcN2S-IdoA-GlcN2S-GlcA2S-GlcN2S-IdoA2S-GlcN2S-GlcA-GlcNAc-GlcA-Gal-Gal-Xyl-L-Ser (protein)
# proton
# adenosine 3',5'-bismonophosphate(4-)
# GlcN2S-IdoA-GlcN2,6diS-GlcA2S-GlcN2,6diS-IdoA2S-GlcN2,6diS-GlcA-GlcNAc-GlcA-Gal-Gal-Xyl-L-Ser (protein)
#
#
# S6T2g
# keratan sulfate II biosynthesis, precursor 8
# 3'-Phosphoadenosine 5'-phosphosulfate; (2R,3S,4R,5R)-5-(6-amino-9H-purin-9-yl)-4-hydroxy-2-({[(sulfonatooxy)phosphinato]oxy}methyl)oxolan-3-yl phosphate
# proton
# keratan sulfate II biosynthesis, precursor 9
# adenosine 3',5'-bismonophosphate(4-)
#
#
# S6T3g
# keratan sulfate II biosynthesis, precursor 10
# 3'-Phosphoadenosine 5'-phosphosulfate; (2R,3S,4R,5R)-5-(6-amino-9H-purin-9-yl)-4-hydroxy-2-({[(sulfonatooxy)phosphinato]oxy}methyl)oxolan-3-yl phosphate
# proton
# adenosine 3',5'-bismonophosphate(4-)
# keratan sulfate II (core 2-linked)
#
#
# S6T4g
# keratan sulfate I biosynthesis, precursor 4
# 3'-Phosphoadenosine 5'-phosphosulfate; (2R,3S,4R,5R)-5-(6-amino-9H-purin-9-yl)-4-hydroxy-2-({[(sulfonatooxy)phosphinato]oxy}methyl)oxolan-3-yl phosphate
# proton
# keratan sulfate I biosynthesis, precursor 5
# adenosine 3',5'-bismonophosphate(4-)
#
#
# S6T5g
# keratan sulfate I biosynthesis, precursor 7
# 3'-Phosphoadenosine 5'-phosphosulfate; (2R,3S,4R,5R)-5-(6-amino-9H-purin-9-yl)-4-hydroxy-2-({[(sulfonatooxy)phosphinato]oxy}methyl)oxolan-3-yl phosphate
# proton
# keratan sulfate I biosynthesis, precursor 8
# adenosine 3',5'-bismonophosphate(4-)
#
#
# S6T6g
# keratan sulfate I biosynthesis, precursor 10
# 3'-Phosphoadenosine 5'-phosphosulfate; (2R,3S,4R,5R)-5-(6-amino-9H-purin-9-yl)-4-hydroxy-2-({[(sulfonatooxy)phosphinato]oxy}methyl)oxolan-3-yl phosphate
# proton
# keratan sulfate I biosynthesis, precursor 11
# adenosine 3',5'-bismonophosphate(4-)
#
#
# S6T7g
# keratan sulfate I biosynthesis, precursor 13
# 3'-Phosphoadenosine 5'-phosphosulfate; (2R,3S,4R,5R)-5-(6-amino-9H-purin-9-yl)-4-hydroxy-2-({[(sulfonatooxy)phosphinato]oxy}methyl)oxolan-3-yl phosphate
# proton
# keratan sulfate I biosynthesis, precursor 14
# adenosine 3',5'-bismonophosphate(4-)
#
#
# S6T8g
# keratan sulfate I biosynthesis, precursor 16
# 3'-Phosphoadenosine 5'-phosphosulfate; (2R,3S,4R,5R)-5-(6-amino-9H-purin-9-yl)-4-hydroxy-2-({[(sulfonatooxy)phosphinato]oxy}methyl)oxolan-3-yl phosphate
# proton
# keratan sulfate I biosynthesis, precursor 17
# adenosine 3',5'-bismonophosphate(4-)
#
#
# S6T9g
# keratan sulfate I biosynthesis, precursor 19
# 3'-Phosphoadenosine 5'-phosphosulfate; (2R,3S,4R,5R)-5-(6-amino-9H-purin-9-yl)-4-hydroxy-2-({[(sulfonatooxy)phosphinato]oxy}methyl)oxolan-3-yl phosphate
# proton
# keratan sulfate I biosynthesis, precursor 20
# adenosine 3',5'-bismonophosphate(4-)
#
#
# S6TASE10ly
# H2O
# keratan sulfate I, degradation product 4
# proton
# sulfate
# keratan sulfate I, degradation product 5
#
#
# S6TASE11ly
# H2O
# keratan sulfate I, degradation product 6
# proton
# sulfate
# keratan sulfate I, degradation product 7
#
#
# S6TASE12ly
# H2O
# keratan sulfate I, degradation product 9
# proton
# sulfate
# keratan sulfate I, degradation product 10
#
#
# S6TASE13ly
# H2O
# keratan sulfate I, degradation product 12
# proton
# sulfate
# keratan sulfate I, degradation product 13
#
#
# S6TASE14ly
# H2O
# keratan sulfate I, degradation product 15
# proton
# sulfate
# keratan sulfate I, degradation product 16
#
#
# S6TASE15ly
# H2O
# keratan sulfate I, degradation product 18
# proton
# sulfate
# keratan sulfate I, degradation product 19
#
#
# S6TASE16ly
# H2O
# keratan sulfate I, degradation product 21
# proton
# sulfate
# keratan sulfate I, degradation product 22
#
#
# S6TASE17ly
# H2O
# keratan sulfate I, degradation product 24
# proton
# sulfate
# keratan sulfate I, degradation product 25
#
#
# S6TASE18ly
# H2O
# keratan sulfate I, degradation product 27
# proton
# sulfate
# keratan sulfate I, degradation product 28
#
#
# S6TASE19ly
# H2O
# keratan sulfate I, degradation product 30
# proton
# sulfate
# keratan sulfate I, degradation product 31
#
#
# S6TASE1ly
# H2O
# heparan sulfate, free chain
# proton
# sulfate
# heparan sulfate, degradation product 1
#
#
# S6TASE20ly
# H2O
# keratan sulfate I, degradation product 33
# proton
# sulfate
# keratan sulfate I, degradation product 34
#
#
# S6TASE21ly
# H2O
# keratan sulfate I, degradation product 36
# proton
# sulfate
# keratan sulfate I, degradation product 37
#
#
# S6TASE22ly
# H2O
# keratan sulfate II (core 2-linked), degradation product 1
# proton
# sulfate
# keratan sulfate II (core 2-linked), degradation product 2
#
#
# S6TASE23ly
# H2O
# keratan sulfate II (core 2-linked), degradation product 3
# proton
# sulfate
# keratan sulfate II (core 2-linked), degradation product 4
#
#
# S6TASE24ly
# H2O
# keratan sulfate II (core 2-linked), degradation product 6
# proton
# sulfate
# keratan sulfate II (core 2-linked), degradation product 7
#
#
# S6TASE25ly
# H2O
# keratan sulfate II (core 4-linked), degradation product 1
# proton
# sulfate
# keratan sulfate II (core 4-linked), degradation product 2
#
#
# S6TASE26ly
# H2O
# keratan sulfate II (core 4-linked), degradation product 3
# proton
# sulfate
# keratan sulfate II (core 4-linked), degradation product 4
#
#
# S6TASE2ly
# H2O
# heparan sulfate, degradation product 5
# proton
# sulfate
# heparan sulfate, degradation product 6
#
#
# S6TASE3ly
# H2O
# heparan sulfate, degradation product 11
# proton
# sulfate
# heparan sulfate, degradation product 12
#
#
# S6TASE4ly
# H2O
# chondroitin sulfate C (GalNAc6S-GlcA), free chain
# proton
# sulfate
# chondroitin sulfate C (GalNAc6S-GlcA), degradation product 1
#
#
# S6TASE5ly
# H2O
# chondroitin sulfate C (GalNAc6S-GlcA), degradation product 3
# proton
# sulfate
# chondroitin sulfate C (GalNAc6S-GlcA), degradation product 4
#
#
# S6TASE6ly
# H2O
# chondroitin sulfate D (GlcNAc6S-GlcA2S), free chain
# proton
# sulfate
# chondroitin sulfate D (GlcNAc6S-GlcA2S), degradation product 1
#
#
# S6TASE7ly
# H2O
# chondroitin sulfate D (GlcNAc6S-GlcA2S), degradation product 4
# proton
# sulfate
# chondroitin sulfate D (GlcNAc6S-GlcA2S), degradation product 5
#
#
# S6TASE8ly
# H2O
# chondroitin sulfate E (GalNAc4,6diS-GlcA), degradation product 1
# proton
# sulfate
# chondroitin sulfate E (GalNAc4,6diS-GlcA), degradation product 2
#
#
# S6TASE9ly
# H2O
# chondroitin sulfate E (GalNAc4,6diS-GlcA), degradation product 5
# proton
# sulfate
# chondroitin sulfate E (GalNAc4,6diS-GlcA), degradation product 6
#
#
# SIAASE
# H2O
# de-Fuc, reducing GlcNAc removed form of PA6 (w/o peptide linkage)
# N-acetylneuraminate
# de-Fuc, reducing GlcNAc removed, de-Sia form of PA6 (w/o peptide linkage)
#
#
# SIAASE2ly
# H2O
# keratan sulfate I, degradation product 3
# N-acetylneuraminate
# keratan sulfate I, degradation product 4
#
#
# SIAASE3ly
# H2O
# keratan sulfate II (core 2-linked)
# N-acetylneuraminate
# keratan sulfate II (core 2-linked), degradation product 1
#
#
# SIAASE4ly
# H2O
# keratan sulfate II (core 4-linked)
# N-acetylneuraminate
# keratan sulfate II (core 4-linked), degradation product 1
#
#
# SIAASEly
# H2O
# de-Fuc, reducing GlcNAc removed form of PA6 (w/o peptide linkage)
# N-acetylneuraminate
# de-Fuc, reducing GlcNAc removed, de-Sia form of PA6 (w/o peptide linkage)
#
#
# ST3GAL31g
# Lc4Cer
# CMP-N-acetyl-beta-neuraminate(2-)
# proton
# CMP
# (Gal)3 (Glc)1 (GlcNAc)1 (Cer)1
#
#
# ST3GAL61g
# Lactoneotetraosylceramide
# CMP-N-acetyl-beta-neuraminate(2-)
# proton
# CMP
# alpha-N-acetylneuraminosyl-(2->3)-beta-D-galactosyl-(1->4)-N-acetyl-beta-D-glucosaminyl-(1->3)-beta-D-galactosyl-(1->4)-beta-D-glucosylceramide(1-)
#
#
# ST3GAL62g
# i-antigen
# CMP-N-acetyl-beta-neuraminate(2-)
# proton
# VI3NeuAc-nLc6Cer
# CMP
#
#
# ST8SIA56g
# CMP-N-acetyl-beta-neuraminate(2-)
# alpha-N-acetylneuraminosyl-(2->3)-beta-D-galactosyl-(1->4)-N-acetyl-beta-D-glucosaminyl-(1->3)-beta-D-galactosyl-(1->4)-beta-D-glucosylceramide(1-)
# proton
# 3',8'-LD1
# CMP
#
#
# UDPDOLPT
# dolichyl phosphate(2-)
# UDPglucose
# UDP
# Dolichyl beta-D-glucosyl phosphate
#
#
# XYLTer
# UDP-alpha-D-xylose(2-)
# protein-linked serine residue (glycosaminoglycan attachment site)
# proton
# UDP
# Xyl-L-Ser (protein)
#
#
# GLCNCTg
# UDP-N-acetyl-alpha-D-glucosamine(2-)
# protein-linked serine or threonine residue (O-glycosylation site)
# proton
# UDP
#
#
#
# OGLNA
# H2O
#
# protein-linked serine or threonine residue (O-glycosylation site)
# N-acetyl-D-glucosamine
#
#
# HYAL
# H2O
# hyaluronan
# N-acetyl-D-glucosamine
# D-glucuronate
#
#
# HYALe
# H2O
# hyaluronan
# N-acetyl-D-glucosamine
# D-glucuronate
#
#
# GDPFPOFTr
# GDP-L-fucose(2-)
# protein-linked serine or threonine residue (O-glycosylation site)
# proton
# GDP
# Fucosyl-polypeptide
#
#
# UPDGOFUCBGTr
# UDPglucose
# Fucosyl-polypeptide
# proton
# UDP
# glucosyl, fucosyl-polypeptide
#
#
# FSERterg
# Fucosyl-polypeptide
# Fucosyl-polypeptide
#
#
# OFPGLCNACTg
# UDP-N-acetyl-alpha-D-glucosamine(2-)
# Fucosyl-polypeptide
# proton
# UDP
# N-acetylglucosaminyl, fucosyl-polypeptide
#
#
# GNOFPGALTg
# UDP-D-galactose(2-)
# N-acetylglucosaminyl, fucosyl-polypeptide
# proton
# UDP
# galactosyl, N-acetylglucosaminyl, fucosyl-polypeptide
#
#
# ST6GALGNFTg
# CMP-N-acetyl-beta-neuraminate(2-)
# galactosyl, N-acetylglucosaminyl, fucosyl-polypeptide
# CMP
# N-acetylneuraminate, galactosyl, N-acetylglucosaminyl, fucosyl-polypeptide
#
#
# POGLUTr
# UDPglucose
# protein-linked serine or threonine residue (O-glycosylation site)
# UDP
# [protein]-3-O-(beta-D-xylosyl)-L-serine
#
#
# GXYLTr
# UDP-alpha-D-xylose(2-)
# [protein]-3-O-(beta-D-xylosyl)-L-serine
# UDP
# Xylalpha(1-3)Glcbeta-Ser53-EGF-like domain of bovine factor IX(45-87)
#
#
# DOLPOMTr
# Dolichyl phosphate D-mannose
# protein-linked serine or threonine residue (O-glycosylation site)
# proton
# dolichyl phosphate(2-)
# mser[r]
#
#
# POMGNTr
# UDP-N-acetyl-alpha-D-glucosamine(2-)
# mser[r]
# UDP
# n(m)ser[r]
#
#
# POMGNGALNTr
# UDP-N-acetyl-D-galactosamine(2-)
# n(m)ser[r]
# UDP
# (GalNAc)1 (GlcNAc)1 (Man)1 (Ser/Thr)1
#
#
# POMKr
# ATP(4-)
# (GalNAc)1 (GlcNAc)1 (Man)1 (Ser/Thr)1
# ADP(3-)
#
#
#
# RBT5PCYTr
# CTP
# D-ribitol 5-phosphate
# Diphosphate(3-)
# CDP-ribitol
#
#
# PCOREM3terg
#
#
#
#
# POCDPRBTLTg
# CDP-ribitol
#
# rbtlpgalnmser[g]
# CDP
#
#
# POCDPRBTLT2g
# CDP-ribitol
# rbtlpgalnmser[g]
# CDP
# rbtlprbtlpgalnmser[g]
#
#
# POXYLTg
# UDP-alpha-D-xylose(2-)
# rbtlprbtlpgalnmser[g]
# UDP
# xylrbtlprbtlpgalnmser[g]
#
#
# POGLCNACTg
# UDP-N-acetyl-alpha-D-glucosamine(2-)
# xylrbtlprbtlpgalnmser[g]
# UDP
# nxylrbtlprbtlpgalnmser[g]
#
#
# LARGEg
# UDP-alpha-D-xylose(2-)
# nxylrbtlprbtlpgalnmser[g]
# UDP
# Alpha Dystroglycan
#
#
# MSERterg
# mser[r]
# mser[g]
#
#
# POMGNT2g
# UDP-N-acetyl-alpha-D-glucosamine(2-)
# mser[g]
# UDP
# nmser[g]
#
#
# GNOFGALTg
# UDP-D-galactose(2-)
# nmser[g]
# UDP
# (Gal)1 (GlcNAc)1 (Man)1 (Ser/Thr)1
#
#
# MNSERGALTg
# UDP-N-acetyl-alpha-D-glucosamine(2-)
# nmser[g]
# UDP
# n2mser[g]
#
#
# GNOFPGALT2g
# UDP-D-galactose(2-)
# n2mser[g]
# UDP
# (Gal)2 (GlcNAc)2 (Man)1 (Ser/Thr)1
#
#
# GGTA1g
# UDP-N-acetyl-D-galactosamine(2-)
# Lc4Cer
# proton
# UDP
#
#
#
# FUT121g
# GDP-L-fucose(2-)
#
# proton
# Type IA glycolipid
# GDP
#
#
# GNPT
# UDP-N-acetyl-alpha-D-glucosamine(2-)
# (alpha-D-mannosyl)4-beta-D-mannosyl-diacetylchitobiosyl-L-asparagine (protein)
# proton
# UDP
# (N-acetyl-D-glucosaminyl-(alpha-D-mannosyl)4-beta-D-mannosyl-diacetylchitobiosyl)-L-asparagine (protein)
#
#
# NAGPA
# H2O
# (N-acetyl-D-glucosaminyl-(alpha-D-mannosyl)4-beta-D-mannosyl-diacetylchitobiosyl)-L-asparagine (protein)
# N-acetyl-D-glucosamine
# (alpha-D-mannosyl)4-beta-D-mannosyl-diacetylchitobiosyl-L-asparagine (protein)

# %% [markdown]
# ### 3. Explore subsystems further and compare to other models

# %% [markdown]
# #### Options for further work:

# %% [markdown]
# ##### a) Explore other subsystems within iCHO2291 and other models
# ##### b) Identify some of the most important metabolites in the glycan metabolism network, for example UDPGlcNAc is an important metabolite in N-linked glycosylation, and find their corresponding reaction with these models (PMID: 36610518 is a good reference)
# ##### c) Compare the organisation of iCHO2291 with the reduced CHO GEM (CHOmpact; I have uploaded onto my Github for you) (PMID: 37272445) and see if the same subsystems and reactions are represented
# ##### d) Explore how the distribution of the model reactions (e.g. uptake and secretion as in first tutorial...) change when FBA is solved for an objective function within glycan metabolism compared with biomass maximisation
# ##### e) Based on literature, which stage of CHO culture would you expect cells to be focussing their metabolism more towards glycan metabolism, and where would they be focussing it more towards growth? (obviously this is a simplification of cell metabolism to say this and they don't 'know' what they're focussing on!)
